# %% [markdown]
# # RENT applied to a binary classification problem

# %% [markdown]
# This Jupyter notebook illustrates how to apply RENT to your data for feature selection with a *binary classification* problem. It is also complimentary to the manscript published at arXiv.org.
#
# [RENT -- Repeated Elastic Net Technique for Feature Selection](https://arxiv.org/abs/2009.12780)

# %% [markdown]
# For an example on how to use RENT for feature selection on a **regression problem**, please have a look this [Jupyter Notebook](https://github.com/NMBU-Data-Science/RENT/blob/master/src/RENT/Regression_example.ipynb).

# %% [markdown]
# ## Content

# %% [markdown]
# 1. [Load Wisconsin Breast Cancer dataset](#Load-Wisconsin-Breast-Cancer-dataset)
# 2. [Prepare data for variable selection using RENT](#Prepare-data-for-variable-selection-using-RENT)
# 2. [Define RENT ensemble for binary classification](#Define-RENT-ensemble-for-binary-classification)
# 3. [Train RENT ensemble and inspect results](#Train-RENT-ensemble-and-inspect-results)
# 4. [Set selection criteria cutoffs](#Set-selection-criteria-cutoffs)
# 5. [Investigation of class predictions](#Investigation-of-class-predictions)
# 6. [Check performance using only selected features](#Check-performance-using-only-selected-features)
# 7. [Feasibility study regarding the features selected by RENT](#Feasibility-study-regarding-the-features-selected-by-RENT)

# %% [markdown]
# ---

# %% [markdown]
# First import needed modules and apply some settings to the Jupyter notebook for better visualisation of results.

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 2000)
from RENT import RENT, stability

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load Wisconsin Breast Cancer dataset

# %% [markdown]
# Now load the data from sciki-learn, store it in a pandas DataFrame and split it into a training and test set.

# %%
from sklearn.datasets import load_breast_cancer

wisconsin = load_breast_cancer()
data = pd.DataFrame(wisconsin.data)
data.columns = wisconsin.feature_names
target = wisconsin.target

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# 0                 0.07871        1.0950         0.9053            8.589
# 1                 0.05667        0.5435         0.7339            3.398
# 2                 0.05999        0.7456         0.7869            4.585
# 3                 0.09744        0.4956         1.1560            3.445
# 4                 0.05883        0.7572         0.7813            5.438
#
#    area error  smoothness error  compactness error  concavity error  \
# 0      153.40          0.006399            0.04904          0.05373
# 1       74.08          0.005225            0.01308          0.01860
# 2       94.03          0.006150            0.04006          0.03832
# 3       27.23          0.009110            0.07458          0.05661
# 4       94.44          0.011490            0.02461          0.05688
#
#    concave points error  symmetry error  fractal dimension error  \
# 0               0.01587         0.03003                 0.006193
# 1               0.01340         0.01389                 0.003532
# 2               0.02058         0.02250                 0.004571
# 3               0.01867         0.05963                 0.009208
# 4               0.01885         0.01756                 0.005115
#
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0         25.38          17.33           184.60      2019.0            0.1622
# 1         24.99          23.41           158.80      1956.0            0.1238
# 2         23.57          25.53           152.50      1709.0            0.1444
# 3         14.91          26.50            98.87       567.7            0.2098
# 4         22.54          16.67           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678

# %% [markdown]
# ### Prepare data for variable selection using RENT

# %% [markdown]
# First split the data into a training and test data.

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, target, random_state=0, shuffle=True)

# %% [markdown]
# ### Define RENT ensemble for binary classification

# %% [markdown]
# **The main idea**
#
# Using the RENT approach we will train an **ensemble of unique models** based on **unique subsets** of the training data. Since each model is trained on a unique subset, all models will be slightly different from each other and elastic net regularisation **may select a different subset of features for each model**.
#
# RENT investigates **how consistenly elastic net selects features** across all unique models by analysing distributions of the weight sizes of each feature. Using specific thresholds or cutoff values for selection criteria $\tau_1$, $\tau_2$ and $\tau_3$ computed from those weight size distributions, we can regulate how aggressively RENT will select features from the full set of features. For more details, please consult the paper mentioned at the top of this Juptyer notebook

# %% [markdown]
# **Elastic net regularisation**
#
# $\lambda_{enet}(\beta) = \gamma [\alpha\lambda_1(\beta)+ (1-\alpha)\lambda_2(\beta)]$

# %% [markdown]
# Since the average prediction performance of an ensemble of models may vary for different combinations of $\gamma$ and $\alpha$ we pre-define a number of values for each and store them in lists `my_C_params` and `my_l1_ratios`. Prior to RENT, the best performing combination of $\gamma$ and $\alpha$ for prediction will be identified through 5-fold cross validation. For the best performing combination RENT will then compute an ensemble of models that will be utilised for feature selection.
#
# **Note** regarding elastic net regularisation term above we follow the scikit-learn convention:
#
# * RENT input paramter `C` represents inverse values of $\gamma$
# * RENT input parameter `l1_ratio` represents values of $\alpha$ for the mix of L1 and L2 regularisation. `l1_ratio = 1` is equivalent to using L1-regularisation, `l1_ratio = 0` is equivalent to using L2-regularisation while values between 0 and 1 will result in a mix of L1 and L2 regularisation.

# %% [markdown]
# In the code below we initialise the `RENT_Classification` ensemble. In addition to various values for `C` and `l1_ratio` we can define:
#
# * `autoEnetParSel`: whether identification of best performing `C` and `l1_ratio` should be done automatic through 5-fold cross validation (set to `True`) or if user selects manually (set to `False`)
# * `poly`: whether to include squares of features and interactions of features. Should be beneficial if data are non-linear, but comes with a computational cost that may increase very much if the number of orginal set of features is high.
# * `testsize_range`: this allows for more randomness in models by allowing test set sizes to vary within range defined in tuple (lower end, higher end). Set both parameters to the same value to secure identical test set size across for all models in ensemble.
# * `scoring`: performance metric to use for model evaluation
# * `method`: which classification algorithm to choose for model training. Uses logistic regression by default.
# * `K`: how many models the ensemble should consist of. The higher the better (denser weight distributions leading to higher selection stability), but computationally more expensive.
# * `random_sate`: set a seed to reproduce examples. Default: None.
# * `verbose`: whether or not to show progress during computations. Choose 1 to get information on computation progress, else 0.
#
# For more detailed information for each input parameter, please consult the documentation [link here]

# %%
# Define a range of regularisation parameters C for elastic net. A minimum of at least one value is required.
my_C_params = [0.1, 1, 10]

# Define a reange of l1-ratios for elastic net.  A minimum of at least one value is required.
my_l1_ratios = [0, 0.1, 0.25, 0.5, 0.75, 0.9, 1]

# Define setting for RENT
analysis = RENT.RENT_Classification(data=train_data, 
                                    target=train_labels, 
                                    feat_names=train_data.columns, 
                                    C=my_C_params, 
                                    l1_ratios=my_l1_ratios,
                                    autoEnetParSel=True,
                                    poly='OFF',
                                    testsize_range=(0.25,0.25),
                                    scoring='mcc',
                                    classifier='logreg',
                                    K=100,
                                    random_state = 0,
                                    verbose=1)
# Out:
# data dimension: (426, 30)  data type: <class 'pandas.core.frame.DataFrame'>
# target dimension (426,)
# regularization parameters C: [0.1, 1, 10]
# elastic net l1_ratios: [0, 0.1, 0.25, 0.5, 0.75, 0.9, 1]
# number of models in ensemble: 100
# scale: True
# classifier: logreg
# random state: 0
# verbose: 1

# %% [markdown]
# ### Train RENT ensemble and inspect results

# %% [markdown]
# Now train a RENT ensemble for the best combination of `C` and `l1_ratio`. The best has already been identified through 5-fold CV with `autoEnetParSel`.

# %%
analysis.train()

# %% [markdown]
# If it is of interest, one can extract time (sec) for computation of all ensembles.

# %%
analysis.get_runtime()
# Out:
# 9.854905366897583

# %% [markdown]
# Acquire the elastic net parameter for which RENT was applied to the data using `.get_enet_params()`.

# %%
# can play around with enet parameter setting...
analysis.get_enet_params()
# Out:
# (0.1, 1.0)

# %% [markdown]
# For the data at hand, best parameter combination is `l1_ratio=0.1` and `C=1`.

# %% [markdown]
# ### Set selection criteria cutoffs

# %% [markdown]
# Here we can set how agressively we want RENT to select features by setting thresholds or cutoff values for $\tau_1$, $\tau_2$ and $\tau_3$.
#
# Below we set `tau_1_cutoff = 0.9`, meaning that we will consider only features that were selected in at least 90% across the $K$ ensemble models.
#
# Sometimes features are selected by elastic net (weight is non-zero), but their weights might be very small. This happens more often when `l1_ratio` is such that the L2-part of the regularisation gets more influence than L1 (smaller values for `l1_ratio`). In addition, feature weights may be positive in some models and negative in others showing little consistency. This may indicate that even though such a feature is selected, it may not be very meaningful, since its feature weights are small and alternating signs. The `tau_2_cutoff` criterion simply allows the user to define a required minimum proportion of the parameter estimates to have the same sign.
#
# `tau_3_cutoff` is chosen such that it corresponds to the well-known statistical Student’s t-test with rejection of the null hypothesis, assuming that the mean of the feature weights across all models is equal to zero. In other words, we test whether the feature weighs are consistently high with low variance across the $K$ models.
#
# Only if the resulting values for each feature are higher than the cutoff for all three criteria, the RENT will select the feature. In the example below we set the cutoff criteria to `tau_1_cutoff=0.9`, `tau_2_cutoff=0.9`, `tau_3_cutoff=0.975`.

# %%
selected_features = analysis.selectFeatures(tau_1_cutoff=0.9, tau_2_cutoff=0.9, tau_3_cutoff=0.975)

# %% [markdown]
# How do we know whether a feature fulfills the criteria?
#
# We can check this by looking at the summary for `tau_1`, `tau_2` and `tau_3` across all features using `.summary_criteria()`. We can see for example that RENT selects feature `worst radius`, since its vaues for `tau_1`, `tau_2` and `tau_3` are all 1, i.e above the cutoffs set in the code above. Feature `mean concave points` gets close with `tau_1=0.89` and `tau_2=0.89`, but they are still below `tau_1_cutoff` and `tau_2_cutoff`. If we would set lower cutoffs, say `tau_1=0.8` and `tau_2=0.8` `mean concave points` would be selected. By varying cutoffs for `tau_1`, `tau_2` and `tau_3` we can define how strict RENT has to be when selecting features.

# %%
analysis.summary_criteria()
# Out:
#        mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# tau_1          0.0      0.240000             0.0        0.0              0.0
# tau_2          0.0      0.240000             0.0        0.0              0.0
# tau_3          NaN      0.999987             NaN        NaN              NaN
#
#        mean compactness  mean concavity  mean concave points  mean symmetry  \
# tau_1               0.0             0.0                 0.89            0.0
# tau_2               0.0             0.0                 0.89            0.0
# tau_3               NaN             NaN                 1.00            NaN
#
#        mean fractal dimension  radius error  texture error  perimeter error  \
# tau_1                     0.0          0.61            0.0              0.0
# tau_2                     0.0          0.61            0.0              0.0
# tau_3                     NaN          1.00            NaN              NaN
#
#        area error  smoothness error  compactness error  concavity error  \
# tau_1         0.0               0.0                0.0              0.0
# tau_2         0.0               0.0                0.0              0.0
# tau_3         NaN               NaN                NaN              NaN
#
#        concave points error  symmetry error  fractal dimension error  \
# tau_1                   0.0             0.0                      0.0
# tau_2                   0.0             0.0                      0.0
# tau_3                   NaN             NaN                      NaN
#
#        worst radius  worst texture  worst perimeter  worst area  \
# tau_1           1.0            1.0         0.110000         0.0
# tau_2           1.0            1.0         0.110000         0.0
# tau_3           1.0            1.0         0.994932         NaN
#
#        worst smoothness  worst compactness  worst concavity  \
# tau_1          0.420000                0.0         0.110000
# tau_2          0.420000                0.0         0.110000
# tau_3          0.999999                NaN         0.997439
#
#        worst concave points  worst symmetry  worst fractal dimension
# tau_1                   1.0            0.96                      0.0
# tau_2                   1.0            0.96                      0.0
# tau_3                   1.0            1.00                      NaN

# %% [markdown]
# Let's check which features were selected based on the cutoffs we defined above.

# %%
selected_features
# Out:
# array([20, 21, 27, 28], dtype=int64)

# %% [markdown]
# Using the indices of the selected features we can identify the feature names.

# %%
train_data.columns[selected_features]
# Out:
# Index(['worst radius', 'worst texture', 'worst concave points',
#        'worst symmetry'],
#       dtype='object')

# %% [markdown]
# **Regarding $\tau_{1}$**
#
# To get a better impression on how often a feature weight was non-zero across all models, we use `.plot_selection_frequency()`. We can see from the plot that across all models in the ensemble elastic net for example never selected features at index 2 through 6, 11 through 19 as well as 23, 25 and 29. This means that elastic net always sets the weights for those feature to zero, across all models in the ensemble. Elatic net selected some features only for a few models in the ensemble (features at index 22 and 26), that is in around 10% of the models (approx. 0.1 on the vertical axis) or lower (for example features at index 0, 2-6, etc). This indicates that the selection of these features by elastic net is relatively unstable and very dependent on the subset of the training samples.

# %%
analysis.plot_selection_frequency()

# %% [markdown]
# **Regarding $\tau_{2}$ and $\tau_{3}$**
#
# One has to keep in mind though, that a feature may be selected by elastic net (i.e. the weight i non-zero), but it may be:
#
# 1. very small and hence not very influential to the model (even though it was selected by elastic net)
# 2. alternating its sign (positive or negative weight value) across the ensemble of models, indicating unstable importance of this feature.
#
# To get more detailed information on the weight sizes one could investigate the full distribution of the weights of each feature across all models. This is possible by calling `.get_weight_distributions()`. This returns an array holding all weights across all models in the ensemble (rows) and each feature (columns). Here we can see that for the feature at index 5 `mean compactness` the weights are always 0 across all 100 models applied in this example (corresponding to the plot above). Selecting `binary=True`, returns a binary matrix, where those postitions where weights is unequal to 0 are assigned 1.

# %%
analysis.get_weight_distributions(binary=False)
# Out:
#          mean radius  mean texture  mean perimeter  mean area  \
# mod 1            0.0      0.000000             0.0        0.0
# mod 2            0.0      0.000000             0.0        0.0
# mod 3            0.0      0.000000             0.0        0.0
# mod 4            0.0      0.000000             0.0        0.0
# mod 5            0.0     -0.151800             0.0        0.0
# mod 6            0.0     -0.160611             0.0        0.0
# mod 7            0.0      0.000000             0.0        0.0
# mod 8            0.0     -0.188747             0.0        0.0
# mod 9            0.0      0.000000             0.0        0.0
# mod 10           0.0      0.000000             0.0        0.0
# mod 11           0.0      0.000000             0.0        0.0
# mod 12           0.0     -0.050933             0.0        0.0
# mod 13           0.0     -0.079598             0.0        0.0
# mod 14           0.0      0.000000             0.0        0.0
# mod 15           0.0      0.000000             0.0        0.0
# mod 16           0.0      0.000000             0.0        0.0
# mod 17           0.0      0.000000             0.0        0.0
# mod 18           0.0      0.000000             0.0        0.0
# mod 19           0.0      0.000000             0.0        0.0
# mod 20           0.0      0.000000             0.0        0.0
# mod 21           0.0      0.000000             0.0        0.0
# mod 22           0.0     -0.136506             0.0        0.0
# mod 23           0.0     -0.040317             0.0        0.0
# mod 24           0.0      0.000000             0.0        0.0
# mod 25           0.0     -0.065171             0.0        0.0
# mod 26           0.0     -0.034513             0.0        0.0
# mod 27           0.0      0.000000             0.0        0.0
# mod 28           0.0      0.000000             0.0        0.0
# mod 29           0.0      0.000000             0.0        0.0
# mod 30           0.0      0.000000             0.0        0.0
# mod 31           0.0      0.000000             0.0        0.0
# mod 32           0.0      0.000000             0.0        0.0
# mod 33           0.0      0.000000             0.0        0.0
# mod 34           0.0     -0.215790             0.0        0.0
# mod 35           0.0      0.000000             0.0        0.0
# mod 36           0.0     -0.013285             0.0        0.0
# mod 37           0.0      0.000000             0.0        0.0
# mod 38           0.0      0.000000             0.0        0.0
# mod 39           0.0     -0.063216             0.0        0.0
# mod 40           0.0      0.000000             0.0        0.0
# mod 41           0.0      0.000000             0.0        0.0
# mod 42           0.0      0.000000             0.0        0.0
# mod 43           0.0      0.000000             0.0        0.0
# mod 44           0.0      0.000000             0.0        0.0
# mod 45           0.0      0.000000             0.0        0.0
# mod 46           0.0      0.000000             0.0        0.0
# mod 47           0.0      0.000000             0.0        0.0
# mod 48           0.0      0.000000             0.0        0.0
# mod 49           0.0     -0.105471             0.0        0.0
# mod 50           0.0      0.000000             0.0        0.0
# mod 51           0.0      0.000000             0.0        0.0
# mod 52           0.0      0.000000             0.0        0.0
# mod 53           0.0     -0.001872             0.0        0.0
# mod 54           0.0      0.000000             0.0        0.0
# mod 55           0.0      0.000000             0.0        0.0
# mod 56           0.0      0.000000             0.0        0.0
# mod 57           0.0      0.000000             0.0        0.0
# mod 58           0.0      0.000000             0.0        0.0
# mod 59           0.0      0.000000             0.0        0.0
# mod 60           0.0     -0.168847             0.0        0.0
# mod 61           0.0      0.000000             0.0        0.0
# mod 62           0.0      0.000000             0.0        0.0
# mod 63           0.0      0.000000             0.0        0.0
# mod 64           0.0      0.000000             0.0        0.0
# mod 65           0.0     -0.003389             0.0        0.0
# mod 66           0.0      0.000000             0.0        0.0
# mod 67           0.0      0.000000             0.0        0.0
# mod 68           0.0     -0.062414             0.0        0.0
# mod 69           0.0      0.000000             0.0        0.0
# mod 70           0.0     -0.127193             0.0        0.0
# mod 71           0.0      0.000000             0.0        0.0
# mod 72           0.0      0.000000             0.0        0.0
# mod 73           0.0      0.000000             0.0        0.0
# mod 74           0.0      0.000000             0.0        0.0
# mod 75           0.0      0.000000             0.0        0.0
# mod 76           0.0     -0.287658             0.0        0.0
# mod 77           0.0      0.000000             0.0        0.0
# mod 78           0.0      0.000000             0.0        0.0
# mod 79           0.0      0.000000             0.0        0.0
# mod 80           0.0      0.000000             0.0        0.0
# mod 81           0.0     -0.094453             0.0        0.0
# mod 82           0.0      0.000000             0.0        0.0
# mod 83           0.0      0.000000             0.0        0.0
# mod 84           0.0      0.000000             0.0        0.0
# mod 85           0.0      0.000000             0.0        0.0
# mod 86           0.0     -0.222060             0.0        0.0
# mod 87           0.0      0.000000             0.0        0.0
# mod 88           0.0      0.000000             0.0        0.0
# mod 89           0.0     -0.108852             0.0        0.0
# mod 90           0.0      0.000000             0.0        0.0
# mod 91           0.0      0.000000             0.0        0.0
# mod 92           0.0      0.000000             0.0        0.0
# mod 93           0.0      0.000000             0.0        0.0
# mod 94           0.0      0.000000             0.0        0.0
# mod 95           0.0     -0.292387             0.0        0.0
# mod 96           0.0      0.000000             0.0        0.0
# mod 97           0.0      0.000000             0.0        0.0
# mod 98           0.0      0.000000             0.0        0.0
# mod 99           0.0      0.000000             0.0        0.0
# mod 100          0.0     -0.164429             0.0        0.0
#
#          mean smoothness  mean compactness  mean concavity  \
# mod 1                0.0               0.0             0.0
# mod 2                0.0               0.0             0.0
# mod 3                0.0               0.0             0.0
# mod 4                0.0               0.0             0.0
# mod 5                0.0               0.0             0.0
# mod 6                0.0               0.0             0.0
# mod 7                0.0               0.0             0.0
# mod 8                0.0               0.0             0.0
# mod 9                0.0               0.0             0.0
# mod 10               0.0               0.0             0.0
# mod 11               0.0               0.0             0.0
# mod 12               0.0               0.0             0.0
# mod 13               0.0               0.0             0.0
# mod 14               0.0               0.0             0.0
# mod 15               0.0               0.0             0.0
# mod 16               0.0               0.0             0.0
# mod 17               0.0               0.0             0.0
# mod 18               0.0               0.0             0.0
# mod 19               0.0               0.0             0.0
# mod 20               0.0               0.0             0.0
# mod 21               0.0               0.0             0.0
# mod 22               0.0               0.0             0.0
# mod 23               0.0               0.0             0.0
# mod 24               0.0               0.0             0.0
# mod 25               0.0               0.0             0.0
# mod 26               0.0               0.0             0.0
# mod 27               0.0               0.0             0.0
# mod 28               0.0               0.0             0.0
# mod 29               0.0               0.0             0.0
# mod 30               0.0               0.0             0.0
# mod 31               0.0               0.0             0.0
# mod 32               0.0               0.0             0.0
# mod 33               0.0               0.0             0.0
# mod 34               0.0               0.0             0.0
# mod 35               0.0               0.0             0.0
# mod 36               0.0               0.0             0.0
# mod 37               0.0               0.0             0.0
# mod 38               0.0               0.0             0.0
# mod 39               0.0               0.0             0.0
# mod 40               0.0               0.0             0.0
# mod 41               0.0               0.0             0.0
# mod 42               0.0               0.0             0.0
# mod 43               0.0               0.0             0.0
# mod 44               0.0               0.0             0.0
# mod 45               0.0               0.0             0.0
# mod 46               0.0               0.0             0.0
# mod 47               0.0               0.0             0.0
# mod 48               0.0               0.0             0.0
# mod 49               0.0               0.0             0.0
# mod 50               0.0               0.0             0.0
# mod 51               0.0               0.0             0.0
# mod 52               0.0               0.0             0.0
# mod 53               0.0               0.0             0.0
# mod 54               0.0               0.0             0.0
# mod 55               0.0               0.0             0.0
# mod 56               0.0               0.0             0.0
# mod 57               0.0               0.0             0.0
# mod 58               0.0               0.0             0.0
# mod 59               0.0               0.0             0.0
# mod 60               0.0               0.0             0.0
# mod 61               0.0               0.0             0.0
# mod 62               0.0               0.0             0.0
# mod 63               0.0               0.0             0.0
# mod 64               0.0               0.0             0.0
# mod 65               0.0               0.0             0.0
# mod 66               0.0               0.0             0.0
# mod 67               0.0               0.0             0.0
# mod 68               0.0               0.0             0.0
# mod 69               0.0               0.0             0.0
# mod 70               0.0               0.0             0.0
# mod 71               0.0               0.0             0.0
# mod 72               0.0               0.0             0.0
# mod 73               0.0               0.0             0.0
# mod 74               0.0               0.0             0.0
# mod 75               0.0               0.0             0.0
# mod 76               0.0               0.0             0.0
# mod 77               0.0               0.0             0.0
# mod 78               0.0               0.0             0.0
# mod 79               0.0               0.0             0.0
# mod 80               0.0               0.0             0.0
# mod 81               0.0               0.0             0.0
# mod 82               0.0               0.0             0.0
# mod 83               0.0               0.0             0.0
# mod 84               0.0               0.0             0.0
# mod 85               0.0               0.0             0.0
# mod 86               0.0               0.0             0.0
# mod 87               0.0               0.0             0.0
# mod 88               0.0               0.0             0.0
# mod 89               0.0               0.0             0.0
# mod 90               0.0               0.0             0.0
# mod 91               0.0               0.0             0.0
# mod 92               0.0               0.0             0.0
# mod 93               0.0               0.0             0.0
# mod 94               0.0               0.0             0.0
# mod 95               0.0               0.0             0.0
# mod 96               0.0               0.0             0.0
# mod 97               0.0               0.0             0.0
# mod 98               0.0               0.0             0.0
# mod 99               0.0               0.0             0.0
# mod 100              0.0               0.0             0.0
#
#          mean concave points  mean symmetry  mean fractal dimension  \
# mod 1              -0.592774            0.0                     0.0
# mod 2              -0.266020            0.0                     0.0
# mod 3              -0.263514            0.0                     0.0
# mod 4              -0.233032            0.0                     0.0
# mod 5              -0.280237            0.0                     0.0
# mod 6              -0.070120            0.0                     0.0
# mod 7              -0.116526            0.0                     0.0
# mod 8               0.000000            0.0                     0.0
# mod 9              -0.397411            0.0                     0.0
# mod 10             -0.717156            0.0                     0.0
# mod 11              0.000000            0.0                     0.0
# mod 12             -0.170589            0.0                     0.0
# mod 13              0.000000            0.0                     0.0
# mod 14             -0.136213            0.0                     0.0
# mod 15             -0.497641            0.0                     0.0
# mod 16             -0.851190            0.0                     0.0
# mod 17             -0.505203            0.0                     0.0
# mod 18             -0.352334            0.0                     0.0
# mod 19             -0.489564            0.0                     0.0
# mod 20             -0.340684            0.0                     0.0
# mod 21             -0.208020            0.0                     0.0
# mod 22             -0.490307            0.0                     0.0
# mod 23             -0.187029            0.0                     0.0
# mod 24             -0.578088            0.0                     0.0
# mod 25             -0.436680            0.0                     0.0
# mod 26             -0.207844            0.0                     0.0
# mod 27             -0.580907            0.0                     0.0
# mod 28             -0.371771            0.0                     0.0
# mod 29             -0.389046            0.0                     0.0
# mod 30             -0.714898            0.0                     0.0
# mod 31             -0.186613            0.0                     0.0
# mod 32             -0.108837            0.0                     0.0
# mod 33             -0.579934            0.0                     0.0
# mod 34             -0.632255            0.0                     0.0
# mod 35             -0.753671            0.0                     0.0
# mod 36             -0.547913            0.0                     0.0
# mod 37             -0.628291            0.0                     0.0
# mod 38             -0.331326            0.0                     0.0
# mod 39              0.000000            0.0                     0.0
# mod 40             -0.566815            0.0                     0.0
# mod 41             -0.532935            0.0                     0.0
# mod 42             -0.693228            0.0                     0.0
# mod 43             -0.414867            0.0                     0.0
# mod 44              0.000000            0.0                     0.0
# mod 45              0.000000            0.0                     0.0
# mod 46             -0.703557            0.0                     0.0
# mod 47             -0.438678            0.0                     0.0
# mod 48             -0.308121            0.0                     0.0
# mod 49              0.000000            0.0                     0.0
# mod 50             -0.719083            0.0                     0.0
# mod 51             -0.261296            0.0                     0.0
# mod 52             -0.204836            0.0                     0.0
# mod 53             -0.316401            0.0                     0.0
# mod 54             -0.811369            0.0                     0.0
# mod 55             -0.457105            0.0                     0.0
# mod 56             -0.725742            0.0                     0.0
# mod 57             -0.353580            0.0                     0.0
# mod 58             -0.438179            0.0                     0.0
# mod 59             -0.039982            0.0                     0.0
# mod 60             -0.213259            0.0                     0.0
# mod 61             -0.042206            0.0                     0.0
# mod 62              0.000000            0.0                     0.0
# mod 63             -0.079933            0.0                     0.0
# mod 64              0.000000            0.0                     0.0
# mod 65             -0.626854            0.0                     0.0
# mod 66             -0.704388            0.0                     0.0
# mod 67             -0.473712            0.0                     0.0
# mod 68             -0.334488            0.0                     0.0
# mod 69             -0.362488            0.0                     0.0
# mod 70             -0.157569            0.0                     0.0
# mod 71             -0.239789            0.0                     0.0
# mod 72             -0.184386            0.0                     0.0
# mod 73             -0.342108            0.0                     0.0
# mod 74             -0.372449            0.0                     0.0
# mod 75             -0.457729            0.0                     0.0
# mod 76             -0.210904            0.0                     0.0
# mod 77             -0.519850            0.0                     0.0
# mod 78             -1.174256            0.0                     0.0
# mod 79             -0.621313            0.0                     0.0
# mod 80              0.000000            0.0                     0.0
# mod 81             -0.626989            0.0                     0.0
# mod 82             -0.657114            0.0                     0.0
# mod 83             -0.519492            0.0                     0.0
# mod 84             -0.118152            0.0                     0.0
# mod 85             -0.755672            0.0                     0.0
# mod 86             -0.103570            0.0                     0.0
# mod 87             -0.741852            0.0                     0.0
# mod 88             -0.267032            0.0                     0.0
# mod 89             -0.277928            0.0                     0.0
# mod 90             -0.360318            0.0                     0.0
# mod 91             -0.216798            0.0                     0.0
# mod 92             -0.036998            0.0                     0.0
# mod 93             -0.313226            0.0                     0.0
# mod 94             -0.810787            0.0                     0.0
# mod 95             -0.124265            0.0                     0.0
# mod 96             -0.482198            0.0                     0.0
# mod 97              0.000000            0.0                     0.0
# mod 98             -0.637555            0.0                     0.0
# mod 99             -0.231995            0.0                     0.0
# mod 100            -0.047495            0.0                     0.0
#
#          radius error  texture error  perimeter error  area error  \
# mod 1       -0.168600            0.0              0.0         0.0
# mod 2        0.000000            0.0              0.0         0.0
# mod 3       -0.301408            0.0              0.0         0.0
# mod 4       -0.563132            0.0              0.0         0.0
# mod 5       -0.044982            0.0              0.0         0.0
# mod 6       -0.325326            0.0              0.0         0.0
# mod 7        0.000000            0.0              0.0         0.0
# mod 8       -0.349329            0.0              0.0         0.0
# mod 9        0.000000            0.0              0.0         0.0
# mod 10      -0.154604            0.0              0.0         0.0
# mod 11      -0.443104            0.0              0.0         0.0
# mod 12      -0.050428            0.0              0.0         0.0
# mod 13      -0.374118            0.0              0.0         0.0
# mod 14      -0.406776            0.0              0.0         0.0
# mod 15       0.000000            0.0              0.0         0.0
# mod 16       0.000000            0.0              0.0         0.0
# mod 17       0.000000            0.0              0.0         0.0
# mod 18      -0.086572            0.0              0.0         0.0
# mod 19      -0.186151            0.0              0.0         0.0
# mod 20       0.000000            0.0              0.0         0.0
# mod 21      -0.379140            0.0              0.0         0.0
# mod 22       0.000000            0.0              0.0         0.0
# mod 23      -0.016092            0.0              0.0         0.0
# mod 24      -0.249969            0.0              0.0         0.0
# mod 25      -0.177204            0.0              0.0         0.0
# mod 26      -0.176931            0.0              0.0         0.0
# mod 27       0.000000            0.0              0.0         0.0
# mod 28      -0.266493            0.0              0.0         0.0
# mod 29      -0.178202            0.0              0.0         0.0
# mod 30       0.000000            0.0              0.0         0.0
# mod 31      -0.521142            0.0              0.0         0.0
# mod 32      -0.350683            0.0              0.0         0.0
# mod 33      -0.117550            0.0              0.0         0.0
# mod 34      -0.186701            0.0              0.0         0.0
# mod 35       0.000000            0.0              0.0         0.0
# mod 36      -0.035228            0.0              0.0         0.0
# mod 37      -0.131694            0.0              0.0         0.0
# mod 38       0.000000            0.0              0.0         0.0
# mod 39      -0.293331            0.0              0.0         0.0
# mod 40       0.000000            0.0              0.0         0.0
# mod 41       0.000000            0.0              0.0         0.0
# mod 42      -0.246083            0.0              0.0         0.0
# mod 43       0.000000            0.0              0.0         0.0
# mod 44      -0.505211            0.0              0.0         0.0
# mod 45      -0.210376            0.0              0.0         0.0
# mod 46      -0.027999            0.0              0.0         0.0
# mod 47       0.000000            0.0              0.0         0.0
# mod 48      -0.353529            0.0              0.0         0.0
# mod 49      -0.423254            0.0              0.0         0.0
# mod 50      -0.120416            0.0              0.0         0.0
# mod 51      -0.418962            0.0              0.0         0.0
# mod 52      -0.294137            0.0              0.0         0.0
# mod 53      -0.160656            0.0              0.0         0.0
# mod 54       0.000000            0.0              0.0         0.0
# mod 55       0.000000            0.0              0.0         0.0
# mod 56      -0.119648            0.0              0.0         0.0
# mod 57      -0.220443            0.0              0.0         0.0
# mod 58       0.000000            0.0              0.0         0.0
# mod 59       0.000000            0.0              0.0         0.0
# mod 60      -0.248154            0.0              0.0         0.0
# mod 61      -0.497709            0.0              0.0         0.0
# mod 62      -0.375984            0.0              0.0         0.0
# mod 63      -0.534044            0.0              0.0         0.0
# mod 64      -0.419756            0.0              0.0         0.0
# mod 65      -0.367609            0.0              0.0         0.0
# mod 66       0.000000            0.0              0.0         0.0
# mod 67       0.000000            0.0              0.0         0.0
# mod 68      -0.146747            0.0              0.0         0.0
# mod 69      -0.270689            0.0              0.0         0.0
# mod 70      -0.196312            0.0              0.0         0.0
# mod 71       0.000000            0.0              0.0         0.0
# mod 72       0.000000            0.0              0.0         0.0
# mod 73      -0.528679            0.0              0.0         0.0
# mod 74       0.000000            0.0              0.0         0.0
# mod 75      -0.278258            0.0              0.0         0.0
# mod 76      -0.367126            0.0              0.0         0.0
# mod 77       0.000000            0.0              0.0         0.0
# mod 78      -0.014636            0.0              0.0         0.0
# mod 79      -0.343508            0.0              0.0         0.0
# mod 80      -0.587179            0.0              0.0         0.0
# mod 81      -0.072983            0.0              0.0         0.0
# mod 82       0.000000            0.0              0.0         0.0
# mod 83       0.000000            0.0              0.0         0.0
# mod 84      -0.168595            0.0              0.0         0.0
# mod 85       0.000000            0.0              0.0         0.0
# mod 86      -0.302070            0.0              0.0         0.0
# mod 87       0.000000            0.0              0.0         0.0
# mod 88       0.000000            0.0              0.0         0.0
# mod 89      -0.187005            0.0              0.0         0.0
# mod 90       0.000000            0.0              0.0         0.0
# mod 91       0.000000            0.0              0.0         0.0
# mod 92       0.000000            0.0              0.0         0.0
# mod 93       0.000000            0.0              0.0         0.0
# mod 94       0.000000            0.0              0.0         0.0
# mod 95      -0.359933            0.0              0.0         0.0
# mod 96       0.000000            0.0              0.0         0.0
# mod 97      -0.297239            0.0              0.0         0.0
# mod 98      -0.078778            0.0              0.0         0.0
# mod 99       0.000000            0.0              0.0         0.0
# mod 100      0.000000            0.0              0.0         0.0
#
#          smoothness error  compactness error  concavity error  \
# mod 1                 0.0                0.0              0.0
# mod 2                 0.0                0.0              0.0
# mod 3                 0.0                0.0              0.0
# mod 4                 0.0                0.0              0.0
# mod 5                 0.0                0.0              0.0
# mod 6                 0.0                0.0              0.0
# mod 7                 0.0                0.0              0.0
# mod 8                 0.0                0.0              0.0
# mod 9                 0.0                0.0              0.0
# mod 10                0.0                0.0              0.0
# mod 11                0.0                0.0              0.0
# mod 12                0.0                0.0              0.0
# mod 13                0.0                0.0              0.0
# mod 14                0.0                0.0              0.0
# mod 15                0.0                0.0              0.0
# mod 16                0.0                0.0              0.0
# mod 17                0.0                0.0              0.0
# mod 18                0.0                0.0              0.0
# mod 19                0.0                0.0              0.0
# mod 20                0.0                0.0              0.0
# mod 21                0.0                0.0              0.0
# mod 22                0.0                0.0              0.0
# mod 23                0.0                0.0              0.0
# mod 24                0.0                0.0              0.0
# mod 25                0.0                0.0              0.0
# mod 26                0.0                0.0              0.0
# mod 27                0.0                0.0              0.0
# mod 28                0.0                0.0              0.0
# mod 29                0.0                0.0              0.0
# mod 30                0.0                0.0              0.0
# mod 31                0.0                0.0              0.0
# mod 32                0.0                0.0              0.0
# mod 33                0.0                0.0              0.0
# mod 34                0.0                0.0              0.0
# mod 35                0.0                0.0              0.0
# mod 36                0.0                0.0              0.0
# mod 37                0.0                0.0              0.0
# mod 38                0.0                0.0              0.0
# mod 39                0.0                0.0              0.0
# mod 40                0.0                0.0              0.0
# mod 41                0.0                0.0              0.0
# mod 42                0.0                0.0              0.0
# mod 43                0.0                0.0              0.0
# mod 44                0.0                0.0              0.0
# mod 45                0.0                0.0              0.0
# mod 46                0.0                0.0              0.0
# mod 47                0.0                0.0              0.0
# mod 48                0.0                0.0              0.0
# mod 49                0.0                0.0              0.0
# mod 50                0.0                0.0              0.0
# mod 51                0.0                0.0              0.0
# mod 52                0.0                0.0              0.0
# mod 53                0.0                0.0              0.0
# mod 54                0.0                0.0              0.0
# mod 55                0.0                0.0              0.0
# mod 56                0.0                0.0              0.0
# mod 57                0.0                0.0              0.0
# mod 58                0.0                0.0              0.0
# mod 59                0.0                0.0              0.0
# mod 60                0.0                0.0              0.0
# mod 61                0.0                0.0              0.0
# mod 62                0.0                0.0              0.0
# mod 63                0.0                0.0              0.0
# mod 64                0.0                0.0              0.0
# mod 65                0.0                0.0              0.0
# mod 66                0.0                0.0              0.0
# mod 67                0.0                0.0              0.0
# mod 68                0.0                0.0              0.0
# mod 69                0.0                0.0              0.0
# mod 70                0.0                0.0              0.0
# mod 71                0.0                0.0              0.0
# mod 72                0.0                0.0              0.0
# mod 73                0.0                0.0              0.0
# mod 74                0.0                0.0              0.0
# mod 75                0.0                0.0              0.0
# mod 76                0.0                0.0              0.0
# mod 77                0.0                0.0              0.0
# mod 78                0.0                0.0              0.0
# mod 79                0.0                0.0              0.0
# mod 80                0.0                0.0              0.0
# mod 81                0.0                0.0              0.0
# mod 82                0.0                0.0              0.0
# mod 83                0.0                0.0              0.0
# mod 84                0.0                0.0              0.0
# mod 85                0.0                0.0              0.0
# mod 86                0.0                0.0              0.0
# mod 87                0.0                0.0              0.0
# mod 88                0.0                0.0              0.0
# mod 89                0.0                0.0              0.0
# mod 90                0.0                0.0              0.0
# mod 91                0.0                0.0              0.0
# mod 92                0.0                0.0              0.0
# mod 93                0.0                0.0              0.0
# mod 94                0.0                0.0              0.0
# mod 95                0.0                0.0              0.0
# mod 96                0.0                0.0              0.0
# mod 97                0.0                0.0              0.0
# mod 98                0.0                0.0              0.0
# mod 99                0.0                0.0              0.0
# mod 100               0.0                0.0              0.0
#
#          concave points error  symmetry error  fractal dimension error  \
# mod 1                     0.0             0.0                      0.0
# mod 2                     0.0             0.0                      0.0
# mod 3                     0.0             0.0                      0.0
# mod 4                     0.0             0.0                      0.0
# mod 5                     0.0             0.0                      0.0
# mod 6                     0.0             0.0                      0.0
# mod 7                     0.0             0.0                      0.0
# mod 8                     0.0             0.0                      0.0
# mod 9                     0.0             0.0                      0.0
# mod 10                    0.0             0.0                      0.0
# mod 11                    0.0             0.0                      0.0
# mod 12                    0.0             0.0                      0.0
# mod 13                    0.0             0.0                      0.0
# mod 14                    0.0             0.0                      0.0
# mod 15                    0.0             0.0                      0.0
# mod 16                    0.0             0.0                      0.0
# mod 17                    0.0             0.0                      0.0
# mod 18                    0.0             0.0                      0.0
# mod 19                    0.0             0.0                      0.0
# mod 20                    0.0             0.0                      0.0
# mod 21                    0.0             0.0                      0.0
# mod 22                    0.0             0.0                      0.0
# mod 23                    0.0             0.0                      0.0
# mod 24                    0.0             0.0                      0.0
# mod 25                    0.0             0.0                      0.0
# mod 26                    0.0             0.0                      0.0
# mod 27                    0.0             0.0                      0.0
# mod 28                    0.0             0.0                      0.0
# mod 29                    0.0             0.0                      0.0
# mod 30                    0.0             0.0                      0.0
# mod 31                    0.0             0.0                      0.0
# mod 32                    0.0             0.0                      0.0
# mod 33                    0.0             0.0                      0.0
# mod 34                    0.0             0.0                      0.0
# mod 35                    0.0             0.0                      0.0
# mod 36                    0.0             0.0                      0.0
# mod 37                    0.0             0.0                      0.0
# mod 38                    0.0             0.0                      0.0
# mod 39                    0.0             0.0                      0.0
# mod 40                    0.0             0.0                      0.0
# mod 41                    0.0             0.0                      0.0
# mod 42                    0.0             0.0                      0.0
# mod 43                    0.0             0.0                      0.0
# mod 44                    0.0             0.0                      0.0
# mod 45                    0.0             0.0                      0.0
# mod 46                    0.0             0.0                      0.0
# mod 47                    0.0             0.0                      0.0
# mod 48                    0.0             0.0                      0.0
# mod 49                    0.0             0.0                      0.0
# mod 50                    0.0             0.0                      0.0
# mod 51                    0.0             0.0                      0.0
# mod 52                    0.0             0.0                      0.0
# mod 53                    0.0             0.0                      0.0
# mod 54                    0.0             0.0                      0.0
# mod 55                    0.0             0.0                      0.0
# mod 56                    0.0             0.0                      0.0
# mod 57                    0.0             0.0                      0.0
# mod 58                    0.0             0.0                      0.0
# mod 59                    0.0             0.0                      0.0
# mod 60                    0.0             0.0                      0.0
# mod 61                    0.0             0.0                      0.0
# mod 62                    0.0             0.0                      0.0
# mod 63                    0.0             0.0                      0.0
# mod 64                    0.0             0.0                      0.0
# mod 65                    0.0             0.0                      0.0
# mod 66                    0.0             0.0                      0.0
# mod 67                    0.0             0.0                      0.0
# mod 68                    0.0             0.0                      0.0
# mod 69                    0.0             0.0                      0.0
# mod 70                    0.0             0.0                      0.0
# mod 71                    0.0             0.0                      0.0
# mod 72                    0.0             0.0                      0.0
# mod 73                    0.0             0.0                      0.0
# mod 74                    0.0             0.0                      0.0
# mod 75                    0.0             0.0                      0.0
# mod 76                    0.0             0.0                      0.0
# mod 77                    0.0             0.0                      0.0
# mod 78                    0.0             0.0                      0.0
# mod 79                    0.0             0.0                      0.0
# mod 80                    0.0             0.0                      0.0
# mod 81                    0.0             0.0                      0.0
# mod 82                    0.0             0.0                      0.0
# mod 83                    0.0             0.0                      0.0
# mod 84                    0.0             0.0                      0.0
# mod 85                    0.0             0.0                      0.0
# mod 86                    0.0             0.0                      0.0
# mod 87                    0.0             0.0                      0.0
# mod 88                    0.0             0.0                      0.0
# mod 89                    0.0             0.0                      0.0
# mod 90                    0.0             0.0                      0.0
# mod 91                    0.0             0.0                      0.0
# mod 92                    0.0             0.0                      0.0
# mod 93                    0.0             0.0                      0.0
# mod 94                    0.0             0.0                      0.0
# mod 95                    0.0             0.0                      0.0
# mod 96                    0.0             0.0                      0.0
# mod 97                    0.0             0.0                      0.0
# mod 98                    0.0             0.0                      0.0
# mod 99                    0.0             0.0                      0.0
# mod 100                   0.0             0.0                      0.0
#
#          worst radius  worst texture  worst perimeter  worst area  \
# mod 1       -1.439556      -0.512063         0.000000         0.0
# mod 2       -1.851195      -0.396974         0.000000         0.0
# mod 3       -1.408903      -0.369618         0.000000         0.0
# mod 4       -1.153691      -0.489706         0.000000         0.0
# mod 5       -1.896456      -0.336635         0.000000         0.0
# mod 6       -1.700784      -0.470013         0.000000         0.0
# mod 7       -1.819758      -0.558110         0.000000         0.0
# mod 8       -1.681860      -0.312884         0.000000         0.0
# mod 9       -1.533704      -0.551172         0.000000         0.0
# mod 10      -1.512711      -0.483282         0.000000         0.0
# mod 11      -1.297789      -0.431256         0.000000         0.0
# mod 12      -1.749490      -0.451351         0.000000         0.0
# mod 13      -1.585834      -0.367748         0.000000         0.0
# mod 14      -1.342935      -0.493702         0.000000         0.0
# mod 15      -1.611850      -0.588543         0.000000         0.0
# mod 16      -1.397352      -0.600616         0.000000         0.0
# mod 17      -1.692881      -0.488219         0.000000         0.0
# mod 18      -1.652665      -0.487445         0.000000         0.0
# mod 19      -1.531910      -0.567381         0.000000         0.0
# mod 20      -1.548043      -0.464700         0.000000         0.0
# mod 21      -1.432880      -0.520543         0.000000         0.0
# mod 22      -1.667109      -0.184888         0.000000         0.0
# mod 23      -1.770023      -0.396370         0.000000         0.0
# mod 24      -1.528470      -0.532908         0.000000         0.0
# mod 25      -1.574390      -0.415872         0.000000         0.0
# mod 26      -1.855529      -0.342368         0.000000         0.0
# mod 27      -1.665213      -0.481781         0.000000         0.0
# mod 28      -1.383962      -0.365541         0.000000         0.0
# mod 29      -1.428793      -0.492253         0.000000         0.0
# mod 30      -1.295013      -0.552114        -0.341662         0.0
# mod 31      -1.366029      -0.414892         0.000000         0.0
# mod 32      -1.562119      -0.409538         0.000000         0.0
# mod 33      -1.229737      -0.620958         0.000000         0.0
# mod 34      -1.413554      -0.372260         0.000000         0.0
# mod 35      -1.616289      -0.576977         0.000000         0.0
# mod 36      -1.626567      -0.530086         0.000000         0.0
# mod 37      -1.530976      -0.564814         0.000000         0.0
# mod 38      -1.729501      -0.414814         0.000000         0.0
# mod 39      -0.960345      -0.394077        -0.616578         0.0
# mod 40      -1.672200      -0.483404         0.000000         0.0
# mod 41      -1.679790      -0.458502         0.000000         0.0
# mod 42      -1.279958      -0.489729         0.000000         0.0
# mod 43      -1.481399      -0.566604        -0.238871         0.0
# mod 44      -1.455727      -0.450746         0.000000         0.0
# mod 45      -1.668538      -0.479184         0.000000         0.0
# mod 46      -1.636038      -0.512167         0.000000         0.0
# mod 47      -1.811994      -0.510839         0.000000         0.0
# mod 48      -1.543525      -0.525534         0.000000         0.0
# mod 49      -1.446963      -0.351016         0.000000         0.0
# mod 50      -1.573150      -0.559325         0.000000         0.0
# mod 51      -1.577698      -0.465272         0.000000         0.0
# mod 52      -1.657063      -0.575972         0.000000         0.0
# mod 53      -1.696849      -0.561330         0.000000         0.0
# mod 54      -1.555475      -0.552123         0.000000         0.0
# mod 55      -1.635081      -0.392004         0.000000         0.0
# mod 56      -1.449371      -0.516231         0.000000         0.0
# mod 57      -1.758138      -0.494658         0.000000         0.0
# mod 58      -1.658217      -0.460923         0.000000         0.0
# mod 59      -1.740968      -0.461741         0.000000         0.0
# mod 60      -1.355439      -0.246651        -0.139956         0.0
# mod 61      -1.564970      -0.398362         0.000000         0.0
# mod 62      -1.569350      -0.451903         0.000000         0.0
# mod 63      -1.492254      -0.419713         0.000000         0.0
# mod 64      -1.442577      -0.452843         0.000000         0.0
# mod 65      -0.726757      -0.391047        -0.684744         0.0
# mod 66      -1.540625      -0.447290         0.000000         0.0
# mod 67      -1.859825      -0.376499         0.000000         0.0
# mod 68      -1.523023      -0.520881         0.000000         0.0
# mod 69      -1.376680      -0.551060        -0.039239         0.0
# mod 70      -1.611961      -0.335344         0.000000         0.0
# mod 71      -1.670792      -0.391901         0.000000         0.0
# mod 72      -1.865494      -0.462054         0.000000         0.0
# mod 73      -1.406490      -0.462050         0.000000         0.0
# mod 74      -1.815389      -0.505543        -0.049993         0.0
# mod 75      -1.468510      -0.545912         0.000000         0.0
# mod 76      -1.549757      -0.111729         0.000000         0.0
# mod 77      -1.454785      -0.579766         0.000000         0.0
# mod 78      -1.617290      -0.559956         0.000000         0.0
# mod 79      -1.279828      -0.420345         0.000000         0.0
# mod 80      -1.147981      -0.443361         0.000000         0.0
# mod 81      -1.729380      -0.400457         0.000000         0.0
# mod 82      -1.585951      -0.481204         0.000000         0.0
# mod 83      -0.856288      -0.550659        -0.748372         0.0
# mod 84      -1.525540      -0.408419        -0.110107         0.0
# mod 85      -1.520245      -0.453034         0.000000         0.0
# mod 86      -1.576044      -0.185514         0.000000         0.0
# mod 87      -0.864384      -0.426423        -0.845379         0.0
# mod 88      -1.737882      -0.395559         0.000000         0.0
# mod 89      -1.664906      -0.456179         0.000000         0.0
# mod 90      -1.850939      -0.427583         0.000000         0.0
# mod 91      -1.633467      -0.577575         0.000000         0.0
# mod 92      -1.900831      -0.461938         0.000000         0.0
# mod 93      -1.608495      -0.589913         0.000000         0.0
# mod 94      -1.460843      -0.613838         0.000000         0.0
# mod 95      -1.397967      -0.180235        -0.061697         0.0
# mod 96      -1.525419      -0.515901         0.000000         0.0
# mod 97      -1.540420      -0.477363         0.000000         0.0
# mod 98      -1.285502      -0.494701         0.000000         0.0
# mod 99      -1.675367      -0.488952         0.000000         0.0
# mod 100     -1.861411      -0.178953         0.000000         0.0
#
#          worst smoothness  worst compactness  worst concavity  \
# mod 1            0.000000                0.0         0.000000
# mod 2            0.000000                0.0         0.000000
# mod 3           -0.017518                0.0         0.000000
# mod 4           -0.075493                0.0         0.000000
# mod 5            0.000000                0.0         0.000000
# mod 6            0.000000                0.0         0.000000
# mod 7           -0.143246                0.0         0.000000
# mod 8            0.000000                0.0         0.000000
# mod 9            0.000000                0.0         0.000000
# mod 10           0.000000                0.0         0.000000
# mod 11           0.000000                0.0         0.000000
# mod 12          -0.023309                0.0        -0.014810
# mod 13           0.000000                0.0         0.000000
# mod 14          -0.018743                0.0         0.000000
# mod 15          -0.058139                0.0         0.000000
# mod 16           0.000000                0.0         0.000000
# mod 17          -0.064158                0.0         0.000000
# mod 18           0.000000                0.0         0.000000
# mod 19           0.000000                0.0         0.000000
# mod 20           0.000000                0.0         0.000000
# mod 21           0.000000                0.0         0.000000
# mod 22           0.000000                0.0         0.000000
# mod 23          -0.003307                0.0        -0.074377
# mod 24          -0.073883                0.0         0.000000
# mod 25           0.000000                0.0         0.000000
# mod 26           0.000000                0.0         0.000000
# mod 27          -0.073185                0.0         0.000000
# mod 28           0.000000                0.0         0.000000
# mod 29           0.000000                0.0         0.000000
# mod 30          -0.170024                0.0         0.000000
# mod 31          -0.096035                0.0         0.000000
# mod 32           0.000000                0.0         0.000000
# mod 33          -0.007488                0.0         0.000000
# mod 34           0.000000                0.0         0.000000
# mod 35          -0.071898                0.0         0.000000
# mod 36           0.000000                0.0         0.000000
# mod 37           0.000000                0.0         0.000000
# mod 38          -0.031691                0.0         0.000000
# mod 39          -0.003393                0.0         0.000000
# mod 40           0.000000                0.0         0.000000
# mod 41           0.000000                0.0         0.000000
# mod 42          -0.030324                0.0         0.000000
# mod 43          -0.223894                0.0         0.000000
# mod 44           0.000000                0.0         0.000000
# mod 45           0.000000                0.0         0.000000
# mod 46          -0.008153                0.0         0.000000
# mod 47           0.000000                0.0         0.000000
# mod 48           0.000000                0.0         0.000000
# mod 49           0.000000                0.0         0.000000
# mod 50          -0.004695                0.0         0.000000
# mod 51           0.000000                0.0         0.000000
# mod 52           0.000000                0.0         0.000000
# mod 53          -0.037183                0.0         0.000000
# mod 54           0.000000                0.0        -0.026938
# mod 55          -0.081382                0.0         0.000000
# mod 56          -0.016477                0.0         0.000000
# mod 57          -0.077763                0.0         0.000000
# mod 58          -0.012479                0.0         0.000000
# mod 59          -0.044213                0.0         0.000000
# mod 60          -0.017037                0.0         0.000000
# mod 61           0.000000                0.0         0.000000
# mod 62           0.000000                0.0         0.000000
# mod 63          -0.002220                0.0         0.000000
# mod 64           0.000000                0.0         0.000000
# mod 65          -0.027090                0.0         0.000000
# mod 66          -0.004521                0.0         0.000000
# mod 67           0.000000                0.0         0.000000
# mod 68           0.000000                0.0        -0.032192
# mod 69           0.000000                0.0        -0.123249
# mod 70          -0.026020                0.0         0.000000
# mod 71          -0.015334                0.0         0.000000
# mod 72          -0.013589                0.0         0.000000
# mod 73           0.000000                0.0         0.000000
# mod 74          -0.117148                0.0        -0.037479
# mod 75           0.000000                0.0         0.000000
# mod 76           0.000000                0.0         0.000000
# mod 77          -0.000222                0.0         0.000000
# mod 78           0.000000                0.0        -0.155312
# mod 79          -0.012040                0.0         0.000000
# mod 80           0.000000                0.0         0.000000
# mod 81           0.000000                0.0        -0.150307
# mod 82           0.000000                0.0         0.000000
# mod 83           0.000000                0.0         0.000000
# mod 84           0.000000                0.0         0.000000
# mod 85           0.000000                0.0         0.000000
# mod 86           0.000000                0.0         0.000000
# mod 87           0.000000                0.0        -0.043433
# mod 88           0.000000                0.0        -0.072727
# mod 89          -0.026155                0.0         0.000000
# mod 90          -0.218413                0.0         0.000000
# mod 91           0.000000                0.0        -0.050178
# mod 92          -0.076336                0.0         0.000000
# mod 93           0.000000                0.0         0.000000
# mod 94           0.000000                0.0         0.000000
# mod 95           0.000000                0.0         0.000000
# mod 96          -0.009313                0.0         0.000000
# mod 97           0.000000                0.0         0.000000
# mod 98          -0.089061                0.0         0.000000
# mod 99          -0.048165                0.0         0.000000
# mod 100          0.000000                0.0         0.000000
#
#          worst concave points  worst symmetry  worst fractal dimension
# mod 1               -1.076206       -0.063620                      0.0
# mod 2               -1.285876       -0.161960                      0.0
# mod 3               -1.378683       -0.179618                      0.0
# mod 4               -1.469476       -0.032476                      0.0
# mod 5               -1.152931       -0.074065                      0.0
# mod 6               -1.211245       -0.163493                      0.0
# mod 7               -1.414674       -0.073108                      0.0
# mod 8               -1.430337       -0.036164                      0.0
# mod 9               -1.311070       -0.124066                      0.0
# mod 10              -0.932992       -0.114233                      0.0
# mod 11              -1.654182       -0.018833                      0.0
# mod 12              -1.302237       -0.091684                      0.0
# mod 13              -1.381438       -0.115341                      0.0
# mod 14              -1.449691       -0.115164                      0.0
# mod 15              -1.285680       -0.157989                      0.0
# mod 16              -1.039248       -0.082885                      0.0
# mod 17              -1.158739       -0.085185                      0.0
# mod 18              -1.196281       -0.108700                      0.0
# mod 19              -0.989380       -0.182704                      0.0
# mod 20              -1.460300       -0.043027                      0.0
# mod 21              -1.292479       -0.119071                      0.0
# mod 22              -1.186761       -0.138441                      0.0
# mod 23              -1.260073       -0.060197                      0.0
# mod 24              -0.857647       -0.118315                      0.0
# mod 25              -1.174811       -0.088334                      0.0
# mod 26              -1.154887       -0.076291                      0.0
# mod 27              -1.049141       -0.116391                      0.0
# mod 28              -1.261161       -0.160109                      0.0
# mod 29              -1.343042       -0.008115                      0.0
# mod 30              -0.902137       -0.204523                      0.0
# mod 31              -1.385418       -0.007261                      0.0
# mod 32              -1.308103       -0.102627                      0.0
# mod 33              -1.176532       -0.254390                      0.0
# mod 34              -1.078678       -0.071671                      0.0
# mod 35              -0.832612       -0.201521                      0.0
# mod 36              -1.078050       -0.102730                      0.0
# mod 37              -0.848702       -0.183759                      0.0
# mod 38              -1.230577       -0.110328                      0.0
# mod 39              -1.516774       -0.094400                      0.0
# mod 40              -1.009978       -0.204297                      0.0
# mod 41              -1.121726       -0.173480                      0.0
# mod 42              -1.095136       -0.023248                      0.0
# mod 43              -1.129604       -0.101774                      0.0
# mod 44              -1.644898        0.000000                      0.0
# mod 45              -1.466218       -0.015012                      0.0
# mod 46              -0.869080       -0.114550                      0.0
# mod 47              -1.062012       -0.141826                      0.0
# mod 48              -1.088970       -0.156134                      0.0
# mod 49              -1.508936       -0.024503                      0.0
# mod 50              -0.888158       -0.100047                      0.0
# mod 51              -1.095276       -0.152684                      0.0
# mod 52              -1.200414       -0.014795                      0.0
# mod 53              -1.077394       -0.055575                      0.0
# mod 54              -0.924602       -0.126991                      0.0
# mod 55              -1.284664       -0.040130                      0.0
# mod 56              -1.008962       -0.110274                      0.0
# mod 57              -0.962656       -0.121460                      0.0
# mod 58              -1.165332       -0.231936                      0.0
# mod 59              -1.701859        0.000000                      0.0
# mod 60              -1.270666       -0.198069                      0.0
# mod 61              -1.371727       -0.191100                      0.0
# mod 62              -1.515908       -0.004491                      0.0
# mod 63              -1.302777       -0.085877                      0.0
# mod 64              -1.535814       -0.071163                      0.0
# mod 65              -1.031266       -0.107223                      0.0
# mod 66              -1.109043       -0.147215                      0.0
# mod 67              -1.094790       -0.194224                      0.0
# mod 68              -1.183359       -0.077284                      0.0
# mod 69              -1.122022       -0.122411                      0.0
# mod 70              -1.377350        0.000000                      0.0
# mod 71              -1.410302       -0.182547                      0.0
# mod 72              -1.271598       -0.138033                      0.0
# mod 73              -1.130551       -0.083309                      0.0
# mod 74              -0.981851       -0.189025                      0.0
# mod 75              -1.087685       -0.157040                      0.0
# mod 76              -1.314973       -0.158870                      0.0
# mod 77              -1.288810       -0.032720                      0.0
# mod 78              -0.390091       -0.195598                      0.0
# mod 79              -1.159744       -0.044966                      0.0
# mod 80              -1.805896        0.000000                      0.0
# mod 81              -0.795791       -0.168606                      0.0
# mod 82              -1.057492       -0.177386                      0.0
# mod 83              -1.108522       -0.222505                      0.0
# mod 84              -1.363370       -0.144412                      0.0
# mod 85              -1.078943       -0.101183                      0.0
# mod 86              -1.398874       -0.140582                      0.0
# mod 87              -0.933468       -0.178880                      0.0
# mod 88              -1.292153       -0.094130                      0.0
# mod 89              -1.209604       -0.104986                      0.0
# mod 90              -1.039077       -0.018351                      0.0
# mod 91              -1.273719       -0.170756                      0.0
# mod 92              -1.414909       -0.138315                      0.0
# mod 93              -1.334986       -0.099711                      0.0
# mod 94              -0.930291       -0.144178                      0.0
# mod 95              -1.563532       -0.127300                      0.0
# mod 96              -1.250561       -0.349597                      0.0
# mod 97              -1.518342       -0.213028                      0.0
# mod 98              -1.277950       -0.063410                      0.0
# mod 99              -1.362264       -0.138430                      0.0
# mod 100             -1.540551       -0.258380                      0.0

# %% [markdown]
# We assign this array to a variable and plot weight distributions of specific feautures using histograms

# %%
weight_dist = analysis.get_weight_distributions()

# %% [markdown]
# Plot the weight distribution of feature at index 27, that is `worst concave points`. This feature is selected very often as we can see that most of the weights are different from zero and negative.

# %%
import seaborn as sns
ax = sns.distplot(weight_dist.values[:, 27], kde=False)

# %% [markdown]
# All of the weights of feature at index 23 (`worst area`) are zero, meaning that this feature is not important for the model.

# %%
ax = sns.distplot(weight_dist.values[:, 23], kde=False)

# %% [markdown]
# With help of ``lineplot()`` we get detailed insight into ``scores`` and ``% of zero weight`` over the ``K`` model. For each of the ``K`` (100) models, we get the exact values on the second axis.

# %%
analysis.lineplot()

# %% [markdown]
# ### Investigation of class predictions

# %% [markdown]
# Since we use an ensemble of models, we can predict the class of the validations samples during the RENT process. We can get more details by calling `.summery_objects()` which will return a data frame holding all predictions.
#
# In the example below we can see that patient 489 was 25 times (out of K=100 models in the ensemble) in the validation set (column `# test`). That means we get 25 predictions from 25 unique models and investigate how well predictions worked for this patient. Patient 489 belongs to class 0 (column `class`) and was predictied incorrectly 25 times (column `# incorrect`) out of 25 predictions, which results in 100% incorrect classifications (column `% incorrect`).
#
# Looking at this dataframe we can see that most of the patients were predicted correctly every time, however, there are some patients that were predicted incorrectly every time (patients 38, 135, 81, 255, 297, 73, 40, 13, 86, 41). It might be worth investigating why it is so difficult predict the correct class for these patients by comparing them to patients from the same class that are predicted correctly most or all of the times. We will do this using PCA further below in this notebook.

# %%
analysis.summary_objects()
# Out:
#      # test  class  # incorrect  % incorrect
# 293      27      1            0     0.000000
# 332      23      1            0     0.000000
# 565      20      0            0     0.000000
# 278      22      1            0     0.000000
# 489      25      0           25   100.000000
# 346      25      1            0     0.000000
# 357      30      1            0     0.000000
# 355      28      1            0     0.000000
# 112      24      1            3    12.500000
# 68       26      1            0     0.000000
# 526      15      1            0     0.000000
# 206      22      1            0     0.000000
# 65       22      0            0     0.000000
# 437      17      1            0     0.000000
# 126      24      0            1     4.166667
# 429      29      1            0     0.000000
# 392      23      0            0     0.000000
# 343      22      0            0     0.000000
# 334      13      1            0     0.000000
# 440      25      1            0     0.000000
# 441      26      0            0     0.000000
# 137      23      1            0     0.000000
# 230      25      0            0     0.000000
# 7        29      0            0     0.000000
# 408      24      0            0     0.000000
# 523      19      1            0     0.000000
# 361      27      1            0     0.000000
# 553      20      1            0     0.000000
# 478      23      1            0     0.000000
# 303      35      1            0     0.000000
# 155      15      1            0     0.000000
# 186      23      0            0     0.000000
# 101      28      1            0     0.000000
# 97       37      1            0     0.000000
# 20       15      1            0     0.000000
# 153      31      1            0     0.000000
# 54       20      0            0     0.000000
# 30       33      0            0     0.000000
# 531      24      1            0     0.000000
# 49       20      1            0     0.000000
# 100      21      0            1     4.761905
# 336      26      1            0     0.000000
# 299      35      1            0     0.000000
# 347      21      1            0     0.000000
# 502      24      1            0     0.000000
# 56       23      0            0     0.000000
# 144      36      1            0     0.000000
# 60       27      1            0     0.000000
# 6        29      0            0     0.000000
# 8        33      0            0     0.000000
# 474      26      1            0     0.000000
# 320      31      1            0     0.000000
# 252      23      0            0     0.000000
# 202      27      0            0     0.000000
# 246      36      1            0     0.000000
# 240      22      1            0     0.000000
# 38       33      0           33   100.000000
# 436      22      1            0     0.000000
# 390      29      1            0     0.000000
# 261      22      0           15    68.181818
# 339      22      0            0     0.000000
# 282      30      0            0     0.000000
# 276      27      1            0     0.000000
# 367      18      1            0     0.000000
# 505      25      1            0     0.000000
# 499      24      0            0     0.000000
# 124      26      1            0     0.000000
# 154      30      1            0     0.000000
# 316      21      1            0     0.000000
# 59       23      1            0     0.000000
# 333      21      1            0     0.000000
# 503      19      0            0     0.000000
# 534      32      1            0     0.000000
# 563      27      0            0     0.000000
# 453      26      1            0     0.000000
# 262      21      0            0     0.000000
# 378      24      1            0     0.000000
# 229      25      0            0     0.000000
# 55       31      1            0     0.000000
# 171      25      0            8    32.000000
# 454      16      1            0     0.000000
# 243      19      1            0     0.000000
# 158      29      1            0     0.000000
# 415      31      1            0     0.000000
# 34       25      0            0     0.000000
# 561      23      1            0     0.000000
# 18       24      0            0     0.000000
# 508      16      1            0     0.000000
# 322      27      1            0     0.000000
# 51       20      1            0     0.000000
# 219      32      0            0     0.000000
# 549      26      1            0     0.000000
# 52       25      1            0     0.000000
# 74       13      1            0     0.000000
# 26       25      0            0     0.000000
# 173      22      1            0     0.000000
# 92       30      1            0     0.000000
# 167      20      0            0     0.000000
# 4        26      0            0     0.000000
# 409      28      1            0     0.000000
# 181      27      0            0     0.000000
# 245      22      1            0     0.000000
# 379      23      0            0     0.000000
# 425      30      1            0     0.000000
# 479      27      0            0     0.000000
# 5        22      0            0     0.000000
# 141      26      0            0     0.000000
# 329      29      0           23    79.310345
# 200      24      1            0     0.000000
# 135      24      0           24   100.000000
# 285      24      1            0     0.000000
# 122      20      0            0     0.000000
# 484      15      1            0     0.000000
# 22       25      0            0     0.000000
# 220      24      1            0     0.000000
# 517      27      0            0     0.000000
# 120      27      1            0     0.000000
# 81       27      1           27   100.000000
# 487      21      0            0     0.000000
# 464      17      1            0     0.000000
# 554      26      1            0     0.000000
# 548      27      1            0     0.000000
# 160      30      1            0     0.000000
# 557      26      1            0     0.000000
# 238      28      1            0     0.000000
# 284      30      1            0     0.000000
# 315      25      1            0     0.000000
# 195      27      1            0     0.000000
# 191      26      1            0     0.000000
# 116      29      1            0     0.000000
# 477      25      1            0     0.000000
# 428      30      1            0     0.000000
# 164      21      0            0     0.000000
# 106      25      1            0     0.000000
# 403      21      1            0     0.000000
# 63       27      1            0     0.000000
# 105      18      0            0     0.000000
# 312      22      1            0     0.000000
# 555      23      1            0     0.000000
# 481      30      1            0     0.000000
# 344      31      1            0     0.000000
# 93       38      1            0     0.000000
# 395      24      1            0     0.000000
# 393      24      0            0     0.000000
# 381      28      1            0     0.000000
# 198      24      0            0     0.000000
# 145      31      1            0     0.000000
# 150      24      1            0     0.000000
# 39       28      0            0     0.000000
# 520      25      1            0     0.000000
# 351      24      0            0     0.000000
# 253      26      0            0     0.000000
# 467      26      1            0     0.000000
# 501      25      0            0     0.000000
# 2        25      0            0     0.000000
# 221      20      1            0     0.000000
# 532      15      1            0     0.000000
# 146      23      0            3    13.043478
# 289      19      1            0     0.000000
# 241      25      1            0     0.000000
# 342      14      1            0     0.000000
# 433      23      0            0     0.000000
# 114      32      1            0     0.000000
# 311      21      1            0     0.000000
# 399      21      1            0     0.000000
# 176      27      1            0     0.000000
# 491      27      1            0     0.000000
# 168      32      0            0     0.000000
# 365      33      0            0     0.000000
# 539      22      1            0     0.000000
# 506      29      1            0     0.000000
# 426      23      1            0     0.000000
# 136      31      1            0     0.000000
# 444      24      0            0     0.000000
# 254      31      0            0     0.000000
# 362      26      1            0     0.000000
# 386      29      1            0     0.000000
# 494      30      1            0     0.000000
# 452      27      1            0     0.000000
# 255      25      0           25   100.000000
# 232      24      1            0     0.000000
# 133      18      1            0     0.000000
# 33       26      0            0     0.000000
# 88       28      1            0     0.000000
# 290      23      1            0     0.000000
# 44       26      0            0     0.000000
# 61       25      1            0     0.000000
# 199      25      0            0     0.000000
# 375      26      1            0     0.000000
# 545      13      1            0     0.000000
# 530      26      1            0     0.000000
# 424      23      1            0     0.000000
# 218      27      0            0     0.000000
# 302      26      0            0     0.000000
# 297      28      0           28   100.000000
# 73       28      0           28   100.000000
# 295      29      1            0     0.000000
# 35       22      0            0     0.000000
# 493      30      1            0     0.000000
# 29       21      0            0     0.000000
# 460      24      0            0     0.000000
# 438      25      1            0     0.000000
# 445      23      1            0     0.000000
# 309      29      1            0     0.000000
# 541      23      1            0     0.000000
# 217      30      1            0     0.000000
# 27       23      0            0     0.000000
# 462      25      1            0     0.000000
# 376      15      1            0     0.000000
# 156      20      0            0     0.000000
# 552      21      1            0     0.000000
# 475      23      1            0     0.000000
# 138      27      0            0     0.000000
# 212      31      0            0     0.000000
# 104      23      1            0     0.000000
# 447      25      1            0     0.000000
# 443      32      1            0     0.000000
# 449      23      0            0     0.000000
# 215      21      0            1     4.761905
# 496      19      1            0     0.000000
# 189      23      1            0     0.000000
# 214      22      0            0     0.000000
# 524      25      1            0     0.000000
# 204      28      1            0     0.000000
# 234      19      1            0     0.000000
# 259      33      0            0     0.000000
# 67       30      1            0     0.000000
# 24       26      0            0     0.000000
# 216      15      1            0     0.000000
# 300      27      0            0     0.000000
# 223      23      0            0     0.000000
# 129      26      0            0     0.000000
# 533      29      0            0     0.000000
# 111      24      1            0     0.000000
# 166      30      1            0     0.000000
# 267      20      1            0     0.000000
# 507      25      1            0     0.000000
# 40       29      0           29   100.000000
# 274      21      0            0     0.000000
# 455      25      1            0     0.000000
# 79       26      1            0     0.000000
# 402      35      1            0     0.000000
# 404      26      1            0     0.000000
# 327      35      1            0     0.000000
# 13       28      0           28   100.000000
# 287      22      1            0     0.000000
# 326      21      1            0     0.000000
# 121      21      0            0     0.000000
# 251      21      1            0     0.000000
# 228      20      1            0     0.000000
# 498      26      0            0     0.000000
# 161      23      0            0     0.000000
# 83       25      0            0     0.000000
# 117      24      0            0     0.000000
# 374      38      1            0     0.000000
# 407      26      1            0     0.000000
# 25       28      0            0     0.000000
# 110      20      1            0     0.000000
# 149      36      1            0     0.000000
# 152      31      1            0     0.000000
# 16       27      0            0     0.000000
# 435      21      0            0     0.000000
# 331      18      1            0     0.000000
# 109      16      1            0     0.000000
# 470      20      1            0     0.000000
# 450      31      1            0     0.000000
# 139      17      1            0     0.000000
# 237      22      0            0     0.000000
# 260      24      0            0     0.000000
# 352      24      0            0     0.000000
# 456      23      1            0     0.000000
# 317      27      0            0     0.000000
# 323      16      0            0     0.000000
# 513      24      1            0     0.000000
# 248      29      1            0     0.000000
# 410      24      1            0     0.000000
# 422      26      1            0     0.000000
# 497      29      1            0     0.000000
# 19       21      1            0     0.000000
# 328      25      0            0     0.000000
# 296      20      1            0     0.000000
# 483      28      1            0     0.000000
# 269      20      1            0     0.000000
# 363      24      1            0     0.000000
# 226      30      1            0     0.000000
# 495      26      1            0     0.000000
# 3        24      0            0     0.000000
# 446      19      0            0     0.000000
# 125      24      1            0     0.000000
# 280      35      0            0     0.000000
# 286      28      1            0     0.000000
# 77       29      0            0     0.000000
# 184      22      0           20    90.909091
# 371      25      1            0     0.000000
# 485      25      1            0     0.000000
# 556      21      1            0     0.000000
# 275      28      1            0     0.000000
# 294      26      1            0     0.000000
# 535      26      0            0     0.000000
# 182      21      0            0     0.000000
# 32       26      0            0     0.000000
# 80       26      1            0     0.000000
# 307      25      1            0     0.000000
# 258      34      0            0     0.000000
# 11       26      0            0     0.000000
# 360      20      1            0     0.000000
# 476      32      1            0     0.000000
# 86       14      0           14   100.000000
# 266      24      1            0     0.000000
# 36       24      0            0     0.000000
# 193      33      0            0     0.000000
# 58       33      1            0     0.000000
# 41       22      0           22   100.000000
# 270      19      1            0     0.000000
# 411      22      1            0     0.000000
# 50       27      1            0     0.000000
# 209      25      1            0     0.000000
# 511      29      1            0     0.000000
# 540      25      1            0     0.000000
# 522      20      1            0     0.000000
# 521      27      0            0     0.000000
# 451      25      0            0     0.000000
# 123      21      1            0     0.000000
# 222      33      1            0     0.000000
# 419      28      1            0     0.000000
# 62       32      0            0     0.000000
# 568      29      1            0     0.000000
# 377      29      1            0     0.000000
# 130      19      1            0     0.000000
# 187      30      1            0     0.000000
# 23       21      0            0     0.000000
# 480      21      1            0     0.000000
# 509      28      0            0     0.000000
# 43       25      0            0     0.000000
# 370      22      0            0     0.000000
# 394      31      1            0     0.000000
# 0        29      0            0     0.000000
# 383      32      1            0     0.000000
# 201      25      0            0     0.000000
# 405      26      1            0     0.000000
# 368      28      0            0     0.000000
# 461      19      0            0     0.000000
# 529      18      1            0     0.000000
# 98       27      1            0     0.000000
# 387      31      1            0     0.000000
# 349      33      1            0     0.000000
# 304      26      1            0     0.000000
# 418      22      1            0     0.000000
# 292      23      1            0     0.000000
# 178      20      1            0     0.000000
# 369      19      0            0     0.000000
# 256      26      0            0     0.000000
# 94       28      0            0     0.000000
# 197      24      0           13    54.166667
# 95       27      0            0     0.000000
# 558      26      1            0     0.000000
# 163      29      1            0     0.000000
# 169      20      1            0     0.000000
# 69       25      1            0     0.000000
# 305      24      1            0     0.000000
# 48       19      1            0     0.000000
# 341      28      1            0     0.000000
# 373      25      0            0     0.000000
# 397      23      1            0     0.000000
# 207      27      0            0     0.000000
# 279      25      1            0     0.000000
# 528      19      1            0     0.000000
# 227      24      1            0     0.000000
# 148      28      1            0     0.000000
# 143      20      1            0     0.000000
# 180      17      0            0     0.000000
# 131      22      0            0     0.000000
# 47       28      0            0     0.000000
# 324      16      1            0     0.000000
# 203      25      0            0     0.000000
# 84       24      1            0     0.000000
# 398      26      1            0     0.000000
# 91       31      0           10    32.258065
# 82       38      0            0     0.000000
# 430      28      0            0     0.000000
# 119      14      0            0     0.000000
# 291      27      1            4    14.814815
# 57       26      0            0     0.000000
# 321      27      0            0     0.000000
# 257      20      0            0     0.000000
# 442      27      1            0     0.000000
# 42       23      0            0     0.000000
# 388      33      1            0     0.000000
# 335      25      0            0     0.000000
# 273      16      1            0     0.000000
# 488      27      1            0     0.000000
# 53       26      0            0     0.000000
# 536      27      0           21    77.777778
# 128      20      1            0     0.000000
# 28       25      0            0     0.000000
# 183      22      1            0     0.000000
# 459      22      1            0     0.000000
# 510      26      1            0     0.000000
# 151      23      1            0     0.000000
# 244      32      0            0     0.000000
# 543      25      1            0     0.000000
# 544      27      1            0     0.000000
# 265      30      0            0     0.000000
# 288      21      1            0     0.000000
# 423      31      1            0     0.000000
# 147      24      1            0     0.000000
# 177      26      0            0     0.000000
# 99       24      0            0     0.000000
# 448      32      1            0     0.000000
# 431      26      1            0     0.000000
# 115      33      1            0     0.000000
# 72       28      0            0     0.000000
# 537      30      1            0     0.000000
# 174      26      1            0     0.000000
# 87       24      0            0     0.000000
# 551      27      1            0     0.000000
# 486      28      1            0     0.000000
# 314      21      1            0     0.000000
# 396      28      1            0     0.000000
# 472      24      1            0     0.000000
# 70       30      0            0     0.000000
# 277      20      0            0     0.000000
# 9        28      0            0     0.000000
# 359      36      1            0     0.000000
# 192      26      1            0     0.000000
# 559      29      1            0     0.000000

# %% [markdown]
# We can also extract the class probabilities for each prediction by calling `.get_object_probabilities`.

# %%
analysis.get_object_probabilities()
# Out:
#         mod 1     mod 2     mod 3     mod 4     mod 5     mod 6     mod 7  \
# 293       NaN       NaN  0.914975       NaN       NaN       NaN       NaN
# 332       NaN  0.987358       NaN       NaN       NaN       NaN  0.988529
# 565       NaN  0.019152  0.020195       NaN  0.012036       NaN  0.016486
# 278       NaN       NaN       NaN  0.948529  0.925322       NaN       NaN
# 489  0.641793       NaN       NaN  0.752553       NaN       NaN  0.586219
# 346       NaN  0.959475       NaN       NaN  0.957550       NaN       NaN
# 357       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 355       NaN       NaN       NaN       NaN       NaN  0.931977  0.949959
# 112       NaN       NaN       NaN       NaN       NaN  0.649818       NaN
# 68        NaN       NaN  0.734611       NaN       NaN       NaN  0.859171
# 526  0.714970       NaN       NaN       NaN       NaN       NaN  0.608335
# 206       NaN       NaN       NaN  0.984261       NaN  0.986854  0.989169
# 65        NaN  0.199845  0.183921       NaN       NaN       NaN       NaN
# 437       NaN       NaN       NaN       NaN       NaN       NaN  0.922587
# 126  0.433693       NaN       NaN       NaN       NaN       NaN       NaN
# 429       NaN       NaN  0.978977  0.981063  0.976430       NaN       NaN
# 392       NaN       NaN       NaN       NaN       NaN  0.026472  0.022591
# 343       NaN  0.006580       NaN  0.009018  0.007393       NaN       NaN
# 334       NaN       NaN  0.970440  0.973251       NaN       NaN       NaN
# 440       NaN       NaN  0.763110       NaN  0.846921       NaN  0.794728
# 441       NaN       NaN       NaN       NaN       NaN       NaN  0.053117
# 137       NaN       NaN       NaN  0.963684       NaN  0.967900       NaN
# 230  0.033070  0.027818  0.027019       NaN       NaN  0.046586       NaN
# 7    0.338907  0.351772       NaN  0.257428       NaN       NaN       NaN
# 408       NaN       NaN       NaN       NaN  0.053180       NaN       NaN
# 523       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 361       NaN       NaN       NaN  0.939883  0.923514       NaN       NaN
# 553       NaN       NaN  0.992658       NaN       NaN       NaN       NaN
# 478       NaN       NaN       NaN  0.968560  0.973020  0.971344       NaN
# 303       NaN  0.983585       NaN       NaN       NaN  0.983000       NaN
# 155  0.930960  0.926915       NaN  0.936636       NaN       NaN       NaN
# 186       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 101  0.998504       NaN  0.998227       NaN       NaN       NaN       NaN
# 97        NaN       NaN       NaN       NaN       NaN  0.989512       NaN
# 20        NaN  0.932246       NaN       NaN       NaN       NaN       NaN
# 153  0.987773       NaN       NaN       NaN  0.988926       NaN       NaN
# 54        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 30        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 531       NaN       NaN       NaN  0.917427  0.918916       NaN       NaN
# 49        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 100       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 336       NaN       NaN       NaN       NaN  0.976306       NaN  0.983091
# 299  0.988371  0.991936       NaN       NaN       NaN       NaN       NaN
# 347       NaN  0.678350  0.674227  0.763023  0.712870       NaN       NaN
# 502       NaN  0.935888       NaN       NaN       NaN       NaN       NaN
# 56        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 144  0.989739  0.990646       NaN       NaN  0.990654       NaN  0.993135
# 60   0.992745       NaN  0.988999       NaN  0.994209       NaN       NaN
# 6         NaN       NaN       NaN  0.052046       NaN  0.032361       NaN
# 8         NaN       NaN       NaN       NaN       NaN       NaN  0.139451
# 474  0.978913       NaN       NaN       NaN       NaN  0.980434       NaN
# 320       NaN  0.967673  0.949727       NaN       NaN       NaN  0.972004
# 252       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 202       NaN  0.001082       NaN       NaN       NaN       NaN       NaN
# 246  0.955670  0.954334  0.957217       NaN  0.954404       NaN  0.959578
# 240       NaN  0.911032       NaN       NaN       NaN  0.921013       NaN
# 38        NaN  0.967583       NaN       NaN       NaN       NaN  0.974754
# 436       NaN       NaN       NaN  0.934401       NaN       NaN       NaN
# 390       NaN       NaN       NaN  0.987336       NaN       NaN       NaN
# 261  0.525390       NaN  0.551965       NaN       NaN       NaN       NaN
# 339  0.000730       NaN  0.000943       NaN  0.000485       NaN       NaN
# 282  0.012441       NaN       NaN       NaN       NaN  0.010792       NaN
# 276       NaN       NaN  0.992893  0.994199       NaN       NaN       NaN
# 367  0.917601  0.903301       NaN       NaN  0.909534       NaN       NaN
# 505       NaN       NaN  0.945703       NaN  0.974232       NaN       NaN
# 499       NaN       NaN       NaN       NaN       NaN       NaN  0.008993
# 124       NaN       NaN       NaN       NaN       NaN       NaN  0.939823
# 154       NaN       NaN       NaN       NaN  0.891587       NaN       NaN
# 316  0.993256       NaN       NaN       NaN  0.992645  0.993494  0.995629
# 59   0.996094       NaN       NaN       NaN       NaN       NaN  0.996466
# 333  0.989581       NaN       NaN  0.991192       NaN       NaN  0.992014
# 503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 534  0.945140       NaN       NaN  0.941555       NaN       NaN       NaN
# 563  0.002273       NaN       NaN  0.002046  0.002488       NaN  0.003097
# 453  0.832622       NaN       NaN       NaN       NaN       NaN  0.878924
# 262       NaN       NaN  0.110669  0.105018       NaN       NaN       NaN
# 378       NaN       NaN  0.882680  0.927335       NaN  0.909619       NaN
# 229       NaN  0.271777       NaN       NaN       NaN       NaN       NaN
# 55   0.964638       NaN       NaN       NaN       NaN       NaN       NaN
# 171       NaN       NaN  0.474235  0.483022  0.475091       NaN       NaN
# 454       NaN       NaN       NaN       NaN  0.904435  0.902985       NaN
# 243       NaN       NaN       NaN       NaN       NaN  0.874354       NaN
# 158       NaN       NaN       NaN       NaN  0.976016       NaN       NaN
# 415  0.929566  0.932105       NaN       NaN       NaN       NaN  0.929560
# 34        NaN       NaN       NaN       NaN  0.083045       NaN       NaN
# 561  0.978313       NaN       NaN       NaN       NaN       NaN       NaN
# 18   0.002683  0.001840       NaN       NaN       NaN       NaN       NaN
# 508       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 322       NaN  0.890778  0.877778       NaN       NaN       NaN       NaN
# 51        NaN       NaN       NaN       NaN       NaN       NaN  0.930746
# 219       NaN  0.003149       NaN  0.004635  0.001645  0.001227  0.001709
# 549       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 52        NaN       NaN  0.967240  0.973856       NaN       NaN       NaN
# 74        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 26        NaN       NaN       NaN       NaN  0.031645       NaN       NaN
# 173       NaN       NaN       NaN       NaN       NaN  0.994053       NaN
# 92   0.843089       NaN  0.825083       NaN       NaN  0.834280  0.859563
# 167       NaN       NaN  0.190942       NaN       NaN  0.179470       NaN
# 4         NaN       NaN       NaN       NaN  0.105335       NaN  0.145811
# 409  0.854846       NaN       NaN  0.846818       NaN  0.826453  0.860908
# 181       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 245       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 379       NaN       NaN       NaN       NaN  0.248163       NaN       NaN
# 425  0.987010       NaN       NaN       NaN       NaN       NaN       NaN
# 479  0.258428       NaN  0.239670       NaN       NaN  0.318501       NaN
# 5         NaN  0.392498       NaN       NaN  0.485506  0.470360  0.389232
# 141       NaN       NaN       NaN       NaN  0.308610       NaN       NaN
# 329       NaN       NaN       NaN  0.533361       NaN       NaN       NaN
# 200       NaN       NaN       NaN       NaN  0.816136       NaN       NaN
# 135       NaN  0.819401       NaN       NaN       NaN       NaN       NaN
# 285       NaN       NaN       NaN  0.989813       NaN       NaN       NaN
# 122       NaN       NaN       NaN       NaN       NaN       NaN  0.003483
# 484       NaN  0.655944       NaN       NaN       NaN       NaN       NaN
# 22        NaN       NaN       NaN  0.092328       NaN  0.105062       NaN
# 220       NaN       NaN       NaN       NaN  0.940250       NaN       NaN
# 517       NaN  0.045031       NaN       NaN       NaN       NaN  0.047548
# 120       NaN       NaN       NaN  0.970860  0.973819  0.977043       NaN
# 81        NaN       NaN  0.406809       NaN       NaN       NaN       NaN
# 487       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 464       NaN  0.868440       NaN       NaN       NaN       NaN       NaN
# 554  0.878535  0.905984       NaN       NaN       NaN       NaN       NaN
# 548  0.986729       NaN       NaN       NaN       NaN       NaN       NaN
# 160       NaN       NaN  0.892557       NaN       NaN       NaN       NaN
# 557  0.987471  0.993314       NaN       NaN       NaN       NaN  0.993188
# 238       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 284  0.928275  0.930909       NaN       NaN  0.931906  0.939722       NaN
# 315       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 195       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 191       NaN  0.969233       NaN       NaN       NaN  0.936942  0.978077
# 116  0.995295       NaN       NaN       NaN  0.996701  0.996858       NaN
# 477  0.952403       NaN       NaN       NaN       NaN       NaN       NaN
# 428       NaN  0.990123  0.989421       NaN       NaN  0.990799  0.993175
# 164       NaN       NaN       NaN       NaN       NaN  0.001478       NaN
# 106       NaN       NaN       NaN  0.773467       NaN       NaN       NaN
# 403  0.936626  0.924137  0.923369       NaN       NaN  0.934429       NaN
# 63        NaN       NaN       NaN  0.987331       NaN       NaN       NaN
# 105       NaN       NaN       NaN       NaN  0.323279  0.349355       NaN
# 312       NaN       NaN  0.943134  0.953513       NaN       NaN       NaN
# 555       NaN       NaN  0.933632       NaN       NaN  0.915735       NaN
# 481       NaN  0.837756       NaN  0.861154       NaN       NaN       NaN
# 344       NaN       NaN       NaN       NaN       NaN       NaN  0.970371
# 93        NaN       NaN       NaN       NaN  0.884361  0.878649       NaN
# 395       NaN  0.898834  0.908702  0.931601       NaN       NaN       NaN
# 393       NaN       NaN       NaN       NaN       NaN       NaN  0.001724
# 381       NaN       NaN  0.971094       NaN       NaN       NaN  0.982765
# 198  0.040762       NaN  0.038617       NaN       NaN       NaN       NaN
# 145       NaN       NaN  0.968832       NaN       NaN  0.976830  0.982577
# 150       NaN  0.938965  0.924070  0.930769       NaN       NaN       NaN
# 39   0.292375       NaN       NaN  0.228713       NaN  0.277109       NaN
# 520       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 351       NaN       NaN       NaN       NaN       NaN  0.114535       NaN
# 253       NaN       NaN       NaN       NaN       NaN  0.146579       NaN
# 467  0.989397       NaN       NaN  0.987148       NaN       NaN       NaN
# 501       NaN       NaN       NaN       NaN  0.338913       NaN       NaN
# 2         NaN       NaN  0.005299       NaN       NaN       NaN       NaN
# 221       NaN       NaN       NaN       NaN       NaN       NaN  0.930665
# 532       NaN       NaN       NaN       NaN       NaN  0.899299       NaN
# 146       NaN       NaN       NaN       NaN  0.510549       NaN  0.434742
# 289       NaN       NaN       NaN  0.963593       NaN  0.956781       NaN
# 241       NaN       NaN       NaN       NaN       NaN  0.983733       NaN
# 342       NaN  0.947288       NaN  0.950325  0.959536       NaN       NaN
# 433       NaN       NaN       NaN       NaN       NaN       NaN  0.033757
# 114       NaN       NaN       NaN       NaN       NaN  0.983721  0.980404
# 311       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 399       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 176  0.942573       NaN  0.932940  0.916998       NaN       NaN       NaN
# 491  0.734712       NaN       NaN       NaN  0.683594       NaN       NaN
# 168  0.018795       NaN       NaN  0.012847       NaN       NaN       NaN
# 365       NaN  0.028202       NaN       NaN  0.022895  0.026537       NaN
# 539       NaN       NaN  0.985881       NaN  0.988715       NaN       NaN
# 506       NaN       NaN  0.943031       NaN  0.945025       NaN       NaN
# 426       NaN       NaN       NaN       NaN       NaN       NaN  0.964034
# 136  0.944459  0.960122       NaN  0.928087       NaN  0.949989       NaN
# 444       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 254  0.016576       NaN  0.012311       NaN       NaN       NaN       NaN
# 362       NaN  0.926801       NaN  0.930517       NaN       NaN       NaN
# 386       NaN       NaN       NaN       NaN       NaN  0.959377       NaN
# 494  0.946685  0.950399       NaN       NaN       NaN       NaN  0.955241
# 452       NaN       NaN       NaN       NaN  0.874481       NaN  0.883845
# 255  0.637271       NaN       NaN       NaN       NaN       NaN       NaN
# 232       NaN       NaN       NaN       NaN  0.925361       NaN       NaN
# 133       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 33        NaN       NaN  0.020727  0.031384       NaN       NaN       NaN
# 88        NaN       NaN       NaN       NaN       NaN  0.743957       NaN
# 290       NaN       NaN       NaN       NaN  0.775499       NaN       NaN
# 44   0.406239       NaN       NaN  0.441737       NaN  0.364638       NaN
# 61        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 199       NaN       NaN       NaN       NaN       NaN       NaN  0.101295
# 375       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 545       NaN       NaN       NaN  0.875682       NaN       NaN       NaN
# 530       NaN  0.885084       NaN  0.815838  0.887097  0.864449       NaN
# 424       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 218       NaN  0.011147       NaN       NaN       NaN       NaN       NaN
# 302       NaN       NaN  0.009219  0.007978       NaN  0.007634       NaN
# 297       NaN       NaN       NaN       NaN  0.951260  0.935728  0.965259
# 73   0.679639  0.641252       NaN  0.693946       NaN       NaN  0.661250
# 295       NaN       NaN       NaN       NaN       NaN       NaN  0.975004
# 35        NaN       NaN  0.060961  0.102561       NaN  0.055957  0.064992
# 493  0.990065  0.990160       NaN       NaN       NaN       NaN  0.994258
# 29   0.287599       NaN       NaN       NaN  0.285360       NaN       NaN
# 460  0.039479       NaN       NaN       NaN       NaN       NaN       NaN
# 438       NaN       NaN       NaN  0.909556  0.886276       NaN       NaN
# 445  0.807967       NaN       NaN  0.799862       NaN  0.800818       NaN
# 309       NaN  0.979650       NaN       NaN       NaN       NaN       NaN
# 541       NaN       NaN  0.574857       NaN       NaN       NaN       NaN
# 217       NaN  0.987950       NaN       NaN       NaN  0.983533       NaN
# 27   0.111882       NaN       NaN       NaN  0.107207  0.089262  0.129141
# 462  0.890148       NaN       NaN       NaN       NaN  0.843001       NaN
# 376       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 156       NaN  0.152582       NaN       NaN       NaN       NaN       NaN
# 552  0.888087  0.909143       NaN       NaN       NaN       NaN       NaN
# 475  0.932475       NaN       NaN       NaN       NaN       NaN       NaN
# 138       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 212       NaN       NaN       NaN  0.000310       NaN  0.001443  0.020564
# 104       NaN       NaN  0.985611       NaN  0.988194       NaN       NaN
# 447       NaN       NaN  0.835965       NaN       NaN       NaN       NaN
# 443       NaN       NaN       NaN       NaN       NaN  0.992161       NaN
# 449       NaN       NaN       NaN       NaN       NaN  0.004056       NaN
# 215       NaN       NaN       NaN  0.469555  0.493621       NaN       NaN
# 496  0.770673       NaN       NaN       NaN       NaN       NaN       NaN
# 189       NaN  0.979118       NaN       NaN       NaN       NaN  0.985307
# 214       NaN       NaN  0.113657  0.147368       NaN       NaN       NaN
# 524       NaN       NaN       NaN       NaN       NaN  0.982342  0.983283
# 204  0.832547       NaN       NaN  0.814903       NaN  0.813189       NaN
# 234       NaN  0.987654       NaN       NaN       NaN       NaN       NaN
# 259  0.019990       NaN  0.026884  0.026062  0.019910       NaN       NaN
# 67        NaN  0.971055       NaN       NaN       NaN       NaN  0.973378
# 24        NaN  0.003546       NaN  0.004497       NaN  0.002680       NaN
# 216       NaN  0.858843       NaN       NaN       NaN       NaN       NaN
# 300       NaN       NaN  0.006306       NaN  0.007032       NaN       NaN
# 223       NaN       NaN       NaN       NaN  0.163065       NaN       NaN
# 129       NaN  0.023203       NaN       NaN       NaN       NaN  0.024370
# 533       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 111       NaN       NaN       NaN       NaN  0.871934  0.876908       NaN
# 166       NaN       NaN  0.993002  0.994062  0.994990  0.996148       NaN
# 267       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 507       NaN       NaN       NaN       NaN  0.965336       NaN       NaN
# 40        NaN       NaN       NaN  0.757377       NaN       NaN       NaN
# 274  0.210893  0.200695       NaN  0.266693       NaN       NaN       NaN
# 455       NaN       NaN       NaN       NaN  0.660800  0.593709       NaN
# 79        NaN       NaN       NaN       NaN       NaN  0.916241  0.927723
# 402       NaN  0.937023       NaN  0.954515       NaN  0.931342       NaN
# 404       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 327  0.986192  0.986872  0.986613       NaN  0.984713  0.984943  0.990165
# 13        NaN       NaN       NaN       NaN  0.563580       NaN  0.653704
# 287  0.985004       NaN       NaN       NaN       NaN       NaN       NaN
# 326       NaN  0.950840  0.954026       NaN       NaN       NaN       NaN
# 121       NaN       NaN       NaN       NaN  0.066238  0.064377       NaN
# 251       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 228       NaN       NaN       NaN  0.778539       NaN       NaN       NaN
# 498       NaN       NaN       NaN       NaN       NaN       NaN  0.075269
# 161       NaN       NaN  0.066981       NaN       NaN  0.080499       NaN
# 83        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 117       NaN       NaN       NaN       NaN       NaN       NaN  0.065398
# 374       NaN       NaN       NaN       NaN  0.938348       NaN  0.953480
# 407       NaN  0.943594  0.930234       NaN       NaN       NaN       NaN
# 25        NaN       NaN  0.004638       NaN       NaN       NaN  0.011103
# 110       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 149       NaN  0.940108  0.944749       NaN       NaN  0.937033       NaN
# 152       NaN       NaN       NaN  0.622807  0.905951       NaN       NaN
# 16        NaN       NaN  0.168427       NaN       NaN       NaN       NaN
# 435       NaN       NaN       NaN       NaN       NaN  0.241580       NaN
# 331       NaN       NaN       NaN       NaN  0.884998  0.871149       NaN
# 109       NaN  0.929872  0.917463       NaN       NaN       NaN       NaN
# 470  0.973422       NaN       NaN       NaN       NaN       NaN       NaN
# 450  0.927323  0.938795       NaN       NaN       NaN       NaN       NaN
# 139       NaN       NaN  0.968010  0.966588       NaN       NaN       NaN
# 237  0.083032       NaN       NaN       NaN       NaN       NaN       NaN
# 260       NaN       NaN  0.017093       NaN       NaN       NaN       NaN
# 352       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 456       NaN       NaN       NaN       NaN       NaN  0.796921  0.860001
# 317       NaN  0.067388       NaN       NaN  0.066929       NaN       NaN
# 323       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 513       NaN       NaN  0.834811  0.868189       NaN       NaN  0.886992
# 248       NaN  0.940994  0.928316  0.925869       NaN       NaN       NaN
# 410       NaN  0.878570       NaN       NaN  0.893069       NaN       NaN
# 422       NaN       NaN  0.914307       NaN       NaN       NaN       NaN
# 497       NaN       NaN       NaN       NaN       NaN       NaN  0.889402
# 19   0.816099       NaN  0.768118       NaN       NaN       NaN       NaN
# 328  0.135306       NaN       NaN       NaN       NaN       NaN       NaN
# 296       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 483       NaN  0.887659       NaN       NaN       NaN       NaN  0.902286
# 269       NaN       NaN       NaN       NaN       NaN       NaN  0.963947
# 363  0.670005  0.666017       NaN       NaN  0.638497       NaN       NaN
# 226       NaN       NaN       NaN  0.989377  0.990285       NaN       NaN
# 495       NaN  0.744143  0.758722       NaN       NaN       NaN  0.749056
# 3         NaN       NaN       NaN       NaN       NaN  0.056877       NaN
# 446       NaN  0.021390       NaN       NaN  0.016870  0.016538  0.014833
# 125  0.950468       NaN  0.950049  0.960494  0.938195  0.942366  0.951458
# 280       NaN       NaN  0.012692       NaN       NaN  0.008122       NaN
# 286       NaN       NaN       NaN  0.851480       NaN  0.860460       NaN
# 77        NaN  0.029646       NaN       NaN       NaN       NaN       NaN
# 184       NaN  0.488111  0.532630  0.636960       NaN       NaN       NaN
# 371       NaN       NaN       NaN       NaN       NaN       NaN  0.939934
# 485       NaN       NaN  0.764759       NaN       NaN       NaN       NaN
# 556       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 275       NaN       NaN       NaN       NaN  0.953609       NaN       NaN
# 294       NaN       NaN       NaN  0.979423       NaN       NaN       NaN
# 535       NaN       NaN  0.009296       NaN       NaN  0.010278       NaN
# 182       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 32        NaN       NaN       NaN  0.035865       NaN       NaN       NaN
# 80        NaN       NaN       NaN  0.916228       NaN       NaN       NaN
# 307       NaN  0.996936       NaN       NaN       NaN       NaN  0.998135
# 258       NaN  0.015384  0.005815  0.002852       NaN  0.007003  0.014080
# 11        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 360       NaN       NaN       NaN  0.987831       NaN       NaN       NaN
# 476       NaN       NaN       NaN  0.617941       NaN       NaN       NaN
# 86        NaN  0.594900       NaN       NaN       NaN       NaN  0.592171
# 266  0.960530       NaN       NaN       NaN       NaN  0.954748       NaN
# 36        NaN  0.454332       NaN       NaN       NaN       NaN       NaN
# 193       NaN       NaN       NaN  0.266771  0.335626       NaN       NaN
# 58        NaN  0.984727       NaN       NaN       NaN       NaN       NaN
# 41   0.610193       NaN       NaN       NaN  0.709364       NaN       NaN
# 270       NaN  0.972615       NaN       NaN  0.970133  0.974851       NaN
# 411       NaN       NaN  0.948114       NaN       NaN       NaN       NaN
# 50   0.974442       NaN  0.974077       NaN       NaN       NaN       NaN
# 209       NaN       NaN       NaN  0.891693       NaN       NaN       NaN
# 511       NaN       NaN       NaN  0.950462       NaN       NaN  0.945622
# 540       NaN       NaN       NaN  0.973116       NaN       NaN       NaN
# 522       NaN  0.987482  0.987216       NaN       NaN       NaN       NaN
# 521       NaN       NaN  0.000557       NaN       NaN  0.000466       NaN
# 451       NaN  0.098737       NaN       NaN  0.071261       NaN       NaN
# 123       NaN       NaN       NaN       NaN  0.846672       NaN       NaN
# 222  0.982279       NaN  0.979104       NaN       NaN       NaN  0.986286
# 419  0.969873  0.974130       NaN       NaN       NaN  0.960950       NaN
# 62        NaN  0.188312       NaN       NaN       NaN       NaN  0.156903
# 568       NaN       NaN  0.994083       NaN  0.994684       NaN       NaN
# 377       NaN       NaN       NaN       NaN       NaN  0.824669  0.880057
# 130       NaN       NaN       NaN       NaN       NaN       NaN  0.964376
# 187  0.926534       NaN       NaN       NaN  0.931299  0.932091  0.933851
# 23        NaN       NaN  0.002397  0.003256       NaN       NaN       NaN
# 480       NaN       NaN       NaN       NaN       NaN       NaN  0.960583
# 509       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 43   0.352877  0.323369       NaN       NaN       NaN  0.314533       NaN
# 370       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 394  0.937308       NaN       NaN  0.943691  0.946073       NaN       NaN
# 0         NaN       NaN  0.001522       NaN       NaN       NaN       NaN
# 383       NaN       NaN  0.886444       NaN  0.903912  0.900659  0.902438
# 201  0.099039       NaN       NaN  0.111288  0.081677  0.091771       NaN
# 405       NaN       NaN       NaN  0.933107  0.957474       NaN       NaN
# 368       NaN  0.002391       NaN  0.002505       NaN       NaN       NaN
# 461       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 529       NaN       NaN       NaN       NaN  0.972168       NaN  0.974496
# 98        NaN       NaN  0.954581       NaN  0.968484       NaN       NaN
# 387       NaN  0.957895  0.962377       NaN       NaN       NaN  0.973526
# 349       NaN       NaN  0.976941       NaN       NaN       NaN       NaN
# 304  0.977805       NaN       NaN  0.975185       NaN       NaN  0.984061
# 418       NaN       NaN  0.953297       NaN       NaN  0.968818       NaN
# 292  0.919530       NaN  0.889115       NaN       NaN       NaN       NaN
# 178  0.978284  0.980187  0.983232       NaN       NaN       NaN       NaN
# 369       NaN       NaN       NaN  0.001494  0.001156       NaN  0.001727
# 256  0.004930       NaN       NaN       NaN       NaN       NaN       NaN
# 94   0.124009  0.121772  0.099401       NaN       NaN       NaN       NaN
# 197       NaN       NaN       NaN  0.541289       NaN       NaN       NaN
# 95        NaN  0.022068  0.023415       NaN       NaN       NaN       NaN
# 558       NaN       NaN       NaN       NaN  0.746820       NaN       NaN
# 163       NaN  0.923880       NaN       NaN       NaN       NaN       NaN
# 169       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 69        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 305       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 48        NaN       NaN       NaN  0.960664  0.962473       NaN       NaN
# 341       NaN       NaN  0.970357       NaN       NaN       NaN       NaN
# 373       NaN  0.011064       NaN  0.018597       NaN       NaN       NaN
# 397       NaN       NaN       NaN       NaN  0.942368       NaN  0.962853
# 207  0.409894       NaN       NaN  0.438663  0.348666       NaN       NaN
# 279       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 528       NaN       NaN       NaN  0.868088       NaN       NaN       NaN
# 227       NaN  0.678064       NaN       NaN       NaN       NaN       NaN
# 148  0.652529       NaN  0.588973       NaN       NaN       NaN       NaN
# 143       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 180  0.000057       NaN       NaN       NaN       NaN       NaN       NaN
# 131       NaN       NaN       NaN       NaN       NaN       NaN  0.216645
# 47        NaN       NaN       NaN       NaN       NaN       NaN  0.165246
# 324       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 203  0.021230  0.024655       NaN       NaN       NaN       NaN       NaN
# 84        NaN  0.931557       NaN  0.941337  0.942311       NaN       NaN
# 398       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 91        NaN       NaN  0.478727  0.521022       NaN       NaN  0.520627
# 82   0.000106       NaN       NaN       NaN  0.000102       NaN       NaN
# 430  0.090891       NaN       NaN       NaN  0.104933       NaN       NaN
# 119       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 291       NaN  0.518971       NaN  0.559663  0.538890       NaN  0.521858
# 57   0.132583       NaN  0.115656       NaN       NaN  0.126873  0.131611
# 321       NaN  0.090257       NaN       NaN       NaN       NaN       NaN
# 257  0.071955  0.094776       NaN       NaN       NaN       NaN       NaN
# 442       NaN       NaN       NaN       NaN       NaN  0.975916       NaN
# 42        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 388       NaN       NaN  0.967726       NaN  0.976712       NaN       NaN
# 335       NaN       NaN       NaN       NaN       NaN  0.032564       NaN
# 273       NaN       NaN       NaN       NaN       NaN  0.989131       NaN
# 488  0.927371       NaN       NaN       NaN       NaN       NaN  0.931851
# 53        NaN       NaN  0.150595  0.151801       NaN  0.157505  0.243175
# 536       NaN  0.532505  0.528064       NaN       NaN  0.523021       NaN
# 128       NaN  0.646203  0.593131       NaN       NaN       NaN       NaN
# 28   0.027799       NaN  0.024827       NaN  0.026141       NaN       NaN
# 183       NaN       NaN  0.980453       NaN       NaN  0.985148       NaN
# 459  0.965264       NaN  0.973826  0.967266       NaN       NaN       NaN
# 510  0.961304       NaN       NaN       NaN       NaN       NaN       NaN
# 151  0.973995       NaN       NaN  0.966617       NaN  0.974617       NaN
# 244  0.067392  0.069731  0.076458       NaN       NaN       NaN       NaN
# 543  0.786619       NaN       NaN       NaN       NaN  0.747386       NaN
# 544       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 265       NaN       NaN       NaN       NaN  0.000202  0.000118  0.000231
# 288  0.927274       NaN       NaN       NaN  0.949314       NaN  0.967878
# 423       NaN       NaN  0.663726  0.716343       NaN  0.703731       NaN
# 147       NaN       NaN       NaN       NaN       NaN  0.784503       NaN
# 177       NaN  0.120548  0.114013  0.143000  0.134739       NaN       NaN
# 99        NaN       NaN       NaN  0.399189       NaN       NaN       NaN
# 448       NaN  0.766710       NaN       NaN       NaN       NaN  0.776682
# 431       NaN  0.961429       NaN  0.962490  0.961551  0.964032       NaN
# 115       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 72        NaN       NaN  0.017916       NaN  0.014001  0.012121  0.012055
# 537       NaN       NaN       NaN       NaN       NaN       NaN  0.703285
# 174       NaN       NaN       NaN  0.995518       NaN       NaN  0.997453
# 87   0.015471       NaN       NaN       NaN       NaN       NaN       NaN
# 551       NaN       NaN  0.953636       NaN       NaN       NaN       NaN
# 486  0.857088       NaN       NaN       NaN       NaN       NaN       NaN
# 314       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 396  0.645425       NaN       NaN  0.662179       NaN       NaN       NaN
# 472       NaN  0.747418       NaN       NaN  0.765856  0.799967       NaN
# 70   0.027061       NaN       NaN       NaN       NaN       NaN  0.023412
# 277       NaN       NaN       NaN  0.464131       NaN       NaN       NaN
# 9         NaN       NaN  0.059005       NaN       NaN       NaN       NaN
# 359  0.974881  0.981356       NaN       NaN       NaN       NaN  0.982050
# 192  0.997039       NaN       NaN       NaN  0.997455  0.997006       NaN
# 559       NaN       NaN       NaN       NaN       NaN       NaN  0.845306
#
#         mod 8     mod 9    mod 10    mod 11    mod 12    mod 13    mod 14  \
# 293       NaN       NaN       NaN       NaN  0.919911  0.926506       NaN
# 332       NaN       NaN  0.983851       NaN       NaN       NaN       NaN
# 565  0.010109  0.013752       NaN       NaN       NaN  0.014761       NaN
# 278  0.925274       NaN       NaN       NaN       NaN  0.932898       NaN
# 489       NaN       NaN       NaN  0.681367       NaN       NaN       NaN
# 346       NaN  0.955642       NaN       NaN       NaN       NaN       NaN
# 357  0.935937       NaN       NaN  0.942247  0.929212  0.939568  0.937184
# 355       NaN  0.925928  0.916503       NaN  0.929197       NaN       NaN
# 112       NaN  0.557165  0.539591  0.574552       NaN       NaN       NaN
# 68        NaN  0.809310       NaN       NaN  0.838636       NaN       NaN
# 526  0.647145  0.623263       NaN       NaN       NaN       NaN       NaN
# 206       NaN       NaN       NaN       NaN       NaN  0.987404       NaN
# 65        NaN       NaN       NaN  0.226161       NaN       NaN       NaN
# 437       NaN  0.905976       NaN       NaN       NaN       NaN  0.896121
# 126  0.354368       NaN       NaN       NaN       NaN       NaN  0.356426
# 429       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 392       NaN  0.024168       NaN       NaN       NaN       NaN  0.020904
# 343       NaN  0.004962       NaN       NaN       NaN       NaN       NaN
# 334       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 440       NaN       NaN       NaN       NaN       NaN  0.791659  0.735737
# 441       NaN       NaN       NaN  0.057841       NaN       NaN       NaN
# 137       NaN       NaN  0.958923       NaN       NaN       NaN       NaN
# 230       NaN       NaN       NaN  0.030966  0.030390       NaN       NaN
# 7         NaN       NaN       NaN       NaN       NaN  0.279414       NaN
# 408       NaN       NaN  0.057198       NaN       NaN  0.055345       NaN
# 523       NaN       NaN       NaN  0.697691       NaN       NaN  0.691050
# 361       NaN  0.922382       NaN       NaN       NaN       NaN       NaN
# 553       NaN       NaN       NaN       NaN  0.993414       NaN       NaN
# 478       NaN       NaN       NaN       NaN       NaN  0.969264       NaN
# 303  0.981769       NaN  0.980636       NaN       NaN       NaN  0.979756
# 155       NaN       NaN       NaN  0.931740       NaN       NaN       NaN
# 186       NaN       NaN       NaN       NaN  0.118464       NaN       NaN
# 101  0.998983       NaN  0.998349       NaN       NaN       NaN       NaN
# 97        NaN  0.991333       NaN  0.989471       NaN       NaN  0.989019
# 20   0.945642       NaN       NaN       NaN       NaN       NaN       NaN
# 153       NaN       NaN  0.986495  0.987418  0.987145       NaN       NaN
# 54        NaN       NaN       NaN  0.267221       NaN       NaN       NaN
# 30        NaN  0.010082       NaN       NaN       NaN       NaN       NaN
# 531       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 49   0.614091  0.585863       NaN       NaN       NaN       NaN       NaN
# 100       NaN       NaN  0.426369       NaN  0.412995  0.415019  0.379073
# 336       NaN  0.977626  0.975874       NaN  0.975164       NaN       NaN
# 299  0.987906       NaN       NaN  0.989889       NaN  0.990050  0.989034
# 347  0.674234       NaN       NaN       NaN       NaN       NaN       NaN
# 502       NaN       NaN       NaN       NaN  0.934151  0.938682  0.931884
# 56        NaN       NaN  0.006583       NaN  0.005630       NaN       NaN
# 144       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 60        NaN       NaN       NaN       NaN       NaN  0.990977  0.989813
# 6         NaN       NaN  0.038997       NaN       NaN  0.030516       NaN
# 8         NaN  0.107853       NaN  0.169497       NaN  0.175562       NaN
# 474       NaN       NaN       NaN       NaN  0.975034       NaN       NaN
# 320       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 252  0.002478       NaN       NaN       NaN       NaN       NaN       NaN
# 202       NaN  0.000741  0.000735       NaN       NaN  0.001405       NaN
# 246  0.958442  0.949021       NaN       NaN  0.948654       NaN       NaN
# 240       NaN       NaN       NaN       NaN       NaN       NaN  0.908975
# 38        NaN  0.963857       NaN       NaN       NaN       NaN       NaN
# 436  0.920343       NaN       NaN       NaN       NaN       NaN       NaN
# 390       NaN       NaN  0.986990  0.987136       NaN       NaN       NaN
# 261       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 339  0.000419       NaN       NaN       NaN       NaN       NaN       NaN
# 282       NaN  0.007894       NaN  0.011253       NaN  0.009766  0.009994
# 276       NaN       NaN  0.992841  0.994455       NaN  0.993788       NaN
# 367  0.901134       NaN       NaN  0.907911       NaN       NaN       NaN
# 505       NaN  0.957366       NaN       NaN       NaN       NaN       NaN
# 499       NaN       NaN       NaN       NaN  0.010474  0.011203       NaN
# 124       NaN       NaN       NaN       NaN  0.919529  0.932397       NaN
# 154       NaN       NaN       NaN       NaN  0.874468       NaN       NaN
# 316  0.992823       NaN       NaN       NaN       NaN  0.993106       NaN
# 59        NaN  0.996090       NaN  0.995916       NaN  0.996069       NaN
# 333       NaN       NaN       NaN       NaN  0.988649  0.989956       NaN
# 503       NaN       NaN       NaN  0.000507  0.001037       NaN       NaN
# 534       NaN       NaN  0.948073  0.942776  0.945029       NaN       NaN
# 563       NaN       NaN       NaN       NaN       NaN       NaN  0.001911
# 453  0.859013       NaN  0.805781       NaN  0.849870       NaN       NaN
# 262       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 378       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 229       NaN       NaN       NaN       NaN  0.247000  0.256805  0.203462
# 55        NaN  0.963577       NaN       NaN       NaN  0.960859       NaN
# 171       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 454       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 243       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 158  0.975553       NaN       NaN       NaN       NaN       NaN       NaN
# 415  0.919439       NaN       NaN       NaN       NaN       NaN       NaN
# 34        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 561       NaN       NaN       NaN       NaN       NaN  0.983263  0.980215
# 18   0.001065       NaN       NaN       NaN       NaN  0.001436       NaN
# 508       NaN       NaN       NaN       NaN  0.665320       NaN       NaN
# 322  0.897797       NaN  0.898623       NaN  0.885678       NaN       NaN
# 51        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 219       NaN       NaN       NaN       NaN       NaN  0.002234       NaN
# 549       NaN  0.960843       NaN       NaN  0.958293       NaN       NaN
# 52        NaN       NaN       NaN  0.970685       NaN       NaN       NaN
# 74        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 26   0.025639       NaN       NaN       NaN       NaN       NaN       NaN
# 173       NaN       NaN       NaN       NaN       NaN       NaN  0.992591
# 92        NaN       NaN       NaN       NaN  0.821033  0.806630  0.811320
# 167       NaN       NaN       NaN       NaN       NaN  0.172989       NaN
# 4         NaN       NaN       NaN  0.098921  0.123077       NaN       NaN
# 409       NaN  0.828550       NaN  0.840275       NaN       NaN       NaN
# 181       NaN       NaN       NaN       NaN       NaN       NaN  0.000415
# 245  0.959084       NaN  0.946945       NaN       NaN       NaN  0.941456
# 379       NaN       NaN       NaN       NaN       NaN  0.153110       NaN
# 425       NaN       NaN       NaN       NaN  0.987296       NaN  0.987386
# 479       NaN       NaN       NaN       NaN  0.272077       NaN  0.274210
# 5    0.476428       NaN       NaN       NaN       NaN       NaN       NaN
# 141       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 329       NaN  0.537086       NaN  0.568478       NaN  0.550802       NaN
# 200       NaN  0.778924       NaN       NaN       NaN       NaN       NaN
# 135       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 285       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 122       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 484       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 220       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 517  0.040248       NaN       NaN       NaN  0.046843       NaN  0.061575
# 120       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 81        NaN       NaN       NaN  0.470013       NaN       NaN  0.438209
# 487       NaN       NaN       NaN       NaN  0.010223       NaN       NaN
# 464       NaN  0.857940       NaN       NaN       NaN       NaN       NaN
# 554       NaN       NaN  0.878911       NaN       NaN  0.895057       NaN
# 548       NaN  0.987554       NaN       NaN       NaN       NaN       NaN
# 160  0.902605  0.911936  0.896571       NaN       NaN       NaN  0.882360
# 557  0.984501  0.990114       NaN       NaN       NaN       NaN       NaN
# 238  0.611729       NaN       NaN       NaN       NaN       NaN       NaN
# 284  0.918132  0.927597       NaN       NaN       NaN       NaN       NaN
# 315       NaN       NaN       NaN       NaN  0.986824       NaN       NaN
# 195  0.940299       NaN  0.938587       NaN       NaN       NaN       NaN
# 191       NaN  0.966104  0.949142       NaN       NaN       NaN  0.938077
# 116       NaN       NaN  0.995224       NaN       NaN  0.996282       NaN
# 477       NaN  0.944343       NaN       NaN  0.938601  0.946949       NaN
# 428       NaN  0.989728  0.988858  0.990954       NaN       NaN       NaN
# 164       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 106       NaN  0.795092  0.827732  0.786906       NaN  0.822471       NaN
# 403       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 63        NaN       NaN       NaN  0.988388       NaN       NaN       NaN
# 105       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 312       NaN       NaN       NaN       NaN  0.951701       NaN       NaN
# 555  0.919182       NaN       NaN       NaN       NaN       NaN       NaN
# 481       NaN  0.832249       NaN       NaN  0.817036       NaN       NaN
# 344       NaN  0.964134       NaN       NaN       NaN       NaN       NaN
# 93        NaN  0.878747       NaN  0.890572       NaN       NaN  0.879694
# 395       NaN       NaN       NaN       NaN       NaN  0.916624  0.912773
# 393       NaN       NaN  0.001077       NaN       NaN       NaN       NaN
# 381  0.979543       NaN       NaN       NaN       NaN       NaN       NaN
# 198  0.025057  0.027408       NaN  0.040403       NaN       NaN  0.035133
# 145       NaN       NaN       NaN  0.972929       NaN       NaN       NaN
# 150       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 39   0.200171       NaN       NaN       NaN       NaN       NaN       NaN
# 520       NaN       NaN       NaN  0.980925       NaN       NaN  0.977380
# 351       NaN       NaN  0.061561       NaN       NaN       NaN       NaN
# 253  0.124038  0.094917       NaN  0.136711       NaN       NaN       NaN
# 467       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 501       NaN       NaN  0.285313       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN  0.005561       NaN
# 221       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 532       NaN       NaN  0.910986       NaN       NaN       NaN       NaN
# 146  0.496301       NaN       NaN       NaN  0.416340       NaN       NaN
# 289       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 241       NaN       NaN  0.981616       NaN       NaN  0.984258       NaN
# 342       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 433  0.021911  0.032050       NaN       NaN       NaN       NaN  0.025169
# 114       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 311       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 399       NaN       NaN       NaN       NaN       NaN  0.960369       NaN
# 176  0.944661       NaN       NaN       NaN  0.951788       NaN       NaN
# 491       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 168  0.011107       NaN       NaN       NaN  0.024614  0.015398       NaN
# 365  0.019237  0.030420       NaN  0.031952       NaN       NaN       NaN
# 539  0.986956       NaN       NaN       NaN       NaN       NaN       NaN
# 506  0.941948       NaN       NaN       NaN  0.939402       NaN       NaN
# 426       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 136       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 444       NaN  0.226185  0.255808       NaN       NaN       NaN       NaN
# 254       NaN       NaN  0.013587       NaN       NaN       NaN       NaN
# 362       NaN       NaN       NaN       NaN  0.916884       NaN       NaN
# 386       NaN  0.952581       NaN       NaN       NaN  0.950831  0.947960
# 494  0.938786       NaN  0.942908       NaN       NaN  0.944489       NaN
# 452  0.870872       NaN  0.884836  0.899437       NaN       NaN  0.876906
# 255       NaN       NaN  0.616874       NaN       NaN       NaN       NaN
# 232  0.925755  0.928835       NaN       NaN  0.933829       NaN       NaN
# 133       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 33        NaN  0.017213       NaN       NaN       NaN  0.015639       NaN
# 88        NaN       NaN       NaN       NaN  0.756654  0.763066       NaN
# 290  0.661882  0.792396  0.694472       NaN  0.795521       NaN       NaN
# 44        NaN  0.305954       NaN       NaN       NaN       NaN       NaN
# 61        NaN       NaN       NaN       NaN  0.991938       NaN       NaN
# 199       NaN       NaN       NaN       NaN       NaN  0.132717       NaN
# 375       NaN       NaN  0.689604  0.756564       NaN       NaN       NaN
# 545       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 530       NaN  0.850375       NaN       NaN       NaN       NaN       NaN
# 424  0.974956       NaN       NaN  0.968535  0.983354       NaN       NaN
# 218       NaN  0.011958       NaN       NaN       NaN  0.007064  0.008307
# 302  0.006893       NaN  0.006825       NaN       NaN       NaN       NaN
# 297       NaN       NaN       NaN       NaN  0.950181       NaN       NaN
# ...
# 397       NaN       NaN       NaN       NaN  0.965308  0.952914       NaN
# 207       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 279       NaN  0.869651  0.885805  0.898520       NaN       NaN       NaN
# 528       NaN       NaN       NaN       NaN       NaN       NaN  0.894534
# 227       NaN       NaN       NaN  0.712688       NaN  0.711948       NaN
# 148  0.612113       NaN       NaN  0.632884       NaN       NaN       NaN
# 143       NaN  0.884004       NaN  0.898222       NaN       NaN       NaN
# 180       NaN  0.000028       NaN       NaN       NaN       NaN       NaN
# 131       NaN  0.179359       NaN       NaN  0.241821  0.257267       NaN
# 47   0.173747       NaN       NaN       NaN       NaN       NaN       NaN
# 324       NaN  0.969137       NaN  0.976495       NaN       NaN       NaN
# 203       NaN       NaN  0.016771       NaN       NaN  0.017478       NaN
# 84        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 398       NaN       NaN  0.984132  0.985921       NaN       NaN  0.985800
# 91   0.522792       NaN       NaN       NaN       NaN  0.550200       NaN
# 82        NaN       NaN       NaN  0.000120       NaN       NaN       NaN
# 430       NaN  0.074394  0.077872       NaN       NaN       NaN  0.064370
# 119       NaN       NaN  0.234694       NaN       NaN       NaN  0.310716
# 291  0.505820       NaN       NaN       NaN       NaN  0.524744       NaN
# 57        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 321       NaN       NaN  0.134872       NaN       NaN       NaN       NaN
# 257       NaN       NaN       NaN       NaN  0.077417       NaN       NaN
# 442  0.979733  0.982526  0.984453       NaN       NaN  0.981555       NaN
# 42   0.002414       NaN  0.002907  0.001222       NaN       NaN       NaN
# 388       NaN  0.976457       NaN  0.973601       NaN  0.975919       NaN
# 335       NaN  0.026399       NaN       NaN       NaN  0.039699       NaN
# 273  0.990041       NaN  0.990754       NaN       NaN       NaN       NaN
# 488  0.927117       NaN       NaN       NaN       NaN       NaN       NaN
# 53        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 536       NaN       NaN       NaN  0.581660  0.498017       NaN       NaN
# 128       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 28   0.021776       NaN  0.021505       NaN       NaN       NaN       NaN
# 183       NaN  0.985161       NaN       NaN  0.991350  0.985872       NaN
# 459       NaN  0.955590       NaN       NaN       NaN  0.973157       NaN
# 510       NaN       NaN       NaN       NaN  0.969554       NaN       NaN
# 151  0.978726       NaN       NaN       NaN       NaN  0.974549  0.968730
# 244  0.070005       NaN       NaN       NaN  0.072853  0.085564       NaN
# 543       NaN  0.720381       NaN       NaN  0.829891       NaN       NaN
# 544       NaN  0.920402       NaN       NaN       NaN       NaN       NaN
# 265       NaN       NaN       NaN  0.000382  0.000496       NaN  0.000849
# 288  0.963077       NaN       NaN       NaN       NaN  0.944100       NaN
# 423       NaN  0.662804       NaN       NaN       NaN       NaN       NaN
# 147       NaN       NaN       NaN       NaN       NaN       NaN  0.859361
# 177       NaN       NaN       NaN  0.122972       NaN  0.137081       NaN
# 99        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 448  0.765010       NaN       NaN       NaN       NaN       NaN       NaN
# 431       NaN  0.956087  0.963501       NaN  0.969100       NaN       NaN
# 115       NaN  0.937331  0.942861       NaN       NaN       NaN  0.941989
# 72        NaN       NaN       NaN       NaN       NaN       NaN  0.021110
# 537  0.750083  0.695766  0.722311       NaN  0.758170       NaN  0.686153
# 174       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 87        NaN  0.010554       NaN       NaN       NaN       NaN       NaN
# 551       NaN       NaN  0.958915       NaN       NaN  0.957608       NaN
# 486  0.845865       NaN       NaN       NaN       NaN       NaN       NaN
# 314       NaN       NaN       NaN  0.997632       NaN       NaN       NaN
# 396  0.645284       NaN       NaN       NaN       NaN  0.675988       NaN
# 472  0.759081       NaN       NaN       NaN       NaN       NaN  0.842989
# 70        NaN  0.026087       NaN       NaN  0.034892       NaN       NaN
# 277       NaN       NaN       NaN  0.375372       NaN  0.400164  0.412763
# 9         NaN  0.038904  0.047779       NaN       NaN       NaN  0.043882
# 359       NaN  0.977583       NaN       NaN  0.985244       NaN  0.979049
# 192  0.998465       NaN       NaN  0.997669       NaN       NaN       NaN
# 559       NaN  0.766563       NaN       NaN  0.875199       NaN  0.816927
#
#        mod 99   mod 100
# 293       NaN  0.932117
# 332       NaN       NaN
# 565       NaN       NaN
# 278       NaN       NaN
# 489       NaN       NaN
# 346       NaN       NaN
# 357  0.935803       NaN
# 355       NaN       NaN
# 112       NaN       NaN
# 68   0.805504       NaN
# 526       NaN       NaN
# 206       NaN       NaN
# 65   0.158256       NaN
# 437       NaN  0.914207
# 126       NaN       NaN
# 429  0.981722  0.984025
# 392       NaN  0.028874
# 343       NaN       NaN
# 334       NaN       NaN
# 440  0.771705       NaN
# 441  0.061697       NaN
# 137       NaN       NaN
# 230       NaN       NaN
# 7         NaN       NaN
# 408  0.050357       NaN
# 523       NaN  0.738723
# 361       NaN       NaN
# 553       NaN       NaN
# 478  0.965961       NaN
# 303       NaN       NaN
# 155       NaN  0.932677
# 186       NaN       NaN
# 101       NaN       NaN
# 97   0.992156       NaN
# 20        NaN       NaN
# 153       NaN       NaN
# 54        NaN       NaN
# 30   0.012275       NaN
# 531  0.899838       NaN
# 49        NaN       NaN
# 100       NaN  0.525986
# 336       NaN       NaN
# 299       NaN  0.993093
# 347       NaN       NaN
# 502       NaN  0.939345
# 56        NaN  0.004851
# 144  0.991076  0.992867
# 60        NaN       NaN
# 6         NaN       NaN
# 8         NaN       NaN
# 474       NaN       NaN
# 320       NaN       NaN
# 252       NaN  0.003543
# 202       NaN       NaN
# 246       NaN       NaN
# 240  0.914901       NaN
# 38   0.970100  0.974591
# 436       NaN       NaN
# 390       NaN       NaN
# 261       NaN       NaN
# 339       NaN       NaN
# 282       NaN       NaN
# 276       NaN       NaN
# 367       NaN  0.902011
# 505       NaN       NaN
# 499  0.009680       NaN
# 124       NaN       NaN
# 154       NaN       NaN
# 316  0.994067       NaN
# 59        NaN       NaN
# 333       NaN  0.991916
# 503       NaN       NaN
# 534       NaN  0.963459
# 563  0.002839       NaN
# 453       NaN       NaN
# 262       NaN       NaN
# 378       NaN       NaN
# 229       NaN       NaN
# 55        NaN  0.965062
# 171       NaN  0.521637
# 454       NaN       NaN
# 243       NaN  0.923955
# 158       NaN       NaN
# 415       NaN       NaN
# 34        NaN  0.056458
# 561       NaN       NaN
# 18   0.001735       NaN
# 508       NaN       NaN
# 322       NaN  0.906537
# 51        NaN       NaN
# 219       NaN       NaN
# 549       NaN       NaN
# 52        NaN       NaN
# 74        NaN  0.933586
# 26        NaN       NaN
# 173       NaN       NaN
# 92   0.839952  0.860462
# 167       NaN       NaN
# 4         NaN       NaN
# 409       NaN       NaN
# 181  0.000319  0.000283
# 245       NaN       NaN
# 379       NaN  0.130960
# 425       NaN  0.992815
# 479       NaN       NaN
# 5    0.346500       NaN
# 141       NaN  0.364146
# 329       NaN  0.620782
# 200  0.789976       NaN
# 135       NaN  0.848150
# 285       NaN       NaN
# 122  0.002931       NaN
# 484  0.672578       NaN
# 22   0.065445       NaN
# 220       NaN       NaN
# 517       NaN  0.051037
# 120       NaN  0.965625
# 81        NaN       NaN
# 487       NaN       NaN
# 464       NaN       NaN
# 554       NaN       NaN
# 548       NaN       NaN
# 160       NaN       NaN
# 557       NaN  0.994984
# 238       NaN       NaN
# 284       NaN       NaN
# 315       NaN  0.990729
# 195  0.935863       NaN
# 191       NaN       NaN
# 116  0.996995       NaN
# 477       NaN  0.945241
# 428       NaN       NaN
# 164       NaN  0.001138
# 106       NaN       NaN
# 403       NaN  0.927597
# 63        NaN       NaN
# 105       NaN       NaN
# 312       NaN       NaN
# 555       NaN       NaN
# 481       NaN  0.859121
# 344       NaN       NaN
# 93        NaN       NaN
# 395  0.898623       NaN
# 393       NaN       NaN
# 381  0.975265       NaN
# 198       NaN  0.028809
# 145  0.978101       NaN
# 150       NaN  0.939460
# 39   0.185845       NaN
# 520  0.982740       NaN
# 351       NaN       NaN
# 253       NaN       NaN
# 467       NaN       NaN
# 501       NaN       NaN
# 2         NaN       NaN
# 221       NaN       NaN
# 532       NaN       NaN
# 146       NaN       NaN
# 289       NaN       NaN
# 241       NaN       NaN
# 342       NaN       NaN
# 433       NaN       NaN
# 114       NaN       NaN
# 311       NaN       NaN
# 399       NaN       NaN
# 176       NaN  0.964463
# 491  0.755739       NaN
# 168       NaN  0.039198
# 365       NaN       NaN
# 539  0.986659       NaN
# 506       NaN       NaN
# 426       NaN       NaN
# 136       NaN       NaN
# 444       NaN       NaN
# 254  0.010564       NaN
# 362       NaN  0.933291
# 386       NaN       NaN
# 494       NaN  0.960773
# 452       NaN       NaN
# 255  0.597622       NaN
# 232       NaN  0.963123
# 133       NaN       NaN
# 33        NaN       NaN
# 88        NaN  0.799062
# 290       NaN       NaN
# 44        NaN       NaN
# 61        NaN       NaN
# 199       NaN       NaN
# 375  0.675581  0.641697
# 545       NaN       NaN
# 530       NaN       NaN
# 424       NaN       NaN
# 218  0.011903       NaN
# 302       NaN       NaN
# 297       NaN  0.968775
# 73        NaN       NaN
# 295  0.967730       NaN
# 35        NaN  0.045772
# 493       NaN       NaN
# 29        NaN       NaN
# 460  0.035095       NaN
# 438       NaN       NaN
# 445       NaN       NaN
# 309  0.983196  0.983598
# 541       NaN       NaN
# 217       NaN       NaN
# 27        NaN       NaN
# 462       NaN  0.910046
# 376       NaN  0.908760
# 156  0.154264       NaN
# 552       NaN       NaN
# 475       NaN       NaN
# 138       NaN  0.225557
# 212       NaN       NaN
# 104  0.989108       NaN
# 447  0.831560       NaN
# 443  0.993324       NaN
# 449       NaN       NaN
# 215       NaN  0.413444
# 496  0.725111       NaN
# 189       NaN       NaN
# 214       NaN       NaN
# 524       NaN  0.986424
# 204       NaN  0.842909
# 234       NaN       NaN
# 259  0.013331  0.028730
# 67   0.968372       NaN
# 24        NaN  0.003343
# 216       NaN       NaN
# 300  0.008582       NaN
# 223       NaN  0.148580
# 129       NaN       NaN
# 533  0.043937  0.043842
# 111       NaN       NaN
# 166       NaN       NaN
# 267  0.908211       NaN
# 507       NaN  0.964656
# 40        NaN       NaN
# 274       NaN       NaN
# 455  0.704169       NaN
# 79        NaN       NaN
# 402       NaN  0.941070
# 404  0.986001  0.986091
# 327       NaN  0.989563
# 13        NaN       NaN
# 287       NaN       NaN
# 326       NaN  0.962801
# 121  0.067970       NaN
# 251       NaN       NaN
# 228       NaN       NaN
# 498       NaN  0.077501
# 161       NaN  0.096314
# 83   0.039801       NaN
# 117       NaN       NaN
# 374       NaN  0.930288
# 407       NaN       NaN
# 25        NaN       NaN
# 110       NaN       NaN
# 149       NaN  0.946812
# 152       NaN       NaN
# 16        NaN  0.184838
# 435       NaN  0.216906
# 331       NaN       NaN
# 109       NaN  0.936787
# 470       NaN       NaN
# 450       NaN       NaN
# 139       NaN       NaN
# 237       NaN       NaN
# 260       NaN       NaN
# 352       NaN       NaN
# 456  0.860985  0.913576
# 317       NaN       NaN
# 323       NaN       NaN
# 513  0.863040       NaN
# 248  0.920982  0.948405
# 410       NaN  0.921356
# 422  0.927902       NaN
# 497       NaN       NaN
# 19        NaN  0.790760
# 328       NaN       NaN
# 296       NaN  0.996074
# 483       NaN       NaN
# 269       NaN       NaN
# 363       NaN       NaN
# 226  0.989641  0.991264
# 495       NaN       NaN
# 3         NaN       NaN
# 446       NaN       NaN
# 125       NaN  0.953760
# 280       NaN  0.012515
# 286       NaN       NaN
# 77   0.032999  0.024327
# 184       NaN       NaN
# 371       NaN  0.915202
# 485       NaN  0.812110
# 556       NaN       NaN
# 275       NaN       NaN
# 294       NaN  0.977820
# 535       NaN       NaN
# 182  0.103458  0.125961
# 32        NaN       NaN
# 80   0.924679       NaN
# 307  0.997122       NaN
# 258       NaN       NaN
# 11        NaN       NaN
# 360       NaN       NaN
# 476  0.585063       NaN
# 86        NaN       NaN
# 266       NaN       NaN
# 36        NaN       NaN
# 193       NaN       NaN
# 58   0.986625  0.987275
# 41        NaN  0.749815
# 270       NaN       NaN
# 411       NaN       NaN
# 50        NaN       NaN
# 209  0.836712  0.818300
# 511  0.934052       NaN
# 540  0.977699  0.982540
# 522  0.986831       NaN
# 521       NaN       NaN
# 451       NaN  0.120575
# 123  0.818313       NaN
# 222  0.982723       NaN
# 419       NaN       NaN
# 62   0.153977       NaN
# 568       NaN       NaN
# 377       NaN       NaN
# 130  0.953588       NaN
# 187       NaN       NaN
# 23        NaN       NaN
# 480       NaN       NaN
# 509       NaN       NaN
# 43        NaN       NaN
# 370       NaN       NaN
# 394  0.940063       NaN
# 0    0.002817       NaN
# 383       NaN  0.902966
# 201  0.072774       NaN
# 405       NaN       NaN
# 368       NaN  0.002740
# 461       NaN       NaN
# 529       NaN       NaN
# 98   0.962211       NaN
# 387  0.965291       NaN
# 349       NaN  0.983001
# 304       NaN       NaN
# 418       NaN  0.961276
# 292       NaN       NaN
# 178       NaN       NaN
# 369  0.001623  0.001504
# 256       NaN       NaN
# 94   0.105467       NaN
# 197  0.562647       NaN
# 95   0.023403       NaN
# 558  0.770099       NaN
# 163       NaN       NaN
# 169       NaN       NaN
# 69   0.972584       NaN
# 305  0.958388       NaN
# 48        NaN       NaN
# 341       NaN       NaN
# 373       NaN  0.010389
# 397       NaN       NaN
# 207  0.404647       NaN
# 279       NaN       NaN
# 528       NaN       NaN
# 227       NaN       NaN
# 148  0.597536       NaN
# 143       NaN       NaN
# 180       NaN       NaN
# 131       NaN       NaN
# 47   0.152453       NaN
# 324       NaN       NaN
# 203  0.014427       NaN
# 84   0.926348  0.939050
# 398       NaN       NaN
# 91        NaN       NaN
# 82        NaN       NaN
# 430       NaN       NaN
# 119       NaN       NaN
# 291  0.487781       NaN
# 57        NaN  0.129245
# 321       NaN       NaN
# 257       NaN       NaN
# 442       NaN       NaN
# 42        NaN       NaN
# 388  0.976155       NaN
# 335       NaN       NaN
# 273       NaN       NaN
# 488  0.922761  0.933917
# 53        NaN  0.231667
# 536       NaN  0.601884
# 128       NaN  0.668231
# 28        NaN       NaN
# 183       NaN       NaN
# 459  0.969728       NaN
# 510       NaN  0.955263
# 151  0.972540       NaN
# 244  0.065307       NaN
# 543       NaN       NaN
# 544       NaN  0.933646
# 265       NaN       NaN
# 288       NaN       NaN
# 423       NaN  0.681133
# 147       NaN       NaN
# 177       NaN       NaN
# 99   0.341305       NaN
# 448       NaN  0.801828
# 431  0.957876       NaN
# 115  0.935641       NaN
# 72        NaN  0.015695
# 537  0.709561       NaN
# 174       NaN       NaN
# 87   0.009958       NaN
# 551  0.958976       NaN
# 486  0.845090       NaN
# 314  0.997776       NaN
# 396       NaN       NaN
# 472       NaN       NaN
# 70        NaN       NaN
# 277  0.332291       NaN
# 9    0.046576       NaN
# 359       NaN  0.985255
# 192       NaN       NaN
# 559       NaN       NaN

# %% [markdown]
# We can plot the class probabilities for one or more patients by calling `.plot_object_probabilities` and investigate how difficult it was to classify the patients correctly. Patient 291 belongs to class 1 and the class probabilities are mostly just above the threshold of 0.5 and below for roughly 13% of the predictions. For patient 255, who belongs to class 0, 100% of the class probabilities indicate incorrectly that this patient belongs to class 1. Patients 253 (class 0) and 150 (class 1) were always predicted correctly and their respective probabilities close to the truth.

# %%
analysis.plot_object_probabilities(object_id=[291, 255, 253, 150])

# %% [markdown]
# We can apply PCA (principal component analysis) either on each class separately or both.
#
# **Example below: PCA on class 0**
#
# * First plot: *PCA scores* plot with coloured scores showing distribution of the patients for the first two components.
#
# Each point represents one patient in the class. The darker the colour, the more often the patient was classified incorrectly. The coloring degree is set by the value in column `% incorrect` in the array above that we got when calling `.summary_objects`. When applying PCA to class 0 we can see that those patients often classified incorrectly are grouped on the left side of the scores plot, indicating that they are similiar in some way.
#
# * Second plot: *PCA scores* plot - same as first plot, now showing patient ID
#
# We can see that the first component explains 37.4% of the total variance in the data based on the four selected features, while the second component explains 30%. That means that the first and second component together explain 67.4% of all the total variance. We have captured much of the systematic information with these two components, however more systematic information may be containten in further componen, i.e. component 3, 4 and so on. One has to keep in mind though, the explained variance is smaller for each following component.
#
# * Third plot: *PCA loadings* plot showing how features contributed to the variance in the data
#
# The four selected features are all located on the right ($\geq 0$ on the first axis) side of the plot. When superimposing the PCA scores plot on PCA loadings plot we can say the following: patients in close proximity of the features have high values for those features. Patients on the opposite side have low values for those features. From the two plots we can say that the misclassified patients had relatively low values for the selected features.
#
# * Fourth plot: *PCA correlation loadings* plot - similar to *PCA loadings* plot, but showing how much of the variance is explained in each feature
#
# We can see that the variance in features `worst radius`, `worst concave points` and `worst symmetry` is explained almost entirely by component 1 and 2, since they are located close to the outer ring that represents 100% explained variance. The inner ring represents 50% explained variance. For feature `worst concave points` almost all of the explained variance is captured by component 1. For features `worst radius` and `worst symmetry` it is the combination of component 1 and 2 that contribute to explaining close to 100% of the variance. Feature `worst texture` is now well explained by component 1 and 2, meaning that some of its systematic variance may be explained by component 3 or further.
#
# * Fifth plot: *PCA bi-plot* - superimposed *PCA scores* and *PCA loadings*
#
# This plot is actually the PCA scores and PCA loadings superimposed.
#
# * Sixth plot: *PCA explained variance*
#
# From this plot we can see the cumulative explained variance across an increasing number of components. The blue line represents the calibrated explained variance, while the red line represents the validated explained variance. The red line being close to the blue line indicates that all components in the model are valid and may be used for interpretation. We also see that four components explain 100% of all variance in the data. This is not surprising, since we have exactly four features in the the data (the four features that were selected by RENT).

# %%
analysis.plot_object_PCA(cl=0)
# Out:
# loo

# %% [markdown]
# **Example below: PCA on class 1**
#
# * First plot: *PCA scores plot* with colouring
#
# We can see that only few samples are coloured darker because of misclassification.

# %%
analysis.plot_object_PCA(cl=1)
# Out:
# loo

# %% [markdown]
# **Example below: PCA on class 0 and class 1 together**
#
# * First plot: *PCA scores* plot with coloured scores
#
# We can see that most of the misclassified samples would lie along the dicision boundary (not shown) that separates the two classes. Circles represent class 0, while stars represent class 1. Setting `cl="continuous` colors the first plot with regard to the average prediction for the object over the models where the object was part of a testset.

# %%
analysis.plot_object_PCA(cl='both', problem ="class")
# Out:
# loo

# %% [markdown]
# Another possibility is to color the objects by their average prediction of belonging to class 1. We observe a gradient coloring, with 2 clusters and unstable objects with probabilities of around 0.5 in the middle.

# %%
analysis.plot_object_PCA(cl='continuous', problem ="class",hoggorm=False)
# Out:
# loo

# %% [markdown]
# ### Check performance using only selected features

# %% [markdown]
# RENT selected some features based on the distribution of the weights of each feature across the ensenmble of models. Now let's check how well a model performs that uses only the selected features on unseen data, i.e data that has not been touched by the RENT method.

# %%
#predict test data

# Import what is needed for prediction and evaluation of predictions from test set
from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression as LR

# Scale the data accordingly
sc = StandardScaler()
train_data_sc = sc.fit_transform(train_data.iloc[:, selected_features])
test_data_sc = sc.transform(test_data.iloc[:, selected_features])

# Train model with 
model = LR(penalty='none', max_iter=8000, solver="saga", random_state=0).\
        fit(train_data_sc, train_labels)

# Print results
print("f1 1: ", f1_score(test_labels, model.predict(test_data_sc)))
print("f1 0: ", f1_score(1 - test_labels, 1 - model.predict(test_data_sc)))
print("Accuracy: ", accuracy_score(test_labels, model.predict(test_data_sc)))
print("Matthews correlation coefficient: ", matthews_corrcoef(test_labels, model.predict(test_data_sc)))
# Out:
# f1 1:  0.983050847457627
# f1 0:  0.9724770642201834
# Accuracy:  0.9790209790209791
# Matthews correlation coefficient:  0.9564940942739543

# %% [markdown]
# Since the classes in the Wisconsin breast cancer data set are easy to separate, we achieve high performance for the test data.

# %% [markdown]
# ### Feasibility study regarding the features selected by RENT

# %% [markdown]
# In order to validate the selected features we benefit to know whether the selected features provide models that perform better than random. This can be done in two complimentary ways, both using a statistical t-test:
#
# 1. randomly draw the same number of features from the full set of features and compute model performance on the test data. Do this many times and collect model performances. Compute average performance across these models and check how many of those are higher than the performance of the selected features. One should expect that the average performance of the models with randomly drawn features would be substantially lower than the performance of the model with the selected features. One should also expect that the number of performances with randomly drawn features higher than the performance of the model with the selected features should be quite low. Say, if 4 out of 100 models with randomly drawn features are higher than the performance with the selected features, this would result in a p-value 4 / 100 = 0.04. It is up to the user where to set the required significance level.
#
# 2. permute the lables of the test data and compute model performance using the selected features every time. In the same manner as in point 1 above, collect the performances based on permuted labels and compute average performance. One should expect that the average performance for the models with permuted labels should be substantially lower. Also as in 1. one can compute the p-value from the permutation based model performances by checking how many of the models provided higher performance than the model using the original lables without permutation.
#
# A nice source on these permuation based p-values is provideded [here](https://www.jwilber.me/permutationtest/ )

# %%
analysis.validation_study(test_data, test_labels, num_drawings=100, num_permutations=1000, alpha=0.05)
# Out:
# mean VS1 0.8026010304541373
# VS1: p-value for average score from random feature drawing:  2.3392029434946884e-27
# With a significancelevel of  0.05  H0 is rejected.
#
# -----------------------------------------------------------
#
# Mean VS2 0.0051245348308271025
# VS2: p-value for score from permutation of test labels:  0.0
# With a significancelevel of  0.05  H0 is rejected.

# %% [markdown]
# From the plot above and the computed p-values we can conclude that the test performance with the selected features is:
#
# * significantly better than the average prediction performance from randomly drawn features from the full set of features
# * significantly better than the average prediction performance from models with permuted test labels
#
# This means we can be confident that we have selected relevant and important features for the model.

# %% [markdown]
# To evaluate the stability of RENT we use a stability measure investiaged by Nogueira et al. We define RENT as stable, if the selected feature set is the same up to some random variability, when applying RENT multiple times (`M`) to the same dataset.

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
import time


M=10 # number of runs 
alpha = 0.05 # level of significance for the confidence interval 
d = len(train_data.columns) # number of features
counts = [2, 5, 10, 50, 100, 300, 500] # values to compare (K)
C, l1 = analysis.get_enet_params()

# Store outputs in dictionaries
times = {}
stabilities = {}
perf = {}
num_feats = {}

start = time.time()

for count in counts:
    time_count = []
    Z_net = np.zeros((M,d), dtype=np.int8)
    performance = np.zeros(M)
    numFeatures = np.zeros(M)
    
    for i in range(M):
        model = RENT.RENT_Classification(data=train_data.values,
                                        target=train_labels,
                                        C=[C],
                                        l1_ratios=[l1],
                                        autoEnetParSel=False,
                                        poly='OFF',
                                        testsize_range=(0.25,0.25),
                                        scoring='mcc',
                                        K=count,
                                        scale=True,
                                        verbose=0)
        model.train()
        features = model.selectFeatures(0.9,0.9,0.975)
        time_count.append(model.get_runtime())
        
        #prediction model
        sc = StandardScaler()
        train = sc.fit_transform(train_data.values[:,features])
        test = sc.transform(test_data.values[:,features])
        ML_model = LogisticRegression(penalty='none', max_iter=8000, solver='saga').fit(train, train_labels)
        performance[i] = matthews_corrcoef(test_labels, ML_model.predict(test))
        Z_net[i,features] = 1
        numFeatures[i] = len(features)
    
    times[count] = time_count
    stabilities[count] = stability.confidenceIntervals(Z_net, alpha=alpha)
    perf[count] = performance
    num_feats[count] = numFeatures    

end = time.time()

print('Runtime: ', end - start)
# Out:
# No feature names found - automatic generate feature names.
# Runtime:  818.6034533977509

# %% [markdown]
# The following plot compares the runtime, stability and prediction performance of RENT for different `K` values.

# %%
import matplotlib.pyplot as plt
def stability_plot(x_levels, stabilities, accuracies, times):
    stability = np.array(list({k: v['stability'] for k, v in stabilities.items()}.values()))
    stab_error = stability - np.array(list({k: v['lower'] for k, v in stabilities.items()}.values()))
    performance = np.array(list({k: np.mean(v) for k, v in accuracies.items()}.values()))
    performance_error = np.array(list({k: np.std(v) for k, v in accuracies.items()}.values()))
    runtime = np.array(list({k: np.mean(v) for k, v in times.items()}.values()))
    runtime_errors = np.array(list({k: np.std(v) for k, v in times.items()}.values())) 

    fig, ax1 = plt.subplots()
    ax1.set_xlabel('number of models (K)',fontsize=10)
    stab = ax1.plot(x_levels,stability, color="red", label='stability', marker='o')
    ax1.fill_between(x_levels, (stability-stab_error), (stability+stab_error),color="red", alpha= 0.1 )
    perf = ax1.plot(x_levels,performance, color="blue", label='performance', marker='o')
    ax1.fill_between(x_levels, (performance-performance_error), (performance+performance_error),color="blue", alpha= 0.1 )
    plt.ylim(0,1.1)
    plt.yticks(fontsize=10)
    plt.xticks(fontsize=10)
    ax2 = ax1.twinx()
    ax2.set_ylabel('time[s]', color='green', fontsize=10)
    tim = ax2.plot(x_levels,runtime, color="green", label='runtime', marker='o')
    ax2.fill_between(x_levels, (runtime-runtime_errors), (runtime+runtime_errors),color="green", alpha= 0.1)
    ax2.tick_params(axis='y', labelcolor="green")

    leg = stab + perf + tim
    labs = [l.get_label() for l in leg]
    ax1.legend(leg, labs, loc=4, fontsize=10)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


stability_plot(counts, stabilities, perf, times)
