# %% [markdown]
# # RENT applied to a binary classification problem

# %% [markdown]
# This Jupyter notebook illustrates how to apply RENT to your data for feature selection with a *binary classification* problem. It is also complimentary to the manscript published at arXiv.org.
#
# [RENT -- Repeated Elastic Net Technique for Feature Selection](https://arxiv.org/abs/2009.12780)

# %% [markdown]
# For an example on how to use RENT for feature selection on a **regression problem**, please have a look this [Jupyter Notebook](https://github.com/NMBU-Data-Science/RENT/blob/master/src/RENT/Regression_example.ipynb).

# %% [markdown]
# ## Content

# %% [markdown]
# 1. [Load Wisconsin Breast Cancer dataset](#Load-Wisconsin-Breast-Cancer-dataset)
# 2. [Prepare data for variable selection using RENT](#Prepare-data-for-variable-selection-using-RENT)
# 2. [Define RENT ensemble for binary classification](#Define-RENT-ensemble-for-binary-classification)
# 3. [Train RENT ensemble and inspect results](#Train-RENT-ensemble-and-inspect-results)
# 4. [Set selection criteria cutoffs](#Set-selection-criteria-cutoffs)
# 5. [Investigation of class predictions](#Investigation-of-class-predictions)
# 6. [Check performance using only selected features](#Check-performance-using-only-selected-features)
# 7. [Feasibility study regarding the features selected by RENT](#Feasibility-study-regarding-the-features-selected-by-RENT)

# %% [markdown]
# ---

# %% [markdown]
# First import needed modules and apply some settings to the Jupyter notebook for better visualisation of results.

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 2000)
from RENT import RENT

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load Wisconsin Breast Cancer dataset

# %% [markdown]
# Now load the data from sciki-learn, store it in a pandas DataFrame and split it into a training and test set.

# %%
from sklearn.datasets import load_breast_cancer

wisconsin = load_breast_cancer()
data = pd.DataFrame(wisconsin.data)
data.columns = wisconsin.feature_names
target = wisconsin.target

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# 0                 0.07871        1.0950         0.9053            8.589
# 1                 0.05667        0.5435         0.7339            3.398
# 2                 0.05999        0.7456         0.7869            4.585
# 3                 0.09744        0.4956         1.1560            3.445
# 4                 0.05883        0.7572         0.7813            5.438
#
#    area error  smoothness error  compactness error  concavity error  \
# 0      153.40          0.006399            0.04904          0.05373
# 1       74.08          0.005225            0.01308          0.01860
# 2       94.03          0.006150            0.04006          0.03832
# 3       27.23          0.009110            0.07458          0.05661
# 4       94.44          0.011490            0.02461          0.05688
#
#    concave points error  symmetry error  fractal dimension error  \
# 0               0.01587         0.03003                 0.006193
# 1               0.01340         0.01389                 0.003532
# 2               0.02058         0.02250                 0.004571
# 3               0.01867         0.05963                 0.009208
# 4               0.01885         0.01756                 0.005115
#
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0         25.38          17.33           184.60      2019.0            0.1622
# 1         24.99          23.41           158.80      1956.0            0.1238
# 2         23.57          25.53           152.50      1709.0            0.1444
# 3         14.91          26.50            98.87       567.7            0.2098
# 4         22.54          16.67           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678

# %% [markdown]
# ### Prepare data for variable selection using RENT

# %% [markdown]
# First split the data into a training and test data.

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, target, random_state=0, shuffle=True)

# %% [markdown]
# ### Define RENT ensemble for binary classification

# %% [markdown]
# **The main idea**
#
# Using the RENT approach we will train an **ensemble of unique models** based on **unique subsets** of the training data. Since each model is trained on a unique subset, all models will be slightly different from each other and elastic net regularisation **may select a different subset of features for each model**.
#
# RENT investigates **how consistenly elastic net selects features** across all unique models by analysing distributions of the weight sizes of each feature. Using specific thresholds or cutoff values for selection criteria $\tau_1$, $\tau_2$ and $\tau_3$ computed from those weight size distributions, we can regulate how aggressively RENT will select features from the full set of features. For more details, please consult the paper mentioned at the top of this Juptyer notebook

# %% [markdown]
# **Elastic net regularisation**
#
# $\lambda_{enet}(\beta) = \gamma [\alpha\lambda_1(\beta)+ (1-\alpha)\lambda_2(\beta)]$

# %% [markdown]
# Since the average prediction performance of an ensemble of models may vary for different combinations of $\gamma$ and $\alpha$ we pre-define a number of values for each and store them in lists `my_C_params` and `my_l1_ratios`. Prior to RENT, the best performing combination of $\gamma$ and $\alpha$ for prediction will be identified through 5-fold cross validation. For the best performing combination RENT will then compute an ensemble of models that will be utilised for feature selection.
#
# **Note** regarding elastic net regularisation term above we follow the scikit-learn convention:
#
# * RENT input paramter `C` represents inverse values of $\gamma$
# * RENT input parameter `l1_ratio` represents values of $\alpha$ for the mix of L1 and L2 regularisation. `l1_ratio = 1` is equivalent to using L1-regularisation, `l1_ratio = 0` is equivalent to using L2-regularisation while values between 0 and 1 will result in a mix of L1 and L2 regularisation.

# %% [markdown]
# In the code below we initialise the `RENT_Classification` ensemble. In addition to various values for `C` and `l1_ratio` we can define:
#
# * `autoEnetParSel`: whether identification of best performing `C` and `l1_ratio` should be done automatic through 5-fold cross validation (set to `True`) or if user selects manually (set to `False`)
# * `poly`: whether to include squares of features and interactions of features. Should be beneficial if data are non-linear, but comes with a computational cost that may increase very much if the number of orginal set of features is high.
# * `testsize_range`: this allows for more randomness in models by allowing test set sizes to vary within range defined in tuple (lower end, higher end). Set both parameters to the same value to secure identical test set size across for all models in ensemble.
# * `scoring`: performance metric to use for model evaluation
# * `method`: which classification algorithm to choose for model training. Uses logistic regression by default.
# * `K`: how many models the ensemble should consist of. The higher the better (denser weight distributions leading to higher selection stability), but computationally more expensive.
# * `verbose`: whether or not to show progress during computations. Choose 1 to get information on computation progress, else 0.
#
# For more detailed information for each input parameter, please consult the documentation [link here]

# %%
# Define a range of regularisation parameters C for elastic net. A minimum of at least one value is required.
my_C_params = [0.1, 1, 10]

# Define a reange of l1-ratios for elastic net.  A minimum of at least one value is required.
my_l1_ratios = [0, 0.1, 0.25, 0.5, 0.75, 0.9, 1]

# Define setting for RENT
analysis = RENT.RENT_Classification(data=train_data, 
                                    target=train_labels, 
                                    feat_names=train_data.columns, 
                                    C=my_C_params, 
                                    l1_ratios=my_l1_ratios,
                                    autoEnetParSel=True,
                                    poly='OFF',
                                    testsize_range=(0.25,0.25),
                                    scoring='mcc',
                                    method='logreg',
                                    K=100,
                                    verbose=1)
# Out:
# data dimension: (426, 30)  data type: <class 'pandas.core.frame.DataFrame'>
# target dimension (426,)
# regularization parameters C: [0.1, 1, 10]
# elastic net l1_ratios: [0, 0.1, 0.25, 0.5, 0.75, 0.9, 1]
# number of models in ensemble: 100
# scale: True
# classification method: logreg
# verbose: 1

# %% [markdown]
# ### Train RENT ensemble and inspect results

# %% [markdown]
# Now train a RENT ensemble for the best combination of `C` and `l1_ratio`. The best combination will be identified through 5-fold CV.

# %%
analysis.train()

# %% [markdown]
# If it is of interest, one can extract time (sec) for computation of all ensembles.

# %%
analysis.get_runtime()
# Out:
# 11.077202081680298

# %% [markdown]
# Acquire the elastic net parameter for which RENT was applied to the data using `.get_enet_params()`.

# %%
# can play around with enet parameter setting...
analysis.get_enet_params()
# Out:
# (0.1, 1.0)

# %% [markdown]
# For the data at hand, best prediction performance was achieved with`l1_ratio=0.1` and `C=1`.

# %% [markdown]
# ### Set selection criteria cutoffs

# %% [markdown]
# Here we can set how agressively we want RENT to select features by setting thresholds or cutoff values for $\tau_1$, $\tau_2$ and $\tau_3$.
#
# Below we set `tau_1_cutoff = 0.9`, meaning that we will consider only features that were selected in at least 90% of the times or more across the ensemble models.
#
# Sometimes features are selected by elastic net (weight is non-zero), but their weight might be very small. This happens more often when `l1_ratio` is such that the L2-part of the regularisation gets more influence than L1 (smaller values for `l1_ratio`). In addition to that some weights of a feature may be consistently very small across all models and may be positive in some models and negative in others showing little consistency. This may indicate that even though such a feature is selected, it may not be very meaningful, since its feature weights are small and often have different signs. The `tau_2_cutoff` criterion simply allows the user to define a required minimum proportion of the parameter estimates to have the same sign.
#
# `tau_3_cutoff` is chosen such that it corresponds to the well-known statistical Student’s t-test with rejection of the null hypothesis assuming that the mean of the feature weights across all models is equal to zero. In other words, we test whether the feature weighs are consistently high with low variance across the $K$ models.
#
# Only if the resulting values for each feature are higher than the cutoff for all three criteria, the RENT will select the feature. In the example below we set the cutoff criteria to `tau_1_cutoff=0.9`, `tau_2_cutoff=0.9`, `tau_3_cutoff=0.975`.

# %%
selected_features = analysis.selectFeatures(tau_1_cutoff=0.9, tau_2_cutoff=0.9, tau_3_cutoff=0.975)

# %% [markdown]
# How do we know whether a feature fulfills the criteria?
#
# We can check this by looking at the summary for `tau_1`, `tau_2` and `tau_3` across all features using `.summary_criteria()`. We can see for example that RENT selects feature `worst radius`, since its vaues for `tau_1`, `tau_2` and `tau_3` are all 1, i.e above the cutoffs set in the code above. Feature `mean concave points` gets close with `tau_1=0.89` and `tau_2=0.89`, but they are still below `tau_1_cutoff` and `tau_2_cutoff`. If we would set lower cutoffs, say `tau_1=0.8` and `tau_2=0.8` `mean concave points` would be selected. By varying cutoffs for `tau_1`, `tau_2` and `tau_3` we can define how strict RENT has to be when selecting features.

# %%
analysis.summary_criteria()
# Out:
#        mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# tau_1          0.0      0.360000             0.0        0.0              0.0
# tau_2          0.0      0.360000             0.0        0.0              0.0
# tau_3          NaN      0.999999             NaN        NaN              NaN
#
#        mean compactness  mean concavity  mean concave points  mean symmetry  \
# tau_1               0.0        0.010000                 0.94            0.0
# tau_2               0.0        0.010000                 0.94            0.0
# tau_3               NaN        0.841336                 1.00            NaN
#
#        mean fractal dimension  radius error  texture error  perimeter error  \
# tau_1                     0.0          0.75            0.0              0.0
# tau_2                     0.0          0.75            0.0              0.0
# tau_3                     NaN          1.00            NaN              NaN
#
#        area error  smoothness error  compactness error  concavity error  \
# tau_1         0.0               0.0                0.0              0.0
# tau_2         0.0               0.0                0.0              0.0
# tau_3         NaN               NaN                NaN              NaN
#
#        concave points error  symmetry error  fractal dimension error  \
# tau_1                   0.0             0.0                      0.0
# tau_2                   0.0             0.0                      0.0
# tau_3                   NaN             NaN                      NaN
#
#        worst radius  worst texture  worst perimeter  worst area  \
# tau_1           1.0            1.0          0.09000         0.0
# tau_2           1.0            1.0          0.09000         0.0
# tau_3           1.0            1.0          0.99682         NaN
#
#        worst smoothness  worst compactness  worst concavity  \
# tau_1              0.44                0.0         0.070000
# tau_2              0.44                0.0         0.070000
# tau_3              1.00                NaN         0.971054
#
#        worst concave points  worst symmetry  worst fractal dimension
# tau_1                   1.0            0.92                      0.0
# tau_2                   1.0            0.92                      0.0
# tau_3                   1.0            1.00                      NaN

# %% [markdown]
# Let's check which features were selected based on the cutoffs we defined above.

# %%
selected_features
# Out:
# array([ 7, 20, 21, 27, 28], dtype=int64)

# %% [markdown]
# Using the indices of the selected features we can identify the feature names.

# %%
train_data.columns[selected_features]
# Out:
# Index(['mean concave points', 'worst radius', 'worst texture',
#        'worst concave points', 'worst symmetry'],
#       dtype='object')

# %% [markdown]
# **Regarding $\tau_{1}$**
#
# To get a better impression on how often a feature weight was non-zero across all models, we use `.plot_selection_frequency()`. We can see from the plot that across all models in the ensemble elastic net for example never selected features at index 2 through 6, 11 through 19 as well as 23, 25 and 29. This means that elastic net always sets the weights for those feature to zero, across all models in the ensemble. Elatic net selected some features only for a few models in the ensemble (features at index 22 and 26), that is in around 10% of the models (approx. 0.1 on the vertical axis) or lower (for example features at index 0, 2-6, etc). This indicates that the selection of these features by elastic net is relatively unstable and very dependent on the subset of the training samples.

# %%
analysis.plot_selection_frequency()

# %% [markdown]
# **Regarding $\tau_{2}$ and $\tau_{3}$**
#
# One has to keep in mind though, that a feature may be selected by elastic net (i.e. the weight i non-zero), but it may be:
#
# 1. very small and hence not very influential to the model (even though it was selected by elastic net)
# 2. alternating its sign (positive or negative weight value) across the ensemble of models, indicating unstable importance of this feature.
#
# To get more detailed information on the weight sizes one could investigate the full distribution of the weights of each feature across all models. This is possible by calling `.get_weight_distributions()`. This returns an array holding all weights across all models in the ensemble (rows) and each feature (columns). Here we can see that for the feature at index 5 `mean compactness` the weights are always 0 across all 100 models applied in this example (corresponding to the plot above).

# %%
analysis.get_weight_distributions()
# Out:
#         mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# K(1)            0.0      0.000000             0.0        0.0              0.0
# K(2)            0.0     -0.134554             0.0        0.0              0.0
# K(3)            0.0      0.000000             0.0        0.0              0.0
# K(4)            0.0     -0.041754             0.0        0.0              0.0
# K(5)            0.0     -0.006332             0.0        0.0              0.0
# K(6)            0.0      0.000000             0.0        0.0              0.0
# K(7)            0.0      0.000000             0.0        0.0              0.0
# K(8)            0.0     -0.077204             0.0        0.0              0.0
# K(9)            0.0      0.000000             0.0        0.0              0.0
# K(10)           0.0      0.000000             0.0        0.0              0.0
# K(11)           0.0      0.000000             0.0        0.0              0.0
# K(12)           0.0      0.000000             0.0        0.0              0.0
# K(13)           0.0     -0.206511             0.0        0.0              0.0
# K(14)           0.0      0.000000             0.0        0.0              0.0
# K(15)           0.0      0.000000             0.0        0.0              0.0
# K(16)           0.0     -0.165826             0.0        0.0              0.0
# K(17)           0.0     -0.029545             0.0        0.0              0.0
# K(18)           0.0      0.000000             0.0        0.0              0.0
# K(19)           0.0      0.000000             0.0        0.0              0.0
# K(20)           0.0      0.000000             0.0        0.0              0.0
# K(21)           0.0      0.000000             0.0        0.0              0.0
# K(22)           0.0     -0.162779             0.0        0.0              0.0
# K(23)           0.0      0.000000             0.0        0.0              0.0
# K(24)           0.0      0.000000             0.0        0.0              0.0
# K(25)           0.0      0.000000             0.0        0.0              0.0
# K(26)           0.0      0.000000             0.0        0.0              0.0
# K(27)           0.0     -0.051689             0.0        0.0              0.0
# K(28)           0.0      0.000000             0.0        0.0              0.0
# K(29)           0.0     -0.185341             0.0        0.0              0.0
# K(30)           0.0      0.000000             0.0        0.0              0.0
# K(31)           0.0     -0.014032             0.0        0.0              0.0
# K(32)           0.0      0.000000             0.0        0.0              0.0
# K(33)           0.0      0.000000             0.0        0.0              0.0
# K(34)           0.0      0.000000             0.0        0.0              0.0
# K(35)           0.0     -0.020354             0.0        0.0              0.0
# K(36)           0.0     -0.024826             0.0        0.0              0.0
# K(37)           0.0      0.000000             0.0        0.0              0.0
# K(38)           0.0      0.000000             0.0        0.0              0.0
# K(39)           0.0      0.000000             0.0        0.0              0.0
# K(40)           0.0      0.000000             0.0        0.0              0.0
# K(41)           0.0     -0.095420             0.0        0.0              0.0
# K(42)           0.0      0.000000             0.0        0.0              0.0
# K(43)           0.0      0.000000             0.0        0.0              0.0
# K(44)           0.0      0.000000             0.0        0.0              0.0
# K(45)           0.0      0.000000             0.0        0.0              0.0
# K(46)           0.0      0.000000             0.0        0.0              0.0
# K(47)           0.0      0.000000             0.0        0.0              0.0
# K(48)           0.0      0.000000             0.0        0.0              0.0
# K(49)           0.0     -0.040670             0.0        0.0              0.0
# K(50)           0.0      0.000000             0.0        0.0              0.0
# K(51)           0.0      0.000000             0.0        0.0              0.0
# K(52)           0.0     -0.441701             0.0        0.0              0.0
# K(53)           0.0      0.000000             0.0        0.0              0.0
# K(54)           0.0      0.000000             0.0        0.0              0.0
# K(55)           0.0      0.000000             0.0        0.0              0.0
# K(56)           0.0     -0.226333             0.0        0.0              0.0
# K(57)           0.0     -0.020991             0.0        0.0              0.0
# K(58)           0.0      0.000000             0.0        0.0              0.0
# K(59)           0.0     -0.056720             0.0        0.0              0.0
# K(60)           0.0     -0.074811             0.0        0.0              0.0
# K(61)           0.0     -0.061243             0.0        0.0              0.0
# K(62)           0.0     -0.020622             0.0        0.0              0.0
# K(63)           0.0      0.000000             0.0        0.0              0.0
# K(64)           0.0      0.000000             0.0        0.0              0.0
# K(65)           0.0     -0.217986             0.0        0.0              0.0
# K(66)           0.0     -0.213164             0.0        0.0              0.0
# K(67)           0.0      0.000000             0.0        0.0              0.0
# K(68)           0.0     -0.270434             0.0        0.0              0.0
# K(69)           0.0      0.000000             0.0        0.0              0.0
# K(70)           0.0      0.000000             0.0        0.0              0.0
# K(71)           0.0      0.000000             0.0        0.0              0.0
# K(72)           0.0     -0.015250             0.0        0.0              0.0
# K(73)           0.0     -0.156218             0.0        0.0              0.0
# K(74)           0.0      0.000000             0.0        0.0              0.0
# K(75)           0.0      0.000000             0.0        0.0              0.0
# K(76)           0.0     -0.027329             0.0        0.0              0.0
# K(77)           0.0     -0.043600             0.0        0.0              0.0
# K(78)           0.0      0.000000             0.0        0.0              0.0
# K(79)           0.0      0.000000             0.0        0.0              0.0
# K(80)           0.0     -0.102446             0.0        0.0              0.0
# K(81)           0.0     -0.036589             0.0        0.0              0.0
# K(82)           0.0      0.000000             0.0        0.0              0.0
# K(83)           0.0      0.000000             0.0        0.0              0.0
# K(84)           0.0      0.000000             0.0        0.0              0.0
# K(85)           0.0     -0.109265             0.0        0.0              0.0
# K(86)           0.0      0.000000             0.0        0.0              0.0
# K(87)           0.0      0.000000             0.0        0.0              0.0
# K(88)           0.0      0.000000             0.0        0.0              0.0
# K(89)           0.0      0.000000             0.0        0.0              0.0
# K(90)           0.0      0.000000             0.0        0.0              0.0
# K(91)           0.0      0.000000             0.0        0.0              0.0
# K(92)           0.0      0.000000             0.0        0.0              0.0
# K(93)           0.0      0.000000             0.0        0.0              0.0
# K(94)           0.0     -0.112362             0.0        0.0              0.0
# K(95)           0.0     -0.105441             0.0        0.0              0.0
# K(96)           0.0      0.000000             0.0        0.0              0.0
# K(97)           0.0      0.000000             0.0        0.0              0.0
# K(98)           0.0      0.000000             0.0        0.0              0.0
# K(99)           0.0     -0.009008             0.0        0.0              0.0
# K(100)          0.0     -0.087350             0.0        0.0              0.0
#
#         mean compactness  mean concavity  mean concave points  mean symmetry  \
# K(1)                 0.0        0.000000            -0.229826            0.0
# K(2)                 0.0        0.000000             0.000000            0.0
# K(3)                 0.0        0.000000            -0.340612            0.0
# K(4)                 0.0        0.000000            -0.102007            0.0
# K(5)                 0.0        0.000000            -0.210871            0.0
# K(6)                 0.0        0.000000            -0.167401            0.0
# K(7)                 0.0        0.000000            -0.243192            0.0
# K(8)                 0.0        0.000000            -0.172554            0.0
# K(9)                 0.0        0.000000            -0.310185            0.0
# K(10)                0.0        0.000000            -0.417659            0.0
# K(11)                0.0        0.000000            -0.815562            0.0
# K(12)                0.0        0.000000            -0.462217            0.0
# K(13)                0.0        0.000000             0.000000            0.0
# K(14)                0.0        0.000000            -0.455536            0.0
# K(15)                0.0        0.000000            -0.333438            0.0
# K(16)                0.0        0.000000            -0.079084            0.0
# K(17)                0.0        0.000000            -0.489580            0.0
# K(18)                0.0        0.000000            -0.118786            0.0
# K(19)                0.0        0.000000            -0.612503            0.0
# K(20)                0.0        0.000000            -0.655706            0.0
# K(21)                0.0        0.000000            -0.474847            0.0
# K(22)                0.0        0.000000            -0.568108            0.0
# K(23)                0.0        0.000000            -0.017290            0.0
# K(24)                0.0        0.000000            -0.426220            0.0
# K(25)                0.0        0.000000            -0.218266            0.0
# K(26)                0.0        0.000000            -0.215138            0.0
# K(27)                0.0        0.000000            -0.583404            0.0
# K(28)                0.0        0.000000            -0.673437            0.0
# K(29)                0.0        0.000000            -0.403367            0.0
# K(30)                0.0        0.000000            -0.151255            0.0
# K(31)                0.0        0.000000            -0.778416            0.0
# K(32)                0.0        0.000000            -0.626361            0.0
# K(33)                0.0        0.000000            -0.305962            0.0
# K(34)                0.0        0.000000            -0.472049            0.0
# K(35)                0.0        0.000000            -0.312701            0.0
# K(36)                0.0        0.000000            -0.427907            0.0
# K(37)                0.0        0.000000            -0.488886            0.0
# K(38)                0.0        0.000000            -0.443406            0.0
# K(39)                0.0        0.000000            -0.040061            0.0
# K(40)                0.0        0.000000            -0.221065            0.0
# K(41)                0.0        0.000000            -0.482130            0.0
# K(42)                0.0        0.000000            -0.641478            0.0
# K(43)                0.0        0.000000            -0.068245            0.0
# K(44)                0.0        0.000000            -0.430873            0.0
# K(45)                0.0        0.000000            -0.473961            0.0
# K(46)                0.0        0.000000            -1.048888            0.0
# K(47)                0.0        0.000000            -0.066583            0.0
# K(48)                0.0        0.000000            -0.638872            0.0
# K(49)                0.0        0.000000            -0.564049            0.0
# K(50)                0.0        0.000000            -0.238618            0.0
# K(51)                0.0        0.000000            -0.291105            0.0
# K(52)                0.0        0.000000            -0.060558            0.0
# K(53)                0.0        0.000000            -0.212603            0.0
# K(54)                0.0        0.000000            -0.251620            0.0
# K(55)                0.0        0.000000            -0.433284            0.0
# K(56)                0.0        0.000000            -0.410820            0.0
# K(57)                0.0        0.000000            -0.548103            0.0
# K(58)                0.0        0.000000            -0.088306            0.0
# K(59)                0.0        0.000000            -0.002334            0.0
# K(60)                0.0        0.000000            -0.457928            0.0
# K(61)                0.0        0.000000            -0.473420            0.0
# K(62)                0.0        0.000000            -0.878927            0.0
# K(63)                0.0        0.000000            -0.382799            0.0
# K(64)                0.0        0.000000            -0.344909            0.0
# K(65)                0.0        0.000000            -0.532470            0.0
# K(66)                0.0        0.000000             0.000000            0.0
# K(67)                0.0        0.000000            -0.142572            0.0
# K(68)                0.0        0.000000            -0.541237            0.0
# K(69)                0.0       -0.094933             0.000000            0.0
# K(70)                0.0        0.000000            -0.663875            0.0
# K(71)                0.0        0.000000            -0.147189            0.0
# K(72)                0.0        0.000000            -0.222170            0.0
# K(73)                0.0        0.000000             0.000000            0.0
# K(74)                0.0        0.000000            -0.376985            0.0
# K(75)                0.0        0.000000            -0.434563            0.0
# K(76)                0.0        0.000000            -0.271995            0.0
# K(77)                0.0        0.000000            -0.306917            0.0
# K(78)                0.0        0.000000            -0.066382            0.0
# K(79)                0.0        0.000000            -0.216654            0.0
# K(80)                0.0        0.000000            -0.293752            0.0
# K(81)                0.0        0.000000            -0.301338            0.0
# K(82)                0.0        0.000000            -0.204350            0.0
# K(83)                0.0        0.000000            -0.336675            0.0
# K(84)                0.0        0.000000            -0.381431            0.0
# K(85)                0.0        0.000000            -0.355025            0.0
# K(86)                0.0        0.000000            -0.242869            0.0
# K(87)                0.0        0.000000            -0.039051            0.0
# K(88)                0.0        0.000000            -0.644357            0.0
# K(89)                0.0        0.000000            -0.191396            0.0
# K(90)                0.0        0.000000            -0.139927            0.0
# K(91)                0.0        0.000000            -0.262187            0.0
# K(92)                0.0        0.000000            -0.372848            0.0
# K(93)                0.0        0.000000            -0.068764            0.0
# K(94)                0.0        0.000000            -0.359797            0.0
# K(95)                0.0        0.000000            -0.026908            0.0
# K(96)                0.0        0.000000            -0.296104            0.0
# K(97)                0.0        0.000000            -0.319384            0.0
# K(98)                0.0        0.000000             0.000000            0.0
# K(99)                0.0        0.000000            -0.776403            0.0
# K(100)               0.0        0.000000            -0.891646            0.0
#
#         mean fractal dimension  radius error  texture error  perimeter error  \
# K(1)                       0.0     -0.143286            0.0              0.0
# K(2)                       0.0     -0.447734            0.0              0.0
# K(3)                       0.0     -0.329611            0.0              0.0
# K(4)                       0.0     -0.413174            0.0              0.0
# K(5)                       0.0     -0.109730            0.0              0.0
# K(6)                       0.0     -0.407118            0.0              0.0
# K(7)                       0.0      0.000000            0.0              0.0
# K(8)                       0.0     -0.309232            0.0              0.0
# K(9)                       0.0      0.000000            0.0              0.0
# K(10)                      0.0      0.000000            0.0              0.0
# K(11)                      0.0      0.000000            0.0              0.0
# K(12)                      0.0     -0.219183            0.0              0.0
# K(13)                      0.0     -0.387812            0.0              0.0
# K(14)                      0.0      0.000000            0.0              0.0
# K(15)                      0.0     -0.303301            0.0              0.0
# K(16)                      0.0     -0.416835            0.0              0.0
# K(17)                      0.0     -0.142543            0.0              0.0
# K(18)                      0.0      0.000000            0.0              0.0
# K(19)                      0.0     -0.048870            0.0              0.0
# K(20)                      0.0     -0.280410            0.0              0.0
# K(21)                      0.0     -0.185179            0.0              0.0
# K(22)                      0.0     -0.200790            0.0              0.0
# K(23)                      0.0      0.000000            0.0              0.0
# K(24)                      0.0     -0.193440            0.0              0.0
# K(25)                      0.0     -0.462124            0.0              0.0
# K(26)                      0.0     -0.383734            0.0              0.0
# K(27)                      0.0     -0.120243            0.0              0.0
# K(28)                      0.0      0.000000            0.0              0.0
# K(29)                      0.0     -0.081752            0.0              0.0
# K(30)                      0.0     -0.392743            0.0              0.0
# K(31)                      0.0      0.000000            0.0              0.0
# K(32)                      0.0      0.000000            0.0              0.0
# K(33)                      0.0     -0.200589            0.0              0.0
# K(34)                      0.0     -0.144128            0.0              0.0
# K(35)                      0.0     -0.097822            0.0              0.0
# K(36)                      0.0     -0.100234            0.0              0.0
# K(37)                      0.0     -0.425099            0.0              0.0
# K(38)                      0.0     -0.267473            0.0              0.0
# K(39)                      0.0      0.000000            0.0              0.0
# K(40)                      0.0     -0.335858            0.0              0.0
# K(41)                      0.0      0.000000            0.0              0.0
# K(42)                      0.0     -0.109117            0.0              0.0
# K(43)                      0.0     -0.369694            0.0              0.0
# K(44)                      0.0     -0.216802            0.0              0.0
# K(45)                      0.0     -0.099765            0.0              0.0
# K(46)                      0.0      0.000000            0.0              0.0
# K(47)                      0.0     -0.050083            0.0              0.0
# K(48)                      0.0      0.000000            0.0              0.0
# K(49)                      0.0     -0.236250            0.0              0.0
# K(50)                      0.0      0.000000            0.0              0.0
# K(51)                      0.0     -0.288441            0.0              0.0
# K(52)                      0.0     -0.109289            0.0              0.0
# K(53)                      0.0     -0.303396            0.0              0.0
# K(54)                      0.0      0.000000            0.0              0.0
# K(55)                      0.0      0.000000            0.0              0.0
# K(56)                      0.0     -0.112668            0.0              0.0
# K(57)                      0.0     -0.088659            0.0              0.0
# K(58)                      0.0     -0.313539            0.0              0.0
# K(59)                      0.0     -0.486765            0.0              0.0
# K(60)                      0.0     -0.274615            0.0              0.0
# K(61)                      0.0     -0.144179            0.0              0.0
# K(62)                      0.0     -0.247560            0.0              0.0
# K(63)                      0.0      0.000000            0.0              0.0
# K(64)                      0.0     -0.006217            0.0              0.0
# K(65)                      0.0     -0.233966            0.0              0.0
# K(66)                      0.0     -0.421948            0.0              0.0
# K(67)                      0.0     -0.140598            0.0              0.0
# K(68)                      0.0      0.000000            0.0              0.0
# K(69)                      0.0     -0.294254            0.0              0.0
# K(70)                      0.0     -0.275323            0.0              0.0
# K(71)                      0.0     -0.197188            0.0              0.0
# K(72)                      0.0     -0.389009            0.0              0.0
# K(73)                      0.0     -0.435869            0.0              0.0
# K(74)                      0.0      0.000000            0.0              0.0
# K(75)                      0.0     -0.296737            0.0              0.0
# K(76)                      0.0     -0.211353            0.0              0.0
# K(77)                      0.0     -0.143369            0.0              0.0
# K(78)                      0.0     -0.218671            0.0              0.0
# K(79)                      0.0     -0.302712            0.0              0.0
# K(80)                      0.0     -0.296611            0.0              0.0
# K(81)                      0.0     -0.139016            0.0              0.0
# K(82)                      0.0     -0.106178            0.0              0.0
# K(83)                      0.0      0.000000            0.0              0.0
# K(84)                      0.0     -0.396248            0.0              0.0
# K(85)                      0.0     -0.216447            0.0              0.0
# K(86)                      0.0      0.000000            0.0              0.0
# K(87)                      0.0     -0.498079            0.0              0.0
# K(88)                      0.0      0.000000            0.0              0.0
# K(89)                      0.0     -0.448249            0.0              0.0
# K(90)                      0.0     -0.321206            0.0              0.0
# K(91)                      0.0     -0.270060            0.0              0.0
# K(92)                      0.0     -0.140317            0.0              0.0
# K(93)                      0.0      0.000000            0.0              0.0
# K(94)                      0.0     -0.199555            0.0              0.0
# K(95)                      0.0     -0.290472            0.0              0.0
# K(96)                      0.0     -0.470659            0.0              0.0
# K(97)                      0.0     -0.305655            0.0              0.0
# K(98)                      0.0     -0.095298            0.0              0.0
# K(99)                      0.0     -0.070123            0.0              0.0
# K(100)                     0.0      0.000000            0.0              0.0
#
#         area error  smoothness error  compactness error  concavity error  \
# K(1)           0.0               0.0                0.0              0.0
# K(2)           0.0               0.0                0.0              0.0
# K(3)           0.0               0.0                0.0              0.0
# K(4)           0.0               0.0                0.0              0.0
# K(5)           0.0               0.0                0.0              0.0
# K(6)           0.0               0.0                0.0              0.0
# K(7)           0.0               0.0                0.0              0.0
# K(8)           0.0               0.0                0.0              0.0
# K(9)           0.0               0.0                0.0              0.0
# K(10)          0.0               0.0                0.0              0.0
# K(11)          0.0               0.0                0.0              0.0
# K(12)          0.0               0.0                0.0              0.0
# K(13)          0.0               0.0                0.0              0.0
# K(14)          0.0               0.0                0.0              0.0
# K(15)          0.0               0.0                0.0              0.0
# K(16)          0.0               0.0                0.0              0.0
# K(17)          0.0               0.0                0.0              0.0
# K(18)          0.0               0.0                0.0              0.0
# K(19)          0.0               0.0                0.0              0.0
# K(20)          0.0               0.0                0.0              0.0
# K(21)          0.0               0.0                0.0              0.0
# K(22)          0.0               0.0                0.0              0.0
# K(23)          0.0               0.0                0.0              0.0
# K(24)          0.0               0.0                0.0              0.0
# K(25)          0.0               0.0                0.0              0.0
# K(26)          0.0               0.0                0.0              0.0
# K(27)          0.0               0.0                0.0              0.0
# K(28)          0.0               0.0                0.0              0.0
# K(29)          0.0               0.0                0.0              0.0
# K(30)          0.0               0.0                0.0              0.0
# K(31)          0.0               0.0                0.0              0.0
# K(32)          0.0               0.0                0.0              0.0
# K(33)          0.0               0.0                0.0              0.0
# K(34)          0.0               0.0                0.0              0.0
# K(35)          0.0               0.0                0.0              0.0
# K(36)          0.0               0.0                0.0              0.0
# K(37)          0.0               0.0                0.0              0.0
# K(38)          0.0               0.0                0.0              0.0
# K(39)          0.0               0.0                0.0              0.0
# K(40)          0.0               0.0                0.0              0.0
# K(41)          0.0               0.0                0.0              0.0
# K(42)          0.0               0.0                0.0              0.0
# K(43)          0.0               0.0                0.0              0.0
# K(44)          0.0               0.0                0.0              0.0
# K(45)          0.0               0.0                0.0              0.0
# K(46)          0.0               0.0                0.0              0.0
# K(47)          0.0               0.0                0.0              0.0
# K(48)          0.0               0.0                0.0              0.0
# K(49)          0.0               0.0                0.0              0.0
# K(50)          0.0               0.0                0.0              0.0
# K(51)          0.0               0.0                0.0              0.0
# K(52)          0.0               0.0                0.0              0.0
# K(53)          0.0               0.0                0.0              0.0
# K(54)          0.0               0.0                0.0              0.0
# K(55)          0.0               0.0                0.0              0.0
# K(56)          0.0               0.0                0.0              0.0
# K(57)          0.0               0.0                0.0              0.0
# K(58)          0.0               0.0                0.0              0.0
# K(59)          0.0               0.0                0.0              0.0
# K(60)          0.0               0.0                0.0              0.0
# K(61)          0.0               0.0                0.0              0.0
# K(62)          0.0               0.0                0.0              0.0
# K(63)          0.0               0.0                0.0              0.0
# K(64)          0.0               0.0                0.0              0.0
# K(65)          0.0               0.0                0.0              0.0
# K(66)          0.0               0.0                0.0              0.0
# K(67)          0.0               0.0                0.0              0.0
# K(68)          0.0               0.0                0.0              0.0
# K(69)          0.0               0.0                0.0              0.0
# K(70)          0.0               0.0                0.0              0.0
# K(71)          0.0               0.0                0.0              0.0
# K(72)          0.0               0.0                0.0              0.0
# K(73)          0.0               0.0                0.0              0.0
# K(74)          0.0               0.0                0.0              0.0
# K(75)          0.0               0.0                0.0              0.0
# K(76)          0.0               0.0                0.0              0.0
# K(77)          0.0               0.0                0.0              0.0
# K(78)          0.0               0.0                0.0              0.0
# K(79)          0.0               0.0                0.0              0.0
# K(80)          0.0               0.0                0.0              0.0
# K(81)          0.0               0.0                0.0              0.0
# K(82)          0.0               0.0                0.0              0.0
# K(83)          0.0               0.0                0.0              0.0
# K(84)          0.0               0.0                0.0              0.0
# K(85)          0.0               0.0                0.0              0.0
# K(86)          0.0               0.0                0.0              0.0
# K(87)          0.0               0.0                0.0              0.0
# K(88)          0.0               0.0                0.0              0.0
# K(89)          0.0               0.0                0.0              0.0
# K(90)          0.0               0.0                0.0              0.0
# K(91)          0.0               0.0                0.0              0.0
# K(92)          0.0               0.0                0.0              0.0
# K(93)          0.0               0.0                0.0              0.0
# K(94)          0.0               0.0                0.0              0.0
# K(95)          0.0               0.0                0.0              0.0
# K(96)          0.0               0.0                0.0              0.0
# K(97)          0.0               0.0                0.0              0.0
# K(98)          0.0               0.0                0.0              0.0
# K(99)          0.0               0.0                0.0              0.0
# K(100)         0.0               0.0                0.0              0.0
#
#         concave points error  symmetry error  fractal dimension error  \
# K(1)                     0.0             0.0                      0.0
# K(2)                     0.0             0.0                      0.0
# K(3)                     0.0             0.0                      0.0
# K(4)                     0.0             0.0                      0.0
# K(5)                     0.0             0.0                      0.0
# K(6)                     0.0             0.0                      0.0
# K(7)                     0.0             0.0                      0.0
# K(8)                     0.0             0.0                      0.0
# K(9)                     0.0             0.0                      0.0
# K(10)                    0.0             0.0                      0.0
# K(11)                    0.0             0.0                      0.0
# K(12)                    0.0             0.0                      0.0
# K(13)                    0.0             0.0                      0.0
# K(14)                    0.0             0.0                      0.0
# K(15)                    0.0             0.0                      0.0
# K(16)                    0.0             0.0                      0.0
# K(17)                    0.0             0.0                      0.0
# K(18)                    0.0             0.0                      0.0
# K(19)                    0.0             0.0                      0.0
# K(20)                    0.0             0.0                      0.0
# K(21)                    0.0             0.0                      0.0
# K(22)                    0.0             0.0                      0.0
# K(23)                    0.0             0.0                      0.0
# K(24)                    0.0             0.0                      0.0
# K(25)                    0.0             0.0                      0.0
# K(26)                    0.0             0.0                      0.0
# K(27)                    0.0             0.0                      0.0
# K(28)                    0.0             0.0                      0.0
# K(29)                    0.0             0.0                      0.0
# K(30)                    0.0             0.0                      0.0
# K(31)                    0.0             0.0                      0.0
# K(32)                    0.0             0.0                      0.0
# K(33)                    0.0             0.0                      0.0
# K(34)                    0.0             0.0                      0.0
# K(35)                    0.0             0.0                      0.0
# K(36)                    0.0             0.0                      0.0
# K(37)                    0.0             0.0                      0.0
# K(38)                    0.0             0.0                      0.0
# K(39)                    0.0             0.0                      0.0
# K(40)                    0.0             0.0                      0.0
# K(41)                    0.0             0.0                      0.0
# K(42)                    0.0             0.0                      0.0
# K(43)                    0.0             0.0                      0.0
# K(44)                    0.0             0.0                      0.0
# K(45)                    0.0             0.0                      0.0
# K(46)                    0.0             0.0                      0.0
# K(47)                    0.0             0.0                      0.0
# K(48)                    0.0             0.0                      0.0
# K(49)                    0.0             0.0                      0.0
# K(50)                    0.0             0.0                      0.0
# K(51)                    0.0             0.0                      0.0
# K(52)                    0.0             0.0                      0.0
# K(53)                    0.0             0.0                      0.0
# K(54)                    0.0             0.0                      0.0
# K(55)                    0.0             0.0                      0.0
# K(56)                    0.0             0.0                      0.0
# K(57)                    0.0             0.0                      0.0
# K(58)                    0.0             0.0                      0.0
# K(59)                    0.0             0.0                      0.0
# K(60)                    0.0             0.0                      0.0
# K(61)                    0.0             0.0                      0.0
# K(62)                    0.0             0.0                      0.0
# K(63)                    0.0             0.0                      0.0
# K(64)                    0.0             0.0                      0.0
# K(65)                    0.0             0.0                      0.0
# K(66)                    0.0             0.0                      0.0
# K(67)                    0.0             0.0                      0.0
# K(68)                    0.0             0.0                      0.0
# K(69)                    0.0             0.0                      0.0
# K(70)                    0.0             0.0                      0.0
# K(71)                    0.0             0.0                      0.0
# K(72)                    0.0             0.0                      0.0
# K(73)                    0.0             0.0                      0.0
# K(74)                    0.0             0.0                      0.0
# K(75)                    0.0             0.0                      0.0
# K(76)                    0.0             0.0                      0.0
# K(77)                    0.0             0.0                      0.0
# K(78)                    0.0             0.0                      0.0
# K(79)                    0.0             0.0                      0.0
# K(80)                    0.0             0.0                      0.0
# K(81)                    0.0             0.0                      0.0
# K(82)                    0.0             0.0                      0.0
# K(83)                    0.0             0.0                      0.0
# K(84)                    0.0             0.0                      0.0
# K(85)                    0.0             0.0                      0.0
# K(86)                    0.0             0.0                      0.0
# K(87)                    0.0             0.0                      0.0
# K(88)                    0.0             0.0                      0.0
# K(89)                    0.0             0.0                      0.0
# K(90)                    0.0             0.0                      0.0
# K(91)                    0.0             0.0                      0.0
# K(92)                    0.0             0.0                      0.0
# K(93)                    0.0             0.0                      0.0
# K(94)                    0.0             0.0                      0.0
# K(95)                    0.0             0.0                      0.0
# K(96)                    0.0             0.0                      0.0
# K(97)                    0.0             0.0                      0.0
# K(98)                    0.0             0.0                      0.0
# K(99)                    0.0             0.0                      0.0
# K(100)                   0.0             0.0                      0.0
#
#         worst radius  worst texture  worst perimeter  worst area  \
# K(1)       -1.579675      -0.416623         0.000000         0.0
# K(2)       -1.619496      -0.259919         0.000000         0.0
# K(3)       -1.478120      -0.448331         0.000000         0.0
# K(4)       -1.516527      -0.370265         0.000000         0.0
# K(5)       -1.718908      -0.473799         0.000000         0.0
# K(6)       -1.577787      -0.384141         0.000000         0.0
# K(7)       -1.753002      -0.449401         0.000000         0.0
# K(8)       -1.648236      -0.398241         0.000000         0.0
# K(9)       -1.617418      -0.471503         0.000000         0.0
# K(10)      -1.477776      -0.479306         0.000000         0.0
# K(11)      -1.608265      -0.416806         0.000000         0.0
# K(12)      -1.434969      -0.494872         0.000000         0.0
# K(13)      -1.443264      -0.313209         0.000000         0.0
# K(14)      -1.721811      -0.480164         0.000000         0.0
# K(15)      -1.532629      -0.524237         0.000000         0.0
# K(16)      -1.023980      -0.296707        -0.573785         0.0
# K(17)      -1.494342      -0.404192         0.000000         0.0
# K(18)      -1.758877      -0.584832         0.000000         0.0
# K(19)      -1.550619      -0.507488         0.000000         0.0
# K(20)      -1.396648      -0.484477         0.000000         0.0
# K(21)      -1.548423      -0.526892         0.000000         0.0
# K(22)      -1.639682      -0.297691         0.000000         0.0
# K(23)      -1.563126      -0.428910        -0.423014         0.0
# K(24)      -1.663474      -0.416254         0.000000         0.0
# K(25)      -1.606889      -0.461093         0.000000         0.0
# K(26)      -1.381517      -0.487778         0.000000         0.0
# K(27)      -1.498143      -0.385486         0.000000         0.0
# K(28)      -1.679437      -0.484082         0.000000         0.0
# K(29)      -1.528033      -0.422606         0.000000         0.0
# K(30)      -1.660806      -0.409759         0.000000         0.0
# K(31)      -1.427997      -0.489716         0.000000         0.0
# K(32)      -1.631896      -0.515998         0.000000         0.0
# K(33)      -1.443859      -0.439079         0.000000         0.0
# K(34)      -1.407968      -0.535150         0.000000         0.0
# K(35)      -1.685590      -0.347028         0.000000         0.0
# K(36)      -1.701816      -0.421269         0.000000         0.0
# K(37)      -1.362074      -0.460546         0.000000         0.0
# K(38)      -1.353550      -0.561769        -0.139839         0.0
# K(39)      -1.855789      -0.428911         0.000000         0.0
# K(40)      -1.458118      -0.486409         0.000000         0.0
# K(41)      -1.718379      -0.379370         0.000000         0.0
# K(42)      -1.317801      -0.487800         0.000000         0.0
# K(43)      -1.709038      -0.327774         0.000000         0.0
# K(44)      -1.497980      -0.534492         0.000000         0.0
# K(45)      -1.664610      -0.361149        -0.059626         0.0
# K(46)      -1.343967      -0.416507        -0.396047         0.0
# K(47)      -1.687424      -0.292700        -0.281489         0.0
# K(48)      -1.491346      -0.434755         0.000000         0.0
# K(49)      -1.684469      -0.440006         0.000000         0.0
# K(50)      -1.569413      -0.520489         0.000000         0.0
# K(51)      -1.425801      -0.496382         0.000000         0.0
# K(52)      -1.623032      -0.106245         0.000000         0.0
# K(53)      -1.508793      -0.467497         0.000000         0.0
# K(54)      -1.732297      -0.443267         0.000000         0.0
# K(55)      -1.542086      -0.404012         0.000000         0.0
# K(56)      -1.511680      -0.224851         0.000000         0.0
# K(57)      -1.542572      -0.521938         0.000000         0.0
# K(58)      -1.445468      -0.428106         0.000000         0.0
# K(59)      -1.337592      -0.421556         0.000000         0.0
# K(60)      -1.415316      -0.489917         0.000000         0.0
# K(61)      -1.354019      -0.383424         0.000000         0.0
# K(62)      -1.417045      -0.443321         0.000000         0.0
# K(63)      -1.559565      -0.534508         0.000000         0.0
# K(64)      -1.651164      -0.517132         0.000000         0.0
# K(65)      -1.723979      -0.296274         0.000000         0.0
# K(66)      -1.731694      -0.191457         0.000000         0.0
# K(67)      -1.778892      -0.390332         0.000000         0.0
# K(68)      -1.859724      -0.142748         0.000000         0.0
# K(69)      -1.737188      -0.401215         0.000000         0.0
# K(70)      -1.370724      -0.478747         0.000000         0.0
# K(71)      -1.639733      -0.604309         0.000000         0.0
# K(72)      -1.438885      -0.344713         0.000000         0.0
# K(73)      -1.667768      -0.322760         0.000000         0.0
# K(74)      -1.518576      -0.528854         0.000000         0.0
# K(75)      -1.439830      -0.533748         0.000000         0.0
# K(76)      -1.484492      -0.544403         0.000000         0.0
# K(77)      -1.722501      -0.491848         0.000000         0.0
# K(78)      -1.648860      -0.574699         0.000000         0.0
# K(79)      -1.512451      -0.338719         0.000000         0.0
# K(80)      -1.845715      -0.243043         0.000000         0.0
# K(81)      -1.467308      -0.481174         0.000000         0.0
# K(82)      -1.689356      -0.447709         0.000000         0.0
# K(83)      -1.632242      -0.595443         0.000000         0.0
# K(84)      -1.379736      -0.505052         0.000000         0.0
# K(85)      -1.572858      -0.425560         0.000000         0.0
# K(86)      -1.565548      -0.458050         0.000000         0.0
# K(87)      -1.573084      -0.480535         0.000000         0.0
# K(88)      -1.461117      -0.330496         0.000000         0.0
# K(89)      -1.414371      -0.461852         0.000000         0.0
# K(90)      -1.331707      -0.481437        -0.324295         0.0
# K(91)      -1.571611      -0.470303         0.000000         0.0
# K(92)      -1.609776      -0.480590         0.000000         0.0
# K(93)      -1.696210      -0.402038         0.000000         0.0
# K(94)      -1.512944      -0.337324         0.000000         0.0
# K(95)      -1.588572      -0.402930         0.000000         0.0
# K(96)      -0.836960      -0.583489        -0.497479         0.0
# K(97)      -1.271150      -0.495380         0.000000         0.0
# K(98)      -1.799134      -0.482420         0.000000         0.0
# K(99)      -1.188161      -0.355527        -0.193987         0.0
# K(100)     -1.646361      -0.389519         0.000000         0.0
#
#         worst smoothness  worst compactness  worst concavity  \
# K(1)           -0.025843                0.0         0.000000
# K(2)           -0.124231                0.0         0.000000
# K(3)           -0.181483                0.0         0.000000
# K(4)           -0.099848                0.0         0.000000
# K(5)           -0.003581                0.0         0.000000
# K(6)            0.000000                0.0         0.000000
# K(7)           -0.143939                0.0         0.000000
# K(8)            0.000000                0.0         0.000000
# K(9)           -0.063717                0.0         0.000000
# K(10)           0.000000                0.0         0.000000
# K(11)           0.000000                0.0         0.000000
# K(12)          -0.037209                0.0         0.000000
# K(13)           0.000000                0.0        -0.027677
# K(14)          -0.072567                0.0         0.000000
# K(15)          -0.043437                0.0         0.000000
# K(16)           0.000000                0.0         0.000000
# K(17)           0.000000                0.0         0.000000
# K(18)           0.000000                0.0         0.000000
# K(19)          -0.094354                0.0         0.000000
# K(20)           0.000000                0.0         0.000000
# K(21)          -0.102476                0.0         0.000000
# K(22)          -0.111319                0.0         0.000000
# K(23)           0.000000                0.0        -0.073601
# K(24)           0.000000                0.0         0.000000
# K(25)          -0.019455                0.0         0.000000
# K(26)          -0.058633                0.0         0.000000
# K(27)          -0.052071                0.0         0.000000
# K(28)           0.000000                0.0         0.000000
# K(29)           0.000000                0.0         0.000000
# K(30)           0.000000                0.0        -0.027568
# K(31)           0.000000                0.0         0.000000
# K(32)           0.000000                0.0         0.000000
# K(33)           0.000000                0.0         0.000000
# K(34)           0.000000                0.0         0.000000
# K(35)          -0.126616                0.0         0.000000
# K(36)          -0.115980                0.0        -0.050359
# K(37)           0.000000                0.0         0.000000
# K(38)          -0.005010                0.0         0.000000
# K(39)           0.000000                0.0         0.000000
# K(40)          -0.128620                0.0         0.000000
# K(41)           0.000000                0.0        -0.179114
# K(42)           0.000000                0.0         0.000000
# K(43)           0.000000                0.0         0.000000
# K(44)          -0.059144                0.0         0.000000
# K(45)          -0.065138                0.0         0.000000
# K(46)          -0.030678                0.0         0.000000
# K(47)          -0.126784                0.0         0.000000
# K(48)           0.000000                0.0         0.000000
# K(49)          -0.190976                0.0         0.000000
# K(50)           0.000000                0.0         0.000000
# K(51)          -0.092817                0.0         0.000000
# K(52)           0.000000                0.0         0.000000
# K(53)           0.000000                0.0         0.000000
# K(54)           0.000000                0.0         0.000000
# K(55)           0.000000                0.0        -0.002187
# K(56)           0.000000                0.0         0.000000
# K(57)           0.000000                0.0         0.000000
# K(58)           0.000000                0.0         0.000000
# K(59)           0.000000                0.0         0.000000
# K(60)           0.000000                0.0         0.000000
# K(61)           0.000000                0.0         0.000000
# K(62)           0.000000                0.0         0.000000
# K(63)           0.000000                0.0         0.000000
# K(64)           0.000000                0.0         0.000000
# K(65)           0.000000                0.0         0.000000
# K(66)          -0.091435                0.0        -0.027048
# K(67)           0.000000                0.0         0.000000
# K(68)          -0.011742                0.0         0.000000
# K(69)           0.000000                0.0         0.000000
# K(70)          -0.047114                0.0         0.000000
# K(71)           0.000000                0.0         0.000000
# K(72)           0.000000                0.0         0.000000
# K(73)          -0.010945                0.0         0.000000
# K(74)           0.000000                0.0         0.000000
# K(75)          -0.033165                0.0         0.000000
# K(76)           0.000000                0.0         0.000000
# K(77)          -0.056164                0.0         0.000000
# K(78)           0.000000                0.0         0.000000
# K(79)          -0.040020                0.0         0.000000
# K(80)           0.000000                0.0         0.000000
# K(81)           0.000000                0.0         0.000000
# K(82)           0.000000                0.0         0.000000
# K(83)          -0.001649                0.0         0.000000
# K(84)           0.000000                0.0         0.000000
# K(85)          -0.071787                0.0         0.000000
# K(86)          -0.059506                0.0         0.000000
# K(87)           0.000000                0.0         0.000000
# K(88)          -0.153294                0.0         0.000000
# K(89)          -0.069129                0.0         0.000000
# K(90)           0.000000                0.0         0.000000
# K(91)           0.000000                0.0         0.000000
# K(92)           0.000000                0.0         0.000000
# K(93)          -0.116678                0.0         0.000000
# K(94)          -0.054653                0.0         0.000000
# K(95)          -0.112618                0.0         0.000000
# K(96)          -0.030416                0.0         0.000000
# K(97)          -0.012860                0.0         0.000000
# K(98)           0.000000                0.0         0.000000
# K(99)           0.000000                0.0         0.000000
# K(100)         -0.060655                0.0         0.000000
#
#         worst concave points  worst symmetry  worst fractal dimension
# K(1)               -1.266276       -0.192931                      0.0
# K(2)               -1.299405       -0.057995                      0.0
# K(3)               -1.089980       -0.007387                      0.0
# K(4)               -1.407050        0.000000                      0.0
# K(5)               -1.258316       -0.091018                      0.0
# K(6)               -1.368595       -0.051803                      0.0
# K(7)               -1.284944        0.000000                      0.0
# K(8)               -1.301600       -0.089727                      0.0
# K(9)               -1.299251       -0.096562                      0.0
# K(10)              -1.296641       -0.188215                      0.0
# K(11)              -0.931599       -0.163637                      0.0
# K(12)              -1.053066       -0.154179                      0.0
# K(13)              -1.462461       -0.123126                      0.0
# K(14)              -1.209419       -0.192355                      0.0
# K(15)              -1.124671       -0.066184                      0.0
# K(16)              -1.217439       -0.218731                      0.0
# K(17)              -1.202990       -0.126327                      0.0
# K(18)              -1.459996       -0.218239                      0.0
# K(19)              -1.018198       -0.098074                      0.0
# K(20)              -1.060290       -0.054687                      0.0
# K(21)              -1.023937       -0.024907                      0.0
# K(22)              -0.839315       -0.074461                      0.0
# K(23)              -1.368254       -0.200039                      0.0
# K(24)              -1.115838       -0.160598                      0.0
# K(25)              -1.066913       -0.150517                      0.0
# K(26)              -1.293947       -0.129542                      0.0
# K(27)              -1.082965       -0.038157                      0.0
# K(28)              -0.960322       -0.205608                      0.0
# K(29)              -1.287371       -0.093121                      0.0
# K(30)              -1.330741        0.000000                      0.0
# K(31)              -0.960574       -0.134685                      0.0
# K(32)              -1.101991       -0.230997                      0.0
# K(33)              -1.432830        0.000000                      0.0
# K(34)              -1.273811        0.000000                      0.0
# K(35)              -1.249815       -0.060958                      0.0
# K(36)              -0.983556       -0.115922                      0.0
# K(37)              -1.179587       -0.106221                      0.0
# K(38)              -1.115826       -0.151087                      0.0
# K(39)              -1.479803       -0.247862                      0.0
# K(40)              -1.289048       -0.013897                      0.0
# K(41)              -0.948404       -0.110201                      0.0
# K(42)              -1.123823       -0.151782                      0.0
# K(43)              -1.378245       -0.247611                      0.0
# K(44)              -1.095756       -0.036220                      0.0
# K(45)              -1.037787       -0.198123                      0.0
# K(46)              -0.567860       -0.182791                      0.0
# K(47)              -1.316870       -0.268547                      0.0
# K(48)              -1.163026       -0.134095                      0.0
# K(49)              -0.746428       -0.013065                      0.0
# K(50)              -1.416740       -0.117403                      0.0
# K(51)              -1.323833        0.000000                      0.0
# K(52)              -1.602743       -0.130238                      0.0
# K(53)              -1.290802       -0.070156                      0.0
# K(54)              -1.417540       -0.057238                      0.0
# K(55)              -1.359393       -0.151221                      0.0
# K(56)              -1.294370       -0.099720                      0.0
# K(57)              -0.970201       -0.194212                      0.0
# K(58)              -1.535480       -0.038723                      0.0
# K(59)              -1.468589       -0.180667                      0.0
# K(60)              -1.097738       -0.163779                      0.0
# K(61)              -1.225172       -0.194222                      0.0
# K(62)              -0.890644        0.000000                      0.0
# K(63)              -1.310913       -0.087905                      0.0
# K(64)              -1.219973       -0.139630                      0.0
# K(65)              -0.862369       -0.147944                      0.0
# K(66)              -1.215346       -0.081269                      0.0
# K(67)              -1.268011       -0.229751                      0.0
# K(68)              -0.973611       -0.188638                      0.0
# K(69)              -1.336530       -0.114386                      0.0
# K(70)              -1.010227       -0.012529                      0.0
# K(71)              -1.232032       -0.109819                      0.0
# K(72)              -1.393441       -0.209539                      0.0
# K(73)              -1.226662       -0.154547                      0.0
# K(74)              -1.337222       -0.094866                      0.0
# K(75)              -1.027440       -0.184080                      0.0
# K(76)              -1.303037       -0.048173                      0.0
# K(77)              -1.111442       -0.136894                      0.0
# K(78)              -1.491725       -0.012743                      0.0
# K(79)              -1.303237       -0.158309                      0.0
# K(80)              -1.009676       -0.187048                      0.0
# K(81)              -1.296458       -0.137297                      0.0
# K(82)              -1.183180       -0.156265                      0.0
# K(83)              -1.436051       -0.065629                      0.0
# K(84)              -1.161719       -0.134947                      0.0
# K(85)              -1.139342       -0.132671                      0.0
# K(86)              -1.449285       -0.171255                      0.0
# K(87)              -1.334446       -0.103899                      0.0
# K(88)              -1.248227        0.000000                      0.0
# K(89)              -1.219289       -0.127438                      0.0
# K(90)              -1.257642       -0.172309                      0.0
# K(91)              -1.340057       -0.023832                      0.0
# K(92)              -1.146774       -0.110272                      0.0
# K(93)              -1.489605       -0.120140                      0.0
# K(94)              -1.214462       -0.140827                      0.0
# K(95)              -1.389183       -0.002128                      0.0
# K(96)              -1.155142       -0.157307                      0.0
# K(97)              -1.375209       -0.125357                      0.0
# K(98)              -1.432876       -0.250486                      0.0
# K(99)              -1.211491       -0.100882                      0.0
# K(100)             -0.861866       -0.087242                      0.0

# %% [markdown]
# We assign this array to a variable and plot weight distributions of specific feautures using histograms

# %%
weight_dist = analysis.get_weight_distributions()

# %% [markdown]
# Plot the weight distribution of feature at index 27, that is `worst concave points`. This feature is selected very often as we can see that most of the weights are different from zero and negative.

# %%
import seaborn as sns
ax = sns.distplot(weight_dist.values[:, 27], kde=False)

# %% [markdown]
# All of the weights of feature at index 23 (`worst area`) are zero, meaning that this feature is not important for the model.

# %%
ax = sns.distplot(weight_dist.values[:, 23], kde=False)

# %% [markdown]
# ### Investigation of class predictions

# %% [markdown]
# Since we use an ensemble of models, we can predict the class of the validations samples during the RENT process. We can get more details by calling `.summery_objects()` which will return a data frame holding all predictions.
#
# In the example below we can see that patient 489 was 25 times (out of K=100 models in the ensemble) in the validation set (column `# test`). That means we get 25 predictions from 25 unique models and investigate how well predictions worked for this patient. Patient 489 belongs to class 0 (column `class`) and was predictied incorrectly 25 times (column `# incorrect`) out of 25 predictions, which results in 100% incorrect classifications (column `% incorrect`).
#
# Looking at this dataframe we can see that most of the patients were predicted correctly every time, however, there are some patients that were predicted incorrectly every time (patients 38, 135, 81, 255, 297, 73, 40, 13, 86, 41). It might be worth investigating why it is so difficult predict the correct class for these patients by comparing them to patients from the same class that are predicted correctly most or all of the times. We will do this using PCA further below in this notebook.

# %%
analysis.summary_objects()
# Out:
#      # test  class  # incorrect  % incorrect
# 293      27      1            0     0.000000
# 332      30      1            0     0.000000
# 565      30      0            0     0.000000
# 278      35      1            0     0.000000
# 489      26      0           25    96.153846
# 346      35      1            0     0.000000
# 357      21      1            0     0.000000
# 355      21      1            0     0.000000
# 112      20      1            4    20.000000
# 68       26      1            0     0.000000
# 526      20      1            0     0.000000
# 206      24      1            0     0.000000
# 65       25      0            0     0.000000
# 437      13      1            0     0.000000
# 126      21      0            1     4.761905
# 429      22      1            0     0.000000
# 392      23      0            0     0.000000
# 343      26      0            0     0.000000
# 334      22      1            0     0.000000
# 440      20      1            0     0.000000
# 441      21      0            0     0.000000
# 137      32      1            0     0.000000
# 230      19      0            0     0.000000
# 7        27      0            0     0.000000
# 408      32      0            0     0.000000
# 523      22      1            0     0.000000
# 361      23      1            0     0.000000
# 553      25      1            0     0.000000
# 478      21      1            0     0.000000
# 303      18      1            0     0.000000
# 155      28      1            0     0.000000
# 186      24      0            0     0.000000
# 101      25      1            0     0.000000
# 97       23      1            0     0.000000
# 20       32      1            0     0.000000
# 153      31      1            0     0.000000
# 54       27      0            0     0.000000
# 30       28      0            0     0.000000
# 531      19      1            0     0.000000
# 49       23      1            0     0.000000
# 100      24      0            3    12.500000
# 336      23      1            0     0.000000
# 299      28      1            0     0.000000
# 347      32      1            0     0.000000
# 502      24      1            0     0.000000
# 56       23      0            0     0.000000
# 144      22      1            0     0.000000
# 60       28      1            0     0.000000
# 6        20      0            0     0.000000
# 8        27      0            0     0.000000
# 474      23      1            0     0.000000
# 320      25      1            0     0.000000
# 252      21      0            0     0.000000
# 202      21      0            0     0.000000
# 246      20      1            0     0.000000
# 240      18      1            0     0.000000
# 38       22      0           22   100.000000
# 436      25      1            0     0.000000
# 390      27      1            0     0.000000
# 261      22      0           14    63.636364
# 339      24      0            0     0.000000
# 282      23      0            0     0.000000
# 276      21      1            0     0.000000
# 367      26      1            0     0.000000
# 505      30      1            0     0.000000
# 499      25      0            0     0.000000
# 124      36      1            0     0.000000
# 154      26      1            0     0.000000
# 316      25      1            0     0.000000
# 59       29      1            0     0.000000
# 333      29      1            0     0.000000
# 503      26      0            0     0.000000
# 534      22      1            0     0.000000
# 563      33      0            0     0.000000
# 453      29      1            0     0.000000
# 262      13      0            0     0.000000
# 378      34      1            0     0.000000
# 229      26      0            0     0.000000
# 55       22      1            0     0.000000
# 171      26      0           14    53.846154
# 454      26      1            0     0.000000
# 243      21      1            0     0.000000
# 158      27      1            0     0.000000
# 415      31      1            0     0.000000
# 34       25      0            0     0.000000
# 561      26      1            0     0.000000
# 18       22      0            0     0.000000
# 508      23      1            0     0.000000
# 322      24      1            0     0.000000
# 51       22      1            0     0.000000
# 219      26      0            0     0.000000
# 549      28      1            0     0.000000
# 52       27      1            0     0.000000
# 74       27      1            0     0.000000
# 26       22      0            0     0.000000
# 173      24      1            0     0.000000
# 92       17      1            0     0.000000
# 167      25      0            0     0.000000
# 4        29      0            0     0.000000
# 409      29      1            0     0.000000
# 181      25      0            0     0.000000
# 245      24      1            0     0.000000
# 379      18      0            0     0.000000
# 425      22      1            0     0.000000
# 479      24      0            0     0.000000
# 5        30      0            0     0.000000
# 141      28      0            0     0.000000
# 329      31      0           25    80.645161
# 200      23      1            0     0.000000
# 135      26      0           26   100.000000
# 285      24      1            0     0.000000
# 122      26      0            0     0.000000
# 484      24      1            0     0.000000
# 22       22      0            0     0.000000
# 220      19      1            0     0.000000
# 517      22      0            0     0.000000
# 120      24      1            0     0.000000
# 81       24      1           21    87.500000
# 487      27      0            0     0.000000
# 464      21      1            0     0.000000
# 554      34      1            0     0.000000
# 548      21      1            0     0.000000
# 160      24      1            0     0.000000
# 557      30      1            0     0.000000
# 238      21      1            0     0.000000
# 284      28      1            0     0.000000
# 315      27      1            0     0.000000
# 195      22      1            0     0.000000
# 191      24      1            0     0.000000
# 116      28      1            0     0.000000
# 477      24      1            0     0.000000
# 428      23      1            0     0.000000
# 164      22      0            0     0.000000
# 106      27      1            0     0.000000
# 403      23      1            0     0.000000
# 63       30      1            0     0.000000
# 105      26      0            0     0.000000
# 312      25      1            0     0.000000
# 555      30      1            0     0.000000
# 481      22      1            0     0.000000
# 344      31      1            0     0.000000
# 93       30      1            0     0.000000
# 395      16      1            0     0.000000
# 393      27      0            0     0.000000
# 381      28      1            0     0.000000
# 198      28      0            0     0.000000
# 145      21      1            0     0.000000
# 150      33      1            0     0.000000
# 39       25      0            0     0.000000
# 520      33      1            0     0.000000
# 351      25      0            0     0.000000
# 253      28      0            0     0.000000
# 467      24      1            0     0.000000
# 501      25      0            0     0.000000
# 2        26      0            0     0.000000
# 221      29      1            0     0.000000
# 532      26      1            0     0.000000
# 146      27      0            6    22.222222
# 289      25      1            0     0.000000
# 241      20      1            0     0.000000
# 342      25      1            0     0.000000
# 433      26      0            0     0.000000
# 114      33      1            0     0.000000
# 311      27      1            0     0.000000
# 399      28      1            0     0.000000
# 176      30      1            0     0.000000
# 491      23      1            0     0.000000
# 168      20      0            0     0.000000
# 365      29      0            0     0.000000
# 539      33      1            0     0.000000
# 506      29      1            0     0.000000
# 426      25      1            0     0.000000
# 136      24      1            0     0.000000
# 444      23      0            0     0.000000
# 254      29      0            0     0.000000
# 362      32      1            0     0.000000
# 386      21      1            0     0.000000
# 494      25      1            0     0.000000
# 452      16      1            0     0.000000
# 255      33      0           33   100.000000
# 232      25      1            0     0.000000
# 133      20      1            0     0.000000
# 33       26      0            0     0.000000
# 88       19      1            0     0.000000
# 290      26      1            0     0.000000
# 44       28      0            0     0.000000
# 61       22      1            0     0.000000
# 199      26      0            0     0.000000
# 375      25      1            0     0.000000
# 545      32      1            0     0.000000
# 530      23      1            0     0.000000
# 424      20      1            0     0.000000
# 218      30      0            0     0.000000
# 302      29      0            0     0.000000
# 297      28      0           28   100.000000
# 73       20      0           20   100.000000
# 295      17      1            0     0.000000
# 35       26      0            0     0.000000
# 493      22      1            0     0.000000
# 29       22      0            0     0.000000
# 460      28      0            0     0.000000
# 438      25      1            0     0.000000
# 445      32      1            0     0.000000
# 309      27      1            0     0.000000
# 541      15      1            1     6.666667
# 217      23      1            0     0.000000
# 27       27      0            0     0.000000
# 462      30      1            0     0.000000
# 376      25      1            0     0.000000
# 156      29      0            0     0.000000
# 552      22      1            0     0.000000
# 475      23      1            0     0.000000
# 138      26      0            0     0.000000
# 212      35      0            0     0.000000
# 104      19      1            0     0.000000
# 447      33      1            0     0.000000
# 443      21      1            0     0.000000
# 449      24      0            0     0.000000
# 215      26      0            1     3.846154
# 496      21      1            0     0.000000
# 189      30      1            0     0.000000
# 214      28      0            0     0.000000
# 524      28      1            0     0.000000
# 204      33      1            0     0.000000
# 234      23      1            0     0.000000
# 259      21      0            0     0.000000
# 67       27      1            0     0.000000
# 24       22      0            0     0.000000
# 216      21      1            0     0.000000
# 300      21      0            0     0.000000
# 223      21      0            0     0.000000
# 129      38      0            0     0.000000
# 533      25      0            0     0.000000
# 111      20      1            0     0.000000
# 166      26      1            0     0.000000
# 267      23      1            0     0.000000
# 507      36      1            0     0.000000
# 40       23      0           23   100.000000
# 274      16      0            0     0.000000
# 455      25      1            0     0.000000
# 79       24      1            0     0.000000
# 402      19      1            0     0.000000
# 404      24      1            0     0.000000
# 327      27      1            0     0.000000
# 13       30      0           30   100.000000
# 287      20      1            0     0.000000
# 326      18      1            0     0.000000
# 121      32      0            0     0.000000
# 251      21      1            0     0.000000
# 228      19      1            0     0.000000
# 498      28      0            0     0.000000
# 161      21      0            0     0.000000
# 83       23      0            0     0.000000
# 117      27      0            0     0.000000
# 374      23      1            0     0.000000
# 407      26      1            0     0.000000
# 25       23      0            0     0.000000
# 110      27      1            0     0.000000
# 149      21      1            0     0.000000
# 152      26      1            0     0.000000
# 16       18      0            0     0.000000
# 435      25      0            0     0.000000
# 331      29      1            0     0.000000
# 109      28      1            0     0.000000
# 470      30      1            0     0.000000
# 450      30      1            0     0.000000
# 139      22      1            0     0.000000
# 237      22      0            0     0.000000
# 260      19      0            0     0.000000
# 352      29      0            0     0.000000
# 456      24      1            0     0.000000
# 317      22      0            0     0.000000
# 323      26      0            0     0.000000
# 513      34      1            0     0.000000
# 248      30      1            0     0.000000
# 410      19      1            0     0.000000
# 422      22      1            0     0.000000
# 497      26      1            0     0.000000
# 19       23      1            0     0.000000
# 328      21      0            0     0.000000
# 296      31      1            0     0.000000
# 483      26      1            0     0.000000
# 269      23      1            0     0.000000
# 363      24      1            0     0.000000
# 226      20      1            0     0.000000
# 495      23      1            0     0.000000
# 3        25      0            0     0.000000
# 446      20      0            0     0.000000
# 125      25      1            0     0.000000
# 280      21      0            0     0.000000
# 286      14      1            0     0.000000
# 77       27      0            0     0.000000
# 184      29      0           24    82.758621
# 371      18      1            0     0.000000
# 485      33      1            0     0.000000
# 556      24      1            0     0.000000
# 275      21      1            0     0.000000
# 294      16      1            0     0.000000
# 535      31      0            0     0.000000
# 182      28      0            0     0.000000
# 32       28      0            0     0.000000
# 80       19      1            0     0.000000
# 307      30      1            0     0.000000
# 258      30      0            0     0.000000
# 11       18      0            0     0.000000
# 360      28      1            0     0.000000
# 476      21      1            0     0.000000
# 86       27      0           27   100.000000
# 266      23      1            0     0.000000
# 36       28      0            0     0.000000
# 193      29      0            0     0.000000
# 58       30      1            0     0.000000
# 41       25      0           25   100.000000
# 270      24      1            0     0.000000
# 411      27      1            0     0.000000
# 50       23      1            0     0.000000
# 209      34      1            0     0.000000
# 511      29      1            0     0.000000
# 540      19      1            0     0.000000
# 522      29      1            0     0.000000
# 521      25      0            0     0.000000
# 451      30      0            0     0.000000
# 123      20      1            0     0.000000
# 222      27      1            0     0.000000
# 419      27      1            0     0.000000
# 62       20      0            0     0.000000
# 568      21      1            0     0.000000
# 377      26      1            0     0.000000
# 130      29      1            0     0.000000
# 187      29      1            0     0.000000
# 23       27      0            0     0.000000
# 480      28      1            0     0.000000
# 509      29      0            0     0.000000
# 43       24      0            0     0.000000
# 370      21      0            0     0.000000
# 394      32      1            0     0.000000
# 0        32      0            0     0.000000
# 383      32      1            0     0.000000
# 201      27      0            0     0.000000
# 405      33      1            0     0.000000
# 368      26      0            0     0.000000
# 461      25      0            0     0.000000
# 529      15      1            0     0.000000
# 98       21      1            0     0.000000
# 387      26      1            0     0.000000
# 349      22      1            0     0.000000
# 304      24      1            0     0.000000
# 418      29      1            0     0.000000
# 292      26      1            0     0.000000
# 178      21      1            0     0.000000
# 369      20      0            0     0.000000
# 256      27      0            0     0.000000
# 94       21      0            0     0.000000
# 197      32      0           22    68.750000
# 95       30      0            0     0.000000
# 558      25      1            0     0.000000
# 163      25      1            0     0.000000
# 169      24      1            0     0.000000
# 69       31      1            0     0.000000
# 305      27      1            0     0.000000
# 48       28      1            0     0.000000
# 341      25      1            0     0.000000
# 373      23      0            0     0.000000
# 397      26      1            0     0.000000
# 207      24      0            0     0.000000
# 279      20      1            0     0.000000
# 528      22      1            0     0.000000
# 227      27      1            0     0.000000
# 148      24      1            0     0.000000
# 143      27      1            0     0.000000
# 180      24      0            0     0.000000
# 131      22      0            0     0.000000
# 47       25      0            0     0.000000
# 324      22      1            0     0.000000
# 203      30      0            0     0.000000
# 84       27      1            0     0.000000
# 398      26      1            0     0.000000
# 91       25      0           10    40.000000
# 82       18      0            0     0.000000
# 430      24      0            0     0.000000
# 119      30      0            0     0.000000
# 291      32      1            6    18.750000
# 57       23      0            0     0.000000
# 321      26      0            0     0.000000
# 257      26      0            0     0.000000
# 442      23      1            0     0.000000
# 42       21      0            0     0.000000
# 388      28      1            0     0.000000
# 335      23      0            0     0.000000
# 273      23      1            0     0.000000
# 488      19      1            0     0.000000
# 53       27      0            0     0.000000
# 536      23      0           18    78.260870
# 128      26      1            1     3.846154
# 28       20      0            0     0.000000
# 183      21      1            0     0.000000
# 459      31      1            0     0.000000
# 510      21      1            0     0.000000
# 151      29      1            0     0.000000
# 244      18      0            0     0.000000
# 543      27      1            0     0.000000
# 544      31      1            0     0.000000
# 265      26      0            0     0.000000
# 288      24      1            0     0.000000
# 423      20      1            0     0.000000
# 147      23      1            0     0.000000
# 177      25      0            0     0.000000
# 99       31      0            0     0.000000
# 448      25      1            0     0.000000
# 431      27      1            0     0.000000
# 115      26      1            0     0.000000
# 72       21      0            0     0.000000
# 537      26      1            0     0.000000
# 174      27      1            0     0.000000
# 87       26      0            0     0.000000
# 551      29      1            0     0.000000
# 486      27      1            0     0.000000
# 314      29      1            0     0.000000
# 396      19      1            0     0.000000
# 472      22      1            0     0.000000
# 70       26      0            0     0.000000
# 277      24      0            0     0.000000
# 9        24      0            0     0.000000
# 359      33      1            0     0.000000
# 192      23      1            0     0.000000
# 559      21      1            0     0.000000

# %% [markdown]
# We can also extract the class probabilities for each prediction by calling `.get_object_probabilities`.

# %%
analysis.get_object_probabilities()
# Out:
#          K(1)      K(2)      K(3)      K(4)      K(5)      K(6)      K(7)  \
# 293  0.914650       NaN  0.923988       NaN       NaN       NaN       NaN
# 332       NaN  0.981868       NaN       NaN       NaN       NaN       NaN
# 565  0.022534       NaN       NaN  0.013624       NaN       NaN  0.010327
# 278  0.932959       NaN       NaN       NaN  0.927506  0.934975  0.928161
# 489       NaN       NaN  0.710917  0.675734  0.521655  0.615095       NaN
# 346  0.953079       NaN       NaN       NaN       NaN       NaN  0.957186
# 357       NaN  0.936201       NaN       NaN       NaN       NaN  0.933928
# 355       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 112       NaN       NaN       NaN  0.625468       NaN       NaN       NaN
# 68        NaN       NaN       NaN       NaN  0.856925  0.816958       NaN
# 526  0.624215  0.640460       NaN  0.663695       NaN       NaN       NaN
# 206  0.983825       NaN       NaN  0.987144       NaN       NaN       NaN
# 65   0.194685       NaN  0.184515       NaN       NaN       NaN       NaN
# 437       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 126       NaN       NaN       NaN       NaN       NaN       NaN  0.374165
# 429       NaN       NaN  0.976391       NaN       NaN  0.977796       NaN
# 392       NaN       NaN       NaN       NaN  0.026085       NaN       NaN
# 343  0.007601  0.009394       NaN       NaN       NaN       NaN       NaN
# 334       NaN       NaN  0.966063       NaN       NaN       NaN       NaN
# 440       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 441       NaN       NaN       NaN       NaN       NaN       NaN  0.053333
# 137       NaN  0.965363  0.961978       NaN       NaN  0.962615       NaN
# 230       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7         NaN       NaN  0.281366       NaN  0.325197       NaN       NaN
# 408       NaN       NaN  0.069812  0.052739       NaN  0.053302       NaN
# 523       NaN       NaN       NaN  0.709737  0.727336       NaN       NaN
# 361       NaN  0.932132       NaN       NaN       NaN       NaN  0.927696
# 553       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 478       NaN       NaN  0.964612       NaN       NaN       NaN       NaN
# 303       NaN  0.980091       NaN       NaN       NaN       NaN       NaN
# 155       NaN  0.930660       NaN  0.937059       NaN       NaN       NaN
# 186  0.143217       NaN       NaN       NaN       NaN       NaN       NaN
# 101       NaN       NaN       NaN       NaN       NaN       NaN  0.998870
# 97        NaN       NaN       NaN  0.989134  0.991671       NaN       NaN
# 20        NaN       NaN       NaN  0.948737  0.938684  0.944400       NaN
# 153       NaN  0.984442       NaN  0.987091       NaN  0.986594       NaN
# 54   0.309600       NaN       NaN       NaN  0.270090       NaN       NaN
# 30        NaN       NaN       NaN       NaN       NaN  0.010350       NaN
# 531       NaN       NaN  0.902522       NaN       NaN       NaN       NaN
# 49        NaN       NaN       NaN       NaN       NaN       NaN  0.635765
# 100  0.459731  0.415691  0.445733  0.416359       NaN  0.434021       NaN
# 336       NaN       NaN  0.976454       NaN       NaN       NaN  0.977550
# 299       NaN       NaN  0.987550       NaN       NaN       NaN       NaN
# 347       NaN  0.667493       NaN       NaN       NaN  0.677607       NaN
# 502       NaN       NaN       NaN  0.935145       NaN       NaN       NaN
# 56        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 144       NaN       NaN       NaN  0.990032  0.990295  0.989428       NaN
# 60        NaN       NaN  0.989924       NaN  0.993665  0.990874  0.991883
# 6         NaN       NaN       NaN       NaN       NaN  0.031516  0.026748
# 8         NaN       NaN  0.180016       NaN       NaN       NaN  0.168586
# 474  0.974240  0.974560       NaN       NaN       NaN  0.977059       NaN
# 320       NaN       NaN       NaN       NaN       NaN       NaN  0.962399
# 252       NaN       NaN       NaN       NaN  0.003811       NaN       NaN
# 202       NaN  0.001604       NaN       NaN  0.001060  0.001195       NaN
# 246  0.950920       NaN       NaN  0.964671       NaN  0.961365  0.956956
# 240       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 38        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 436       NaN       NaN       NaN  0.930976       NaN       NaN       NaN
# 390       NaN       NaN       NaN       NaN  0.988379       NaN       NaN
# 261       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 339       NaN       NaN       NaN       NaN       NaN  0.000531       NaN
# 282  0.010973       NaN       NaN  0.010110       NaN       NaN       NaN
# 276       NaN       NaN       NaN       NaN  0.993815       NaN       NaN
# 367  0.892816  0.894335       NaN       NaN  0.904925       NaN  0.904101
# 505       NaN       NaN  0.925574       NaN  0.968775       NaN  0.969109
# 499  0.014387       NaN       NaN       NaN       NaN       NaN       NaN
# 124  0.929561       NaN  0.935579  0.934406       NaN       NaN       NaN
# 154       NaN       NaN       NaN       NaN       NaN  0.883076       NaN
# 316       NaN       NaN       NaN  0.993457  0.993096  0.992762       NaN
# 59        NaN       NaN  0.993284       NaN  0.996368       NaN       NaN
# 333       NaN       NaN       NaN  0.990736       NaN       NaN       NaN
# 503       NaN       NaN       NaN  0.000376       NaN       NaN       NaN
# 534  0.946487       NaN       NaN       NaN       NaN       NaN  0.954135
# 563       NaN       NaN  0.002875       NaN       NaN       NaN       NaN
# 453       NaN       NaN  0.831723       NaN       NaN  0.835591  0.846773
# 262       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 378       NaN       NaN  0.916978  0.915242  0.897295  0.905171       NaN
# 229       NaN  0.259213  0.254166  0.243374  0.266202  0.265243       NaN
# 55        NaN       NaN       NaN       NaN       NaN       NaN  0.962068
# 171       NaN  0.415216  0.471561       NaN       NaN       NaN       NaN
# 454  0.887713       NaN       NaN       NaN       NaN       NaN  0.904415
# 243       NaN  0.889039       NaN       NaN       NaN       NaN       NaN
# 158       NaN  0.971611  0.970629       NaN       NaN  0.972464       NaN
# 415  0.917928       NaN       NaN  0.926038       NaN       NaN  0.924661
# 34        NaN  0.099773  0.116055       NaN       NaN       NaN       NaN
# 561  0.985077       NaN       NaN  0.983573       NaN       NaN       NaN
# 18   0.002664       NaN       NaN  0.001253       NaN       NaN       NaN
# 508       NaN  0.669814       NaN       NaN       NaN  0.676751  0.682948
# 322       NaN  0.881318       NaN       NaN       NaN       NaN       NaN
# 51        NaN  0.924058       NaN       NaN       NaN  0.921824  0.921274
# 219  0.004197       NaN  0.003769       NaN       NaN       NaN       NaN
# 549       NaN       NaN       NaN       NaN  0.960995  0.956824       NaN
# 52        NaN  0.965999       NaN       NaN       NaN  0.970390       NaN
# 74        NaN       NaN  0.928034       NaN       NaN       NaN       NaN
# 26        NaN       NaN  0.041392       NaN       NaN  0.026392  0.024799
# 173       NaN       NaN       NaN  0.991941       NaN       NaN       NaN
# 92   0.838674       NaN       NaN       NaN       NaN       NaN       NaN
# 167  0.217138       NaN       NaN  0.169732       NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 409       NaN       NaN       NaN  0.859940       NaN  0.850456       NaN
# 181       NaN       NaN       NaN       NaN  0.000372  0.000420       NaN
# 245       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 379       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 425       NaN       NaN  0.986891       NaN       NaN       NaN       NaN
# 479       NaN  0.311621       NaN       NaN  0.274762       NaN       NaN
# 5         NaN  0.424193       NaN       NaN  0.422487       NaN  0.426739
# 141       NaN       NaN       NaN       NaN       NaN       NaN  0.242189
# 329  0.566053       NaN       NaN       NaN       NaN  0.518079       NaN
# 200  0.798939       NaN  0.776066  0.785521       NaN       NaN       NaN
# 135       NaN       NaN       NaN  0.818210       NaN  0.829053  0.803371
# 285       NaN       NaN       NaN  0.988556  0.987448       NaN       NaN
# 122  0.002690       NaN       NaN       NaN       NaN  0.000859  0.000947
# 484       NaN  0.706563       NaN       NaN       NaN       NaN  0.720825
# 22        NaN       NaN       NaN       NaN       NaN  0.070357  0.078831
# 220       NaN  0.931191       NaN       NaN       NaN       NaN       NaN
# 517       NaN  0.045774       NaN       NaN  0.043845       NaN       NaN
# 120       NaN  0.964889  0.961504       NaN       NaN       NaN  0.971895
# 81   0.447580  0.506742       NaN       NaN       NaN       NaN       NaN
# 487       NaN  0.012264       NaN  0.010245       NaN  0.009823       NaN
# 464       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 554       NaN       NaN       NaN  0.902588  0.887155       NaN       NaN
# 548       NaN       NaN       NaN       NaN       NaN       NaN  0.987569
# 160       NaN       NaN       NaN       NaN  0.918925  0.902209       NaN
# 557       NaN       NaN       NaN       NaN  0.990661       NaN       NaN
# 238       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 284       NaN       NaN  0.932706  0.923276       NaN       NaN       NaN
# 315  0.988132       NaN  0.986889  0.988598  0.988088       NaN       NaN
# 195       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 191       NaN       NaN       NaN       NaN       NaN  0.937187       NaN
# 116       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 477       NaN  0.950905       NaN       NaN  0.942354  0.949926       NaN
# 428       NaN  0.990260       NaN  0.991487       NaN       NaN       NaN
# 164       NaN       NaN       NaN       NaN       NaN       NaN  0.001189
# 106       NaN       NaN  0.775527       NaN  0.827013       NaN       NaN
# 403       NaN       NaN       NaN       NaN  0.930110       NaN       NaN
# 63        NaN       NaN       NaN  0.990933  0.992084       NaN       NaN
# 105       NaN       NaN       NaN       NaN  0.274470       NaN       NaN
# 312       NaN  0.939305  0.949812       NaN       NaN  0.943226       NaN
# 555  0.934765       NaN       NaN       NaN       NaN       NaN  0.933074
# 481  0.840839       NaN       NaN       NaN  0.823011  0.828289       NaN
# 344  0.957582       NaN       NaN  0.955034       NaN       NaN  0.961055
# 93        NaN       NaN  0.876612       NaN       NaN       NaN  0.880577
# 395       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 393  0.002200  0.002331  0.002629       NaN       NaN  0.001812       NaN
# 381       NaN  0.978801       NaN       NaN       NaN       NaN  0.978257
# 198       NaN       NaN       NaN       NaN       NaN  0.034301       NaN
# 145       NaN  0.962227       NaN       NaN       NaN       NaN  0.973815
# 150       NaN       NaN       NaN       NaN       NaN       NaN  0.924852
# 39        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 520       NaN  0.973372       NaN       NaN       NaN  0.981817       NaN
# 351       NaN  0.109940       NaN       NaN  0.104433  0.089160  0.091707
# 253       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 467       NaN       NaN  0.985633       NaN       NaN       NaN       NaN
# 501       NaN  0.275552  0.274729  0.286395       NaN       NaN       NaN
# 2    0.007534  0.005539       NaN       NaN       NaN       NaN  0.004552
# 221  0.903435       NaN       NaN  0.917977       NaN       NaN       NaN
# 532  0.889717       NaN       NaN       NaN       NaN  0.898083  0.893788
# 146       NaN  0.493433  0.508865  0.497607       NaN       NaN       NaN
# 289       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 241       NaN       NaN       NaN  0.987000       NaN  0.984691       NaN
# 342       NaN  0.951225       NaN       NaN  0.952811       NaN       NaN
# 433       NaN       NaN  0.033121       NaN       NaN       NaN       NaN
# 114       NaN  0.974220  0.971788       NaN  0.982493       NaN       NaN
# 311       NaN  0.909281  0.925894       NaN       NaN  0.913735  0.909072
# 399       NaN       NaN       NaN  0.960707       NaN       NaN       NaN
# 176       NaN       NaN       NaN  0.936672  0.954121       NaN       NaN
# 491       NaN       NaN       NaN       NaN  0.691413  0.660100       NaN
# 168       NaN  0.010653       NaN  0.010201       NaN       NaN       NaN
# 365       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 539       NaN       NaN       NaN       NaN  0.989197       NaN       NaN
# 506       NaN  0.940080       NaN       NaN       NaN  0.950377  0.947413
# 426  0.948014       NaN       NaN       NaN       NaN  0.949372       NaN
# 136       NaN  0.932523       NaN       NaN       NaN       NaN       NaN
# 444       NaN       NaN       NaN       NaN  0.222135       NaN       NaN
# 254       NaN  0.009172  0.016137       NaN  0.009892  0.010120       NaN
# 362  0.919318       NaN       NaN       NaN  0.923778  0.928152  0.924477
# 386       NaN       NaN       NaN  0.954619       NaN       NaN       NaN
# 494       NaN       NaN  0.945299       NaN       NaN       NaN       NaN
# 452       NaN       NaN       NaN  0.907230       NaN       NaN       NaN
# 255  0.601544       NaN       NaN       NaN       NaN  0.576652  0.586126
# 232  0.943899  0.949881       NaN       NaN       NaN       NaN       NaN
# 133       NaN       NaN       NaN       NaN       NaN       NaN  0.588011
# 33        NaN       NaN       NaN       NaN       NaN       NaN  0.013247
# 88        NaN       NaN       NaN       NaN       NaN  0.774672       NaN
# 290       NaN  0.620472       NaN       NaN       NaN       NaN       NaN
# 44        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 61        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 199       NaN  0.170852  0.194757       NaN       NaN  0.160886       NaN
# 375  0.686600       NaN  0.754416       NaN       NaN       NaN       NaN
# 545  0.865944       NaN       NaN       NaN       NaN       NaN  0.847262
# 530       NaN       NaN  0.832235       NaN  0.868859       NaN       NaN
# 424       NaN       NaN       NaN       NaN       NaN  0.972785       NaN
# 218       NaN       NaN       NaN       NaN       NaN       NaN  0.005844
# 302       NaN       NaN  0.010400       NaN       NaN       NaN       NaN
# 297       NaN       NaN       NaN       NaN  0.948719       NaN       NaN
# 73        NaN       NaN  0.661249       NaN       NaN       NaN  0.650342
# 295       NaN       NaN       NaN       NaN       NaN  0.966033       NaN
# 35   0.064581       NaN       NaN       NaN       NaN       NaN       NaN
# 493  0.989312       NaN       NaN       NaN       NaN       NaN       NaN
# 29        NaN  0.235946  0.289830       NaN       NaN       NaN       NaN
# 460       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 438  0.896445       NaN       NaN       NaN       NaN       NaN       NaN
# 445  0.822933       NaN       NaN  0.822587       NaN       NaN       NaN
# 309       NaN  0.969523  0.976508       NaN       NaN       NaN  0.975790
# 541       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 217  0.984336  0.984753       NaN       NaN       NaN       NaN       NaN
# 27        NaN       NaN       NaN  0.066342  0.105923       NaN       NaN
# 462       NaN       NaN       NaN       NaN  0.883465  0.906496       NaN
# 376       NaN       NaN       NaN       NaN  0.915239       NaN       NaN
# 156  0.158214       NaN       NaN  0.088064  0.133082  0.095631       NaN
# 552       NaN       NaN  0.890438  0.898315       NaN       NaN       NaN
# 475  0.915791       NaN       NaN       NaN  0.925349  0.928910       NaN
# 138       NaN  0.062001  0.122190       NaN       NaN       NaN       NaN
# 212       NaN  0.000234       NaN  0.000290       NaN  0.000448  0.000736
# 104       NaN       NaN  0.984570       NaN  0.988622       NaN  0.986899
# 447  0.822629       NaN  0.874859       NaN       NaN       NaN       NaN
# 443       NaN  0.993082       NaN       NaN       NaN       NaN       NaN
# 449       NaN       NaN       NaN       NaN  0.003169       NaN  0.002690
# 215  0.409499       NaN       NaN  0.471358       NaN  0.451347       NaN
# 496       NaN       NaN  0.757288       NaN       NaN       NaN       NaN
# 189       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 214  0.122147       NaN       NaN       NaN       NaN       NaN  0.133558
# 524  0.977846  0.977605       NaN       NaN       NaN  0.979648  0.981491
# 204       NaN  0.789402  0.807837       NaN  0.828775       NaN       NaN
# 234       NaN       NaN       NaN  0.985114       NaN       NaN       NaN
# 259  0.024532       NaN       NaN       NaN       NaN       NaN       NaN
# 67   0.965944  0.961383       NaN  0.965225  0.968999       NaN  0.967008
# 24        NaN  0.002302       NaN       NaN       NaN  0.002950       NaN
# 216       NaN       NaN  0.852697       NaN       NaN       NaN  0.853686
# 300       NaN  0.003296       NaN       NaN       NaN       NaN  0.003779
# 223       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 129       NaN       NaN       NaN       NaN  0.022117       NaN       NaN
# 533  0.044912       NaN       NaN       NaN  0.035180       NaN       NaN
# 111       NaN  0.862728       NaN       NaN       NaN       NaN       NaN
# 166       NaN       NaN       NaN  0.993328  0.994530       NaN       NaN
# 267  0.905940       NaN  0.909773  0.908849       NaN       NaN       NaN
# 507       NaN       NaN  0.944717  0.958750       NaN       NaN       NaN
# 40        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 274       NaN       NaN       NaN       NaN  0.172162       NaN       NaN
# 455       NaN       NaN       NaN       NaN       NaN       NaN  0.680003
# 79        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 402       NaN       NaN       NaN       NaN       NaN       NaN  0.938506
# 404       NaN       NaN       NaN       NaN       NaN  0.978894  0.980994
# 327  0.985726       NaN       NaN       NaN       NaN       NaN       NaN
# 13   0.619032       NaN       NaN  0.610909       NaN       NaN       NaN
# 287       NaN  0.982818       NaN       NaN       NaN  0.982686       NaN
# 326       NaN  0.945761       NaN       NaN  0.951686       NaN       NaN
# 121  0.075594       NaN  0.062293       NaN  0.061379       NaN       NaN
# 251       NaN  0.950668       NaN       NaN       NaN       NaN       NaN
# 228       NaN  0.770017       NaN       NaN       NaN       NaN  0.759883
# 498       NaN       NaN  0.059557       NaN  0.061111       NaN       NaN
# 161  0.104304       NaN  0.081050  0.043862       NaN       NaN       NaN
# 83        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 117  0.083949       NaN       NaN  0.077468       NaN       NaN       NaN
# 374  0.931016       NaN       NaN       NaN       NaN       NaN       NaN
# 407       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 25        NaN  0.004911  0.007914  0.004503       NaN       NaN  0.005106
# 110       NaN       NaN       NaN  0.981208       NaN  0.983364       NaN
# 149       NaN       NaN       NaN  0.945582       NaN       NaN       NaN
# 152  0.829705       NaN  0.785614       NaN       NaN       NaN  0.809580
# 16        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 435       NaN  0.260370       NaN       NaN       NaN  0.238622       NaN
# 331       NaN       NaN       NaN       NaN       NaN       NaN  0.880300
# 109       NaN  0.904293  0.895860       NaN       NaN       NaN  0.922874
# 470       NaN       NaN  0.970060  0.971996  0.975827       NaN       NaN
# 450       NaN       NaN       NaN  0.935596       NaN  0.930586       NaN
# 139  0.974045       NaN       NaN       NaN       NaN       NaN       NaN
# 237       NaN  0.040683       NaN  0.045382  0.055443       NaN       NaN
# 260       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 352       NaN       NaN       NaN       NaN  0.000077       NaN  0.000056
# 456       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 317       NaN       NaN       NaN       NaN  0.068084  0.073348       NaN
# 323  0.000896       NaN       NaN       NaN       NaN       NaN       NaN
# 513  0.848878       NaN  0.844922       NaN       NaN       NaN  0.834853
# 248  0.920414       NaN  0.920867       NaN       NaN       NaN  0.931485
# 410  0.853560       NaN       NaN       NaN       NaN       NaN       NaN
# 422       NaN  0.926379       NaN       NaN       NaN       NaN       NaN
# 497  0.874367  0.895070  0.900432       NaN       NaN       NaN  0.891736
# 19        NaN       NaN       NaN  0.797681  0.804552       NaN       NaN
# 328       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 296       NaN       NaN       NaN  0.995500       NaN       NaN       NaN
# 483  0.887307       NaN       NaN  0.893674       NaN       NaN       NaN
# 269       NaN       NaN       NaN  0.950898       NaN       NaN       NaN
# 363       NaN       NaN       NaN  0.670220  0.653918       NaN       NaN
# 226       NaN       NaN       NaN       NaN       NaN  0.989577       NaN
# 495       NaN       NaN  0.752814       NaN       NaN       NaN       NaN
# 3         NaN       NaN       NaN       NaN  0.071986  0.062417       NaN
# 446       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 125       NaN  0.940705  0.946179       NaN  0.941486       NaN       NaN
# 280       NaN       NaN       NaN  0.009140  0.010045       NaN       NaN
# 286       NaN       NaN       NaN       NaN  0.864725       NaN       NaN
# 77   0.030629       NaN       NaN       NaN       NaN  0.016178       NaN
# 184       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 371       NaN       NaN       NaN       NaN  0.920285  0.922989  0.924736
# 485  0.802223       NaN  0.834654  0.810337       NaN  0.790377       NaN
# 556  0.993109       NaN       NaN       NaN       NaN       NaN  0.993726
# 275       NaN  0.912637  0.905978       NaN       NaN  0.920263       NaN
# 294  0.973681  0.972210       NaN       NaN       NaN       NaN       NaN
# 535       NaN       NaN       NaN       NaN       NaN  0.007785  0.006935
# 182       NaN  0.139279       NaN       NaN  0.112593       NaN       NaN
# 32        NaN       NaN  0.032654       NaN       NaN  0.033556  0.027720
# 80        NaN  0.918877  0.903519       NaN  0.930947       NaN       NaN
# 307       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 258  0.011910       NaN  0.007072       NaN       NaN       NaN       NaN
# 11   0.084059       NaN       NaN       NaN       NaN       NaN       NaN
# 360       NaN       NaN  0.985739       NaN       NaN  0.985320  0.984671
# 476       NaN       NaN       NaN       NaN       NaN  0.576157       NaN
# 86   0.575739       NaN  0.586610       NaN       NaN  0.566525       NaN
# 266       NaN       NaN  0.955131       NaN       NaN  0.953713       NaN
# 36   0.435836       NaN  0.494951  0.494456       NaN       NaN       NaN
# 193       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 58   0.982597       NaN  0.981148  0.981838       NaN       NaN  0.980028
# 41        NaN       NaN       NaN       NaN  0.662711       NaN  0.678534
# 270       NaN       NaN       NaN       NaN  0.973747       NaN       NaN
# 411  0.946786       NaN       NaN       NaN  0.954777       NaN       NaN
# 50        NaN       NaN       NaN       NaN       NaN       NaN  0.970894
# 209       NaN  0.823927       NaN  0.837129  0.826979       NaN  0.833983
# 511       NaN       NaN  0.936074       NaN       NaN       NaN       NaN
# 540       NaN  0.971769       NaN       NaN       NaN       NaN       NaN
# 522       NaN  0.987471       NaN       NaN  0.986848       NaN  0.987494
# 521       NaN       NaN       NaN  0.000362       NaN  0.000356       NaN
# 451       NaN  0.088227  0.089509       NaN       NaN       NaN       NaN
# 123       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 222       NaN       NaN  0.978564  0.983230       NaN       NaN       NaN
# 419  0.966847       NaN  0.966492  0.972221       NaN       NaN       NaN
# 62   0.170230       NaN       NaN  0.103700       NaN       NaN       NaN
# 568       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 377       NaN  0.893032       NaN       NaN  0.876659       NaN       NaN
# 130  0.946479       NaN       NaN       NaN  0.958614       NaN       NaN
# 187       NaN       NaN  0.919399  0.918522  0.926228  0.918320       NaN
# 23   0.002374       NaN       NaN       NaN  0.001247       NaN  0.001045
# 480  0.955151       NaN       NaN       NaN       NaN       NaN       NaN
# 509       NaN  0.086179  0.072975  0.068613  0.069933       NaN       NaN
# 43        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 370       NaN       NaN  0.052951  0.038098       NaN  0.032843       NaN
# 394       NaN       NaN       NaN       NaN  0.943822       NaN       NaN
# 0         NaN       NaN       NaN       NaN  0.002687       NaN       NaN
# 383  0.890149       NaN       NaN       NaN       NaN  0.896927  0.897182
# 201       NaN       NaN       NaN       NaN       NaN  0.078621       NaN
# 405       NaN       NaN       NaN  0.940809       NaN       NaN       NaN
# 368       NaN  0.000874       NaN       NaN       NaN       NaN  0.001021
# 461       NaN  0.000001  0.000009  0.000002  0.000014       NaN       NaN
# 529       NaN       NaN       NaN       NaN  0.970711       NaN       NaN
# 98   0.957910  0.958125       NaN       NaN       NaN       NaN       NaN
# 387       NaN       NaN       NaN       NaN       NaN  0.960194       NaN
# 349       NaN       NaN  0.978179       NaN  0.983019  0.979778       NaN
# 304  0.977233       NaN       NaN  0.974705       NaN  0.975085       NaN
# 418  0.955624       NaN       NaN       NaN       NaN       NaN       NaN
# 292       NaN       NaN  0.907982  0.914654       NaN       NaN       NaN
# 178       NaN  0.981417       NaN       NaN       NaN       NaN       NaN
# 369       NaN       NaN       NaN  0.000860       NaN       NaN       NaN
# 256       NaN       NaN       NaN  0.004084       NaN       NaN       NaN
# 94        NaN       NaN       NaN  0.094087       NaN       NaN       NaN
# 197  0.543935       NaN  0.536351       NaN       NaN       NaN       NaN
# 95        NaN       NaN       NaN       NaN  0.019917  0.019690  0.014905
# 558  0.791080  0.791529       NaN       NaN       NaN  0.784422  0.762901
# 163       NaN  0.893644       NaN  0.901019       NaN       NaN       NaN
# 169       NaN       NaN       NaN       NaN  0.853844       NaN       NaN
# 69   0.969633       NaN  0.965609       NaN       NaN       NaN  0.971558
# 305       NaN       NaN       NaN       NaN       NaN       NaN  0.956594
# 48        NaN  0.951107  0.947035       NaN  0.959919  0.958884       NaN
# 341       NaN       NaN  0.975514       NaN  0.977968       NaN       NaN
# 373       NaN       NaN       NaN       NaN       NaN       NaN  0.009056
# 397       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 207       NaN       NaN       NaN       NaN       NaN       NaN  0.312929
# 279  0.863250       NaN       NaN       NaN       NaN  0.872495       NaN
# 528       NaN       NaN       NaN       NaN       NaN       NaN  0.892890
# 227       NaN       NaN       NaN  0.724905       NaN       NaN       NaN
# 148       NaN       NaN       NaN       NaN  0.624388       NaN       NaN
# 143       NaN       NaN       NaN       NaN  0.882288       NaN       NaN
# 180  0.000113  0.000087  0.000098       NaN       NaN       NaN  0.000044
# 131       NaN  0.201003       NaN  0.199095       NaN       NaN  0.196905
# 47        NaN       NaN       NaN       NaN       NaN  0.213058       NaN
# 324       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 203       NaN       NaN       NaN       NaN  0.021490       NaN  0.019926
# 84   0.921001  0.933918       NaN  0.941195       NaN       NaN  0.937084
# 398       NaN       NaN       NaN       NaN  0.981257       NaN       NaN
# 91        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 82        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 430       NaN       NaN  0.123645       NaN       NaN       NaN       NaN
# 119       NaN       NaN       NaN  0.250539  0.189138       NaN       NaN
# 291       NaN       NaN       NaN       NaN       NaN  0.522353  0.513312
# 57   0.131596  0.155256       NaN       NaN       NaN       NaN       NaN
# 321       NaN       NaN       NaN  0.097376       NaN  0.087120       NaN
# 257       NaN       NaN       NaN       NaN  0.094752  0.064686       NaN
# 442       NaN       NaN       NaN       NaN       NaN  0.972691       NaN
# 42        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 388       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 335       NaN  0.029317       NaN       NaN       NaN       NaN  0.026459
# 273       NaN       NaN       NaN       NaN       NaN  0.988346       NaN
# 488       NaN       NaN  0.901878       NaN       NaN       NaN       NaN
# 53        NaN       NaN       NaN       NaN  0.173096       NaN  0.126402
# 536  0.525910  0.602569       NaN       NaN       NaN       NaN       NaN
# 128       NaN       NaN       NaN  0.609100       NaN  0.600495       NaN
# 28        NaN       NaN       NaN       NaN       NaN       NaN  0.022948
# 183       NaN       NaN       NaN       NaN       NaN       NaN  0.981765
# 459  0.970957  0.973760       NaN       NaN       NaN  0.976778       NaN
# 510       NaN  0.957823       NaN       NaN  0.959493       NaN       NaN
# 151       NaN       NaN  0.968241       NaN       NaN       NaN       NaN
# 244  0.081131       NaN       NaN       NaN       NaN       NaN  0.055635
# 543       NaN       NaN       NaN  0.843212       NaN       NaN       NaN
# 544       NaN       NaN       NaN       NaN       NaN  0.922266       NaN
# 265       NaN       NaN       NaN  0.000199       NaN       NaN  0.000145
# 288  0.937564       NaN       NaN       NaN       NaN       NaN       NaN
# 423  0.682182       NaN       NaN       NaN       NaN       NaN       NaN
# 147  0.811214  0.800241  0.834579       NaN       NaN       NaN  0.786936
# 177       NaN  0.159796  0.153942  0.135265       NaN       NaN       NaN
# 99        NaN       NaN       NaN       NaN       NaN  0.398184       NaN
# 448       NaN       NaN       NaN       NaN       NaN       NaN  0.755911
# 431       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 115       NaN  0.912155  0.917221       NaN       NaN       NaN       NaN
# 72        NaN  0.013685       NaN       NaN       NaN       NaN       NaN
# 537       NaN       NaN       NaN       NaN       NaN       NaN  0.747692
# 174       NaN       NaN       NaN  0.995647       NaN       NaN       NaN
# 87        NaN  0.011361       NaN  0.012576       NaN       NaN       NaN
# 551  0.953513       NaN       NaN  0.964711       NaN       NaN       NaN
# 486       NaN       NaN       NaN       NaN  0.838603       NaN       NaN
# 314       NaN       NaN       NaN       NaN  0.997797  0.997410       NaN
# 396       NaN  0.685058       NaN       NaN  0.650343       NaN       NaN
# 472       NaN       NaN       NaN  0.787868       NaN       NaN       NaN
# 70        NaN       NaN       NaN  0.014474       NaN       NaN       NaN
# 277       NaN  0.339273  0.392579       NaN       NaN       NaN       NaN
# 9    0.066210       NaN  0.082707       NaN       NaN       NaN       NaN
# 359       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 192  0.997371       NaN  0.997147       NaN       NaN  0.997012       NaN
# 559       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#          K(8)      K(9)     K(10)     K(11)     K(12)     K(13)     K(14)  \
# 293       NaN       NaN       NaN       NaN       NaN  0.921608       NaN
# 332       NaN  0.987390  0.985868  0.984931  0.981197  0.983362       NaN
# 565       NaN       NaN  0.020956  0.015946  0.016315       NaN       NaN
# 278  0.933033       NaN       NaN       NaN       NaN  0.935527  0.950502
# 489  0.636393  0.579852       NaN  0.542894       NaN       NaN       NaN
# 346       NaN       NaN       NaN       NaN  0.952897       NaN       NaN
# 357       NaN       NaN  0.939823  0.934699       NaN       NaN       NaN
# 355       NaN       NaN       NaN       NaN       NaN       NaN  0.947987
# 112       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 68        NaN  0.835856  0.786996  0.851765       NaN  0.742553       NaN
# 526       NaN       NaN       NaN       NaN  0.663666       NaN       NaN
# 206       NaN  0.987058       NaN       NaN  0.982809       NaN  0.988236
# 65        NaN       NaN       NaN       NaN       NaN  0.216063  0.163386
# 437       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 126       NaN       NaN       NaN  0.452766       NaN       NaN       NaN
# 429       NaN       NaN       NaN       NaN  0.977839       NaN  0.985127
# 392  0.025243       NaN       NaN       NaN       NaN       NaN       NaN
# 343       NaN       NaN  0.006298       NaN       NaN       NaN       NaN
# 334       NaN  0.969336       NaN  0.969451       NaN       NaN       NaN
# 440  0.785902       NaN  0.786232       NaN       NaN       NaN       NaN
# 441       NaN       NaN       NaN       NaN  0.081076       NaN       NaN
# 137  0.961809       NaN       NaN       NaN  0.958761       NaN       NaN
# 230  0.024064       NaN       NaN       NaN  0.035955  0.039211       NaN
# 7    0.315191       NaN  0.339602       NaN       NaN       NaN       NaN
# 408       NaN       NaN  0.060270       NaN       NaN       NaN       NaN
# 523       NaN  0.727783       NaN       NaN       NaN  0.711288       NaN
# 361       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 553       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 478       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 303  0.978040       NaN       NaN       NaN       NaN  0.979577  0.985209
# 155       NaN       NaN       NaN       NaN  0.920940  0.923489       NaN
# 186       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 101       NaN  0.998781       NaN       NaN  0.998032       NaN       NaN
# 97   0.990553       NaN       NaN       NaN       NaN  0.988848       NaN
# 20        NaN       NaN       NaN       NaN       NaN       NaN  0.941833
# 153       NaN       NaN  0.987004       NaN  0.985782       NaN       NaN
# 54        NaN       NaN  0.315041  0.393414       NaN  0.277425       NaN
# 30        NaN  0.012754       NaN  0.008570       NaN  0.014034       NaN
# 531       NaN       NaN       NaN       NaN  0.898980       NaN       NaN
# 49        NaN       NaN  0.629152       NaN       NaN       NaN       NaN
# 100       NaN       NaN  0.458716       NaN       NaN       NaN       NaN
# 336       NaN       NaN       NaN  0.974319  0.977204       NaN       NaN
# 299  0.990967       NaN  0.990607       NaN       NaN       NaN       NaN
# 347  0.714840  0.731751       NaN  0.732604       NaN       NaN       NaN
# 502  0.928726  0.936019       NaN  0.929585       NaN  0.935911       NaN
# 56   0.005422       NaN       NaN  0.006895       NaN       NaN       NaN
# 144       NaN       NaN       NaN       NaN  0.989150       NaN  0.993037
# 60        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6    0.029469       NaN  0.037836       NaN       NaN       NaN       NaN
# 8    0.163428  0.131224       NaN       NaN       NaN       NaN       NaN
# 474       NaN       NaN       NaN  0.978400       NaN       NaN       NaN
# 320       NaN       NaN  0.961163       NaN       NaN       NaN  0.969772
# 252  0.003556       NaN       NaN       NaN       NaN  0.004412       NaN
# 202       NaN  0.000958  0.001041       NaN       NaN       NaN       NaN
# 246       NaN       NaN       NaN       NaN  0.950862       NaN       NaN
# 240  0.908058  0.919452       NaN  0.907827       NaN       NaN       NaN
# 38        NaN  0.969521  0.970084  0.958757       NaN       NaN  0.975885
# 436       NaN       NaN       NaN       NaN       NaN  0.916807       NaN
# 390       NaN       NaN       NaN       NaN  0.986081  0.987164       NaN
# 261  0.470605  0.506424       NaN       NaN  0.511460  0.499011       NaN
# 339       NaN       NaN       NaN       NaN  0.000873       NaN       NaN
# 282       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 276       NaN       NaN       NaN  0.992825       NaN  0.993588  0.994962
# 367       NaN       NaN       NaN       NaN  0.900686  0.894995       NaN
# 505       NaN       NaN       NaN  0.939362       NaN       NaN       NaN
# 499  0.009270       NaN       NaN       NaN  0.012317       NaN       NaN
# 124  0.923857       NaN  0.929200       NaN  0.933224       NaN       NaN
# 154  0.881098  0.880705       NaN       NaN       NaN       NaN       NaN
# 316  0.993345       NaN       NaN       NaN  0.992904       NaN       NaN
# 59   0.994957       NaN       NaN  0.995313  0.994716       NaN       NaN
# 333       NaN       NaN       NaN       NaN       NaN       NaN  0.991595
# 503  0.001251       NaN       NaN       NaN       NaN  0.000897       NaN
# 534       NaN       NaN  0.944323       NaN       NaN       NaN  0.956820
# 563       NaN       NaN       NaN       NaN       NaN       NaN  0.002840
# 453       NaN  0.850820       NaN       NaN       NaN       NaN       NaN
# 262       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 378       NaN       NaN       NaN       NaN       NaN  0.898677       NaN
# 229       NaN  0.223249       NaN       NaN  0.246256  0.227494       NaN
# 55        NaN  0.968108       NaN  0.961006       NaN  0.955702       NaN
# 171       NaN       NaN  0.514637       NaN       NaN       NaN       NaN
# 454       NaN       NaN       NaN  0.905122       NaN       NaN       NaN
# 243       NaN  0.930434  0.923845  0.919144  0.908680  0.881640       NaN
# 158       NaN       NaN       NaN       NaN       NaN  0.975458       NaN
# 415       NaN       NaN  0.923757       NaN       NaN       NaN       NaN
# 34        NaN       NaN       NaN  0.067820       NaN  0.097434       NaN
# 561  0.984998  0.985566       NaN       NaN       NaN       NaN       NaN
# 18        NaN       NaN       NaN       NaN  0.002799       NaN       NaN
# 508       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 322       NaN  0.885358       NaN  0.899283       NaN  0.902167       NaN
# 51        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 219       NaN  0.002940       NaN  0.004742       NaN  0.002957       NaN
# 549       NaN       NaN       NaN  0.965488       NaN       NaN       NaN
# 52        NaN       NaN       NaN  0.971593       NaN       NaN       NaN
# 74        NaN       NaN       NaN  0.930843  0.925526       NaN  0.940871
# 26        NaN       NaN       NaN       NaN       NaN       NaN  0.018949
# 173       NaN       NaN       NaN       NaN       NaN  0.992390       NaN
# 92        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 167       NaN       NaN       NaN       NaN       NaN       NaN  0.238296
# 4    0.107643  0.130299       NaN       NaN       NaN  0.142635       NaN
# 409       NaN       NaN       NaN       NaN       NaN       NaN  0.863575
# 181       NaN  0.000369       NaN       NaN  0.000472       NaN  0.000314
# 245       NaN       NaN  0.954726       NaN       NaN       NaN       NaN
# 379  0.117425  0.109180       NaN       NaN       NaN       NaN       NaN
# 425       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 479       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5         NaN       NaN       NaN       NaN       NaN  0.440089       NaN
# 141       NaN       NaN       NaN       NaN  0.313280       NaN       NaN
# 329  0.554323  0.571680       NaN       NaN       NaN  0.551077  0.568333
# 200       NaN  0.800613  0.801573       NaN       NaN       NaN       NaN
# 135       NaN       NaN       NaN       NaN       NaN  0.794853       NaN
# 285       NaN       NaN       NaN  0.987162       NaN  0.986513       NaN
# 122       NaN       NaN       NaN       NaN       NaN  0.002478       NaN
# 484  0.627170       NaN       NaN       NaN       NaN       NaN       NaN
# 22        NaN       NaN       NaN       NaN       NaN       NaN  0.067360
# 220  0.930371       NaN       NaN       NaN  0.946362       NaN       NaN
# 517       NaN  0.050163       NaN       NaN       NaN  0.070267       NaN
# 120       NaN       NaN       NaN       NaN  0.965632       NaN       NaN
# 81        NaN       NaN       NaN       NaN       NaN       NaN  0.450177
# 487       NaN       NaN       NaN       NaN       NaN       NaN  0.008537
# 464  0.849365       NaN       NaN       NaN  0.878590       NaN  0.894077
# 554       NaN  0.888309       NaN       NaN       NaN  0.859677  0.910213
# 548       NaN       NaN       NaN       NaN  0.985109       NaN       NaN
# 160       NaN       NaN       NaN  0.909390       NaN       NaN       NaN
# 557       NaN       NaN       NaN       NaN       NaN       NaN  0.993745
# 238       NaN  0.658603       NaN       NaN       NaN       NaN       NaN
# 284       NaN       NaN  0.933672  0.932646  0.934881       NaN  0.950534
# 315       NaN  0.989760  0.989834       NaN       NaN       NaN       NaN
# 195       NaN       NaN       NaN       NaN       NaN  0.937387  0.948072
# 191       NaN  0.972048       NaN  0.962295       NaN       NaN       NaN
# 116       NaN       NaN       NaN       NaN       NaN  0.995315  0.997574
# 477       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 428       NaN       NaN  0.989791       NaN       NaN  0.989483       NaN
# 164       NaN       NaN       NaN  0.002244  0.002704  0.002313       NaN
# 106       NaN       NaN       NaN       NaN  0.801191       NaN       NaN
# 403       NaN       NaN       NaN  0.925925       NaN  0.933500       NaN
# 63        NaN  0.993065       NaN  0.989396  0.988080       NaN  0.993254
# 105       NaN  0.230836       NaN  0.216021       NaN  0.295337       NaN
# 312       NaN       NaN       NaN  0.953900       NaN       NaN       NaN
# 555  0.928826       NaN       NaN       NaN  0.920960       NaN       NaN
# 481       NaN       NaN       NaN       NaN       NaN  0.827360       NaN
# 344  0.959684  0.965419       NaN  0.958997       NaN       NaN       NaN
# 93        NaN       NaN  0.890470       NaN       NaN       NaN       NaN
# 395       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 393       NaN  0.001635       NaN       NaN  0.001771       NaN       NaN
# 381       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 198  0.031302  0.031459       NaN       NaN       NaN  0.039782       NaN
# 145       NaN       NaN       NaN       NaN  0.971879  0.972977       NaN
# 150  0.942321  0.943327  0.937440       NaN       NaN       NaN       NaN
# 39        NaN       NaN  0.224638       NaN  0.287347       NaN  0.258708
# 520       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 351       NaN       NaN       NaN  0.055559       NaN  0.103370       NaN
# 253       NaN       NaN  0.109857       NaN  0.128127  0.157564  0.110223
# 467       NaN       NaN  0.989870       NaN  0.986326       NaN       NaN
# 501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN  0.006885       NaN       NaN
# 221       NaN       NaN       NaN       NaN       NaN       NaN  0.917818
# 532       NaN       NaN  0.902990       NaN       NaN  0.897204       NaN
# 146  0.502261       NaN       NaN       NaN       NaN       NaN  0.304370
# 289  0.969096       NaN  0.958409  0.959202       NaN       NaN       NaN
# 241  0.983801       NaN       NaN       NaN       NaN       NaN       NaN
# 342       NaN       NaN  0.939438       NaN       NaN       NaN       NaN
# 433  0.036743       NaN       NaN       NaN       NaN       NaN       NaN
# 114       NaN  0.978902       NaN       NaN  0.977616       NaN  0.982066
# 311       NaN       NaN  0.928885       NaN       NaN       NaN       NaN
# 399  0.964344       NaN  0.964566       NaN  0.957166       NaN       NaN
# 176       NaN  0.954330       NaN       NaN       NaN  0.932785       NaN
# 491  0.711555  0.761867       NaN       NaN       NaN       NaN       NaN
# 168       NaN  0.027757       NaN       NaN       NaN       NaN       NaN
# 365       NaN       NaN       NaN  0.035471       NaN       NaN       NaN
# 539  0.986793  0.987179  0.985961       NaN  0.982222       NaN  0.989313
# 506       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 426  0.957570       NaN       NaN       NaN       NaN  0.946809  0.963808
# 136  0.946643  0.956216       NaN       NaN       NaN       NaN       NaN
# 444       NaN       NaN  0.256241       NaN  0.284388       NaN  0.258131
# 254       NaN  0.012112       NaN       NaN       NaN  0.014955  0.011845
# 362       NaN  0.926300       NaN       NaN  0.922265       NaN       NaN
# 386  0.958250       NaN       NaN       NaN       NaN       NaN       NaN
# 494       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 452  0.891697  0.887591  0.887223  0.905620       NaN       NaN  0.911780
# 255       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 232  0.956935  0.948138       NaN       NaN       NaN  0.914274  0.957222
# 133       NaN       NaN       NaN  0.568789       NaN       NaN       NaN
# 33        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 88        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 290       NaN       NaN  0.810544       NaN       NaN       NaN       NaN
# 44   0.361818       NaN       NaN       NaN       NaN       NaN       NaN
# 61        NaN       NaN  0.991842  0.991963       NaN       NaN       NaN
# 199       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 375       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 545       NaN  0.875655       NaN  0.877474       NaN       NaN  0.892950
# 530  0.864964  0.870123       NaN       NaN       NaN       NaN       NaN
# 424       NaN  0.985869       NaN       NaN       NaN       NaN       NaN
# 218       NaN  0.013274  0.016362       NaN       NaN  0.010755       NaN
# 302       NaN  0.013904  0.014102       NaN       NaN       NaN       NaN
# 297  0.952980       NaN       NaN       NaN       NaN       NaN  0.966127
# ...
# 397  0.937562       NaN       NaN  0.938493       NaN       NaN       NaN
# 207       NaN       NaN       NaN       NaN  0.379751       NaN       NaN
# 279  0.867207       NaN       NaN  0.880193       NaN       NaN       NaN
# 528       NaN       NaN  0.878172  0.893641       NaN       NaN       NaN
# 227  0.721286       NaN       NaN  0.720395       NaN       NaN  0.685085
# 148       NaN  0.594330       NaN       NaN       NaN       NaN       NaN
# 143       NaN       NaN  0.868352       NaN       NaN       NaN  0.862417
# 180  0.000068       NaN  0.000058       NaN       NaN       NaN       NaN
# 131       NaN       NaN       NaN       NaN       NaN  0.216270       NaN
# 47        NaN       NaN       NaN       NaN  0.220602  0.169236       NaN
# 324       NaN       NaN       NaN  0.964427       NaN       NaN       NaN
# 203       NaN       NaN  0.017119  0.018605       NaN       NaN  0.015833
# 84   0.928964       NaN       NaN       NaN       NaN       NaN  0.922588
# 398       NaN       NaN       NaN       NaN  0.983563       NaN       NaN
# 91        NaN       NaN       NaN  0.483204  0.538066       NaN  0.539097
# 82        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 430       NaN       NaN  0.074722  0.096792       NaN       NaN  0.097806
# 119       NaN  0.246760  0.182211  0.258437       NaN       NaN  0.134414
# 291       NaN       NaN  0.501571  0.513223       NaN       NaN  0.503557
# 57        NaN       NaN       NaN       NaN  0.136138       NaN       NaN
# 321       NaN       NaN       NaN       NaN       NaN  0.113221       NaN
# 257       NaN       NaN  0.058499       NaN       NaN       NaN       NaN
# 442       NaN       NaN  0.975746       NaN       NaN  0.982401       NaN
# 42        NaN       NaN       NaN       NaN  0.001399  0.001524  0.001560
# 388  0.972324       NaN  0.969976       NaN       NaN  0.972277       NaN
# 335       NaN       NaN  0.032987       NaN       NaN       NaN  0.045641
# 273       NaN       NaN       NaN  0.986233       NaN       NaN  0.989930
# 488       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 53   0.158604       NaN       NaN       NaN       NaN  0.138687       NaN
# 536       NaN       NaN  0.494795       NaN       NaN       NaN  0.527716
# 128       NaN  0.672063       NaN       NaN       NaN       NaN       NaN
# 28        NaN       NaN       NaN  0.026646  0.020641       NaN  0.019500
# 183       NaN       NaN       NaN       NaN  0.983592  0.983449       NaN
# 459       NaN       NaN  0.969185       NaN       NaN       NaN       NaN
# 510  0.958392       NaN       NaN  0.957972       NaN       NaN       NaN
# 151       NaN       NaN  0.971122  0.971031  0.966421       NaN       NaN
# 244       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 543       NaN       NaN       NaN  0.783983  0.791267       NaN  0.819149
# 544       NaN       NaN  0.913465       NaN       NaN       NaN       NaN
# 265       NaN       NaN       NaN  0.000228  0.000260       NaN       NaN
# 288       NaN       NaN       NaN       NaN       NaN  0.924673  0.954760
# 423  0.681680  0.682810  0.663374       NaN       NaN       NaN       NaN
# 147       NaN  0.850087       NaN       NaN       NaN       NaN       NaN
# 177       NaN  0.119154       NaN       NaN       NaN       NaN       NaN
# 99        NaN  0.375753  0.373812       NaN  0.402804       NaN  0.386051
# 448  0.755272       NaN       NaN       NaN       NaN       NaN       NaN
# 431  0.957431       NaN       NaN       NaN  0.960212       NaN       NaN
# 115       NaN       NaN       NaN       NaN  0.932831  0.941173       NaN
# 72   0.017632  0.017030       NaN       NaN       NaN       NaN  0.013637
# 537       NaN  0.721085       NaN       NaN       NaN  0.721101       NaN
# 174       NaN       NaN       NaN       NaN  0.994830       NaN       NaN
# 87        NaN       NaN       NaN  0.012920  0.017788       NaN  0.008070
# 551       NaN       NaN       NaN       NaN       NaN       NaN  0.957975
# 486       NaN       NaN       NaN       NaN       NaN       NaN  0.852348
# 314  0.996993  0.997813       NaN       NaN  0.995865  0.997372       NaN
# 396       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 472       NaN       NaN       NaN  0.783439       NaN       NaN       NaN
# 70        NaN       NaN       NaN  0.018595       NaN       NaN  0.022363
# 277       NaN       NaN       NaN       NaN  0.449762       NaN       NaN
# 9         NaN       NaN       NaN       NaN       NaN       NaN  0.053937
# 359       NaN  0.979974  0.972606       NaN  0.964322  0.973018       NaN
# 192       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 559       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#         K(99)    K(100)
# 293       NaN  0.940662
# 332       NaN  0.986523
# 565  0.016716       NaN
# 278       NaN       NaN
# 489       NaN  0.635237
# 346       NaN       NaN
# 357       NaN       NaN
# 355  0.916411       NaN
# 112  0.479129       NaN
# 68        NaN       NaN
# 526  0.691651  0.736860
# 206       NaN       NaN
# 65        NaN  0.141917
# 437       NaN       NaN
# 126  0.482510  0.480219
# 429       NaN       NaN
# 392  0.024202       NaN
# 343       NaN       NaN
# 334       NaN       NaN
# 440  0.790235       NaN
# 441       NaN  0.098380
# 137       NaN  0.966004
# 230       NaN       NaN
# 7         NaN       NaN
# 408       NaN       NaN
# 523       NaN       NaN
# 361       NaN       NaN
# 553       NaN       NaN
# 478       NaN  0.973554
# 303       NaN  0.982744
# 155  0.936329  0.940453
# 186       NaN       NaN
# 101       NaN  0.998645
# 97        NaN       NaN
# 20        NaN  0.938043
# 153       NaN  0.988279
# 54        NaN  0.413066
# 30        NaN       NaN
# 531       NaN       NaN
# 49        NaN       NaN
# 100       NaN       NaN
# 336       NaN       NaN
# 299       NaN       NaN
# 347       NaN       NaN
# 502  0.935451       NaN
# 56   0.006691  0.007449
# 144  0.991389  0.991628
# 60        NaN       NaN
# 6         NaN       NaN
# 8         NaN       NaN
# 474  0.977739       NaN
# 320       NaN       NaN
# 252       NaN       NaN
# 202       NaN       NaN
# 246       NaN       NaN
# 240       NaN  0.917310
# 38        NaN       NaN
# 436       NaN  0.940481
# 390       NaN  0.988873
# 261  0.615502       NaN
# 339       NaN       NaN
# 282       NaN  0.011669
# 276  0.994746       NaN
# 367  0.921524  0.926672
# 505       NaN       NaN
# 499  0.007804       NaN
# 124  0.929788       NaN
# 154  0.877384       NaN
# 316  0.994017       NaN
# 59   0.995791  0.996130
# 333       NaN       NaN
# 503  0.001201       NaN
# 534       NaN       NaN
# 563  0.001280       NaN
# 453       NaN       NaN
# 262       NaN       NaN
# 378       NaN       NaN
# 229       NaN       NaN
# 55   0.966701       NaN
# 171  0.565934  0.569220
# 454       NaN       NaN
# 243       NaN       NaN
# 158       NaN  0.977225
# 415  0.938205       NaN
# 34   0.069083       NaN
# 561       NaN  0.984140
# 18        NaN       NaN
# 508       NaN       NaN
# 322  0.887731  0.910181
# 51   0.935340       NaN
# 219       NaN       NaN
# 549  0.974111  0.968071
# 52   0.974947       NaN
# 74   0.934692  0.941768
# 26        NaN       NaN
# 173       NaN       NaN
# 92        NaN  0.881247
# 167       NaN  0.230622
# 4         NaN  0.085041
# 409       NaN  0.886974
# 181       NaN  0.000325
# 245       NaN       NaN
# 379  0.133915       NaN
# 425       NaN       NaN
# 479       NaN       NaN
# 5         NaN       NaN
# 141       NaN       NaN
# 329       NaN       NaN
# 200       NaN       NaN
# 135  0.845784  0.833117
# 285       NaN  0.988615
# 122       NaN       NaN
# 484  0.619232       NaN
# 22        NaN       NaN
# 220       NaN       NaN
# 517  0.040498       NaN
# 120       NaN       NaN
# 81   0.398176       NaN
# 487       NaN  0.007521
# 464       NaN  0.891250
# 554       NaN       NaN
# 548       NaN  0.989478
# 160  0.914337       NaN
# 557       NaN       NaN
# 238       NaN       NaN
# 284       NaN       NaN
# 315       NaN       NaN
# 195       NaN       NaN
# 191       NaN  0.963571
# 116       NaN       NaN
# 477       NaN       NaN
# 428       NaN  0.990450
# 164       NaN       NaN
# 106       NaN  0.856549
# 403       NaN       NaN
# 63   0.990000  0.992466
# 105       NaN       NaN
# 312  0.953164  0.961925
# 555  0.940767  0.937939
# 481       NaN       NaN
# 344       NaN       NaN
# 93        NaN  0.898230
# 395  0.906914  0.907687
# 393  0.000855       NaN
# 381  0.975584       NaN
# 198       NaN       NaN
# 145  0.973429       NaN
# 150       NaN       NaN
# 39        NaN       NaN
# 520  0.982378       NaN
# 351       NaN       NaN
# 253       NaN       NaN
# 467  0.991984       NaN
# 501       NaN       NaN
# 2         NaN       NaN
# 221       NaN       NaN
# 532       NaN       NaN
# 146       NaN  0.433265
# 289       NaN       NaN
# 241  0.984891       NaN
# 342       NaN       NaN
# 433       NaN       NaN
# 114       NaN       NaN
# 311       NaN  0.933147
# 399  0.969706       NaN
# 176       NaN       NaN
# 491       NaN       NaN
# 168  0.019714       NaN
# 365       NaN       NaN
# 539       NaN  0.987574
# 506  0.952145       NaN
# 426       NaN       NaN
# 136       NaN       NaN
# 444       NaN       NaN
# 254       NaN       NaN
# 362       NaN       NaN
# 386       NaN       NaN
# 494  0.961819       NaN
# 452       NaN       NaN
# 255       NaN       NaN
# 232  0.967136       NaN
# 133       NaN       NaN
# 33        NaN       NaN
# 88        NaN       NaN
# 290  0.723008       NaN
# 44        NaN  0.418704
# 61   0.993315       NaN
# 199       NaN       NaN
# 375       NaN       NaN
# 545       NaN       NaN
# 530  0.858265       NaN
# 424       NaN       NaN
# 218       NaN       NaN
# 302       NaN  0.008050
# 297  0.947194  0.952561
# 73        NaN  0.684996
# 295       NaN       NaN
# 35   0.087413       NaN
# 493       NaN       NaN
# 29        NaN       NaN
# 460  0.049963       NaN
# 438       NaN  0.908763
# 445       NaN       NaN
# 309       NaN       NaN
# 541       NaN       NaN
# 217  0.988424       NaN
# 27   0.114569       NaN
# 462       NaN  0.898784
# 376       NaN       NaN
# 156       NaN       NaN
# 552       NaN       NaN
# 475       NaN       NaN
# 138       NaN  0.224270
# 212       NaN       NaN
# 104       NaN       NaN
# 447       NaN  0.872165
# 443  0.993290       NaN
# 449       NaN       NaN
# 215       NaN       NaN
# 496       NaN       NaN
# 189       NaN  0.981225
# 214  0.143502       NaN
# 524       NaN       NaN
# 204       NaN  0.845394
# 234       NaN  0.988519
# 259       NaN       NaN
# 67   0.970168       NaN
# 24        NaN  0.004598
# 216       NaN       NaN
# 300       NaN  0.008019
# 223       NaN       NaN
# 129  0.016594       NaN
# 533       NaN  0.033100
# 111       NaN       NaN
# 166       NaN       NaN
# 267       NaN       NaN
# 507       NaN       NaN
# 40        NaN  0.791238
# 274       NaN       NaN
# 455       NaN  0.722598
# 79        NaN  0.933384
# 402  0.948072       NaN
# 404       NaN       NaN
# 327       NaN       NaN
# 13        NaN       NaN
# 287       NaN  0.986367
# 326       NaN       NaN
# 121       NaN       NaN
# 251       NaN       NaN
# 228       NaN  0.843308
# 498  0.056993  0.062696
# 161       NaN  0.092343
# 83   0.015894       NaN
# 117  0.063940       NaN
# 374       NaN       NaN
# 407       NaN       NaN
# 25   0.003764       NaN
# 110       NaN       NaN
# 149       NaN       NaN
# 152       NaN       NaN
# 16        NaN       NaN
# 435       NaN       NaN
# 331       NaN       NaN
# 109       NaN       NaN
# 470       NaN       NaN
# 450       NaN       NaN
# 139       NaN       NaN
# 237       NaN       NaN
# 260       NaN       NaN
# 352       NaN       NaN
# 456       NaN       NaN
# 317       NaN       NaN
# 323       NaN       NaN
# 513       NaN       NaN
# 248  0.950191       NaN
# 410       NaN       NaN
# 422       NaN       NaN
# 497       NaN       NaN
# 19        NaN       NaN
# 328       NaN       NaN
# 296  0.994725       NaN
# 483  0.895978       NaN
# 269       NaN       NaN
# 363       NaN  0.652707
# 226       NaN       NaN
# 495       NaN  0.724709
# 3         NaN  0.064297
# 446       NaN       NaN
# 125       NaN       NaN
# 280       NaN  0.009678
# 286       NaN       NaN
# 77        NaN       NaN
# 184  0.589483  0.582640
# 371       NaN       NaN
# 485       NaN       NaN
# 556       NaN  0.993318
# 275  0.905027       NaN
# 294       NaN       NaN
# 535       NaN       NaN
# 182       NaN  0.168262
# 32        NaN       NaN
# 80   0.944978       NaN
# 307       NaN       NaN
# 258  0.005097  0.009571
# 11        NaN       NaN
# 360       NaN       NaN
# 476       NaN       NaN
# 86        NaN       NaN
# 266       NaN       NaN
# 36        NaN       NaN
# 193  0.385711  0.377264
# 58   0.988512       NaN
# 41        NaN  0.643973
# 270       NaN       NaN
# 411  0.956455  0.958444
# 50        NaN       NaN
# 209       NaN       NaN
# 511       NaN       NaN
# 540       NaN       NaN
# 522  0.989615       NaN
# 521       NaN  0.000415
# 451       NaN       NaN
# 123       NaN       NaN
# 222       NaN       NaN
# 419       NaN  0.974658
# 62        NaN       NaN
# 568       NaN       NaN
# 377  0.924314  0.900040
# 130  0.952915       NaN
# 187  0.920265  0.936603
# 23   0.002595       NaN
# 480  0.965377  0.963921
# 509       NaN  0.076112
# 43        NaN       NaN
# 370       NaN       NaN
# 394  0.943023       NaN
# 0         NaN  0.002574
# 383  0.903982  0.914058
# 201  0.075682  0.100502
# 405       NaN       NaN
# 368       NaN       NaN
# 461  0.000016       NaN
# 529       NaN       NaN
# 98        NaN       NaN
# 387       NaN       NaN
# 349  0.983109       NaN
# 304       NaN  0.981501
# 418       NaN       NaN
# 292       NaN  0.919731
# 178       NaN       NaN
# 369       NaN       NaN
# 256       NaN  0.004351
# 94   0.084828       NaN
# 197       NaN       NaN
# 95        NaN       NaN
# 558  0.785051       NaN
# 163       NaN  0.917078
# 169       NaN  0.861909
# 69        NaN  0.969117
# 305       NaN       NaN
# 48        NaN       NaN
# 341       NaN       NaN
# 373       NaN       NaN
# 397       NaN       NaN
# 207  0.413046       NaN
# 279       NaN       NaN
# 528       NaN       NaN
# 227       NaN       NaN
# 148  0.569277       NaN
# 143       NaN  0.901929
# 180       NaN       NaN
# 131  0.186380       NaN
# 47        NaN       NaN
# 324       NaN       NaN
# 203  0.020892       NaN
# 84        NaN       NaN
# 398       NaN  0.985846
# 91        NaN       NaN
# 82   0.000058       NaN
# 430       NaN       NaN
# 119  0.239494       NaN
# 291       NaN       NaN
# 57        NaN       NaN
# 321       NaN       NaN
# 257       NaN       NaN
# 442       NaN       NaN
# 42        NaN  0.004168
# 388       NaN       NaN
# 335       NaN       NaN
# 273  0.989509  0.990019
# 488  0.925494  0.936464
# 53        NaN       NaN
# 536       NaN       NaN
# 128       NaN       NaN
# 28   0.022460       NaN
# 183  0.982177       NaN
# 459       NaN       NaN
# 510       NaN  0.968422
# 151  0.977386       NaN
# 244       NaN  0.055601
# 543       NaN       NaN
# 544       NaN       NaN
# 265       NaN       NaN
# 288       NaN       NaN
# 423       NaN       NaN
# 147       NaN       NaN
# 177       NaN       NaN
# 99        NaN       NaN
# 448       NaN       NaN
# 431       NaN       NaN
# 115       NaN       NaN
# 72   0.019879       NaN
# 537       NaN       NaN
# 174       NaN       NaN
# 87   0.013697       NaN
# 551       NaN       NaN
# 486       NaN  0.868171
# 314       NaN       NaN
# 396       NaN  0.671113
# 472  0.792511       NaN
# 70        NaN       NaN
# 277       NaN  0.341166
# 9         NaN       NaN
# 359       NaN       NaN
# 192  0.997865       NaN
# 559       NaN       NaN

# %% [markdown]
# We can plot the class probabilities for one or more patients by calling `.plot_object_probabilities` and investigate how difficult it was to classify the patients correctly. Patient 291 belongs to class 1 and the class probabilities are mostly just above the threshold of 0.5 and below for roughly 13% of the predictions. For patient 255, who belongs to class 0, 100% of the class probabilities indicate incorrectly that this patient belongs to class 1. Patients 253 (class 0) and 150 (class 1) were always predicted correctly and their respective probabilities close to the truth.

# %%
analysis.plot_object_probabilities(object_id=[291, 255, 253, 150])

# %% [markdown]
# We can apply PCA (principal component analysis) either on each class separately or both.
#
# **Example below: PCA on class 0**
#
# * First plot: *PCA scores* plot with coloured scores showing distribution of the patients for the first two components.
#
# Each point represents one patient in the class. The darker the colour, the more often the patient was classified incorrectly. The coloring degree is set by the value in column `% incorrect` in the array above that we got when calling `.summary_objects`. When applying PCA to class 0 we can see that those patients often classified incorrectly are grouped on the left side of the scores plot, indicating that they are similiar in some way.
#
# * Second plot: *PCA scores* plot - same as first plot, now showing patient ID
#
# We can see that the first component explains 44.7% of the total variance in the data based on the four selected features, while the second component explains 24.7%. That means that the first and second component together explain 67.7% of all the total variance. We have caputred much of the systematic information with these two components, however more systematic information may be containten in further componen, i.e. component 3, 4 and so on. One has to keep in mind though, the explained variance is smaller for each following component.
#
# * Third plot: *PCA loadings* plot showing how features contributed to the variance in the data
#
# The five selected features are all located on the right ($\geq 0$ on the first axis) side of the plot. When superimposing the PCA scores plot on PCA loadings plot we can say the following: patients in close proximity of the features have high values for those features. Patients on the opposite side have low values for those features. From the two plots we can say that the misclassified patients had relatively low values for the selected features.
#
# * Fourth plot: *PCA correlation loadings* plot - similar to *PCA loadings* plot, but showing how much of the variance is explained in each feature
#
# We can see that the variance in features `worst radius`, `mean concave points`, `worst concave points` and `worst symmetry` is explained almost entirely by component 1 and 2, since they are located close to the outer ring that represents 100% explained variance. The inner ring represents 50% explained variance. For feature `mean concave points` almost all of the explained variance is captured by component 1. For features `worst radius`, `worst concave points` and `worst symmetry` it is the combination of component 1 and 2 that contribute to explaining close to 100% of the variance. Feature `worst texture` is now well explained by component 1 and 2, meaning that some of its systematic variance may be explained by component 3 or further.
#
# * Fifth plot: *PCA bi-plot* - superimposed *PCA scores* and *PCA loadings*
#
# This plot is actually the PCA scores and PCA loadings superimposed.
#
# * Sixth plot: *PCA explained variance*
#
# From this plot we can see the cumulative explained variance across an increasing number of components. The blue line represents the calibrated explained variance, while the red line represents the validated explained variance. The red line being close to the blue line indicates that all components in the model are valid and may be used for interpretation. We also see that five components explain 100% of all variance in the data. This is not surprising, since we have exactly five features in the the data (the four features that were selected by RENT).

# %%
analysis.plot_object_PCA(cl=0)
# Out:
# loo

# %% [markdown]
# **Example below: PCA on class 1**
#
# * First plot: *PCA scores plot* with colouring
#
# We can see that only few samples are coloured darker because of misclassification.

# %%
analysis.plot_object_PCA(cl=1)
# Out:
# loo

# %% [markdown]
# **Example below: PCA on class 0 and class 1 together**
#
# * First plot: *PCA scores* plot with coloured scores
#
# We can see that most of the misclassified samples would lie along the dicision boundary (not shown) that separates the two classes. Circles represent class 0, while stars represent class 1.

# %%
analysis.plot_object_PCA(cl='both')
# Out:
# loo

# %% [markdown]
# ### Check performance using only selected features

# %% [markdown]
# RENT selected some features based on the distribution of the weights of each feature across the ensenmble of models. Now let's check how well a model performs that uses only the selected features on unseen data, i.e data that has not been touched by the RENT method.

# %%
#predict test data

# Import what is needed for prediction and evaluation of predictions from test set
from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression as LR

# Scale the data accordingly
sc = StandardScaler()
train_data_sc = sc.fit_transform(train_data.iloc[:, selected_features])
test_data_sc = sc.transform(test_data.iloc[:, selected_features])

# Train model with 
model = LR(penalty='none', max_iter=8000, solver="saga", random_state=0).\
        fit(train_data_sc, train_labels)

# Print results
print("f1 1: ", f1_score(test_labels, model.predict(test_data_sc)))
print("f1 0: ", f1_score(1 - test_labels, 1 - model.predict(test_data_sc)))
print("Accuracy: ", accuracy_score(test_labels, model.predict(test_data_sc)))
print("Matthews correlation coefficient: ", matthews_corrcoef(test_labels, model.predict(test_data_sc)))
# Out:
# f1 1:  0.9775280898876404
# f1 0:  0.9629629629629629
# Accuracy:  0.972027972027972
# Matthews correlation coefficient:  0.9409198630485198

# %% [markdown]
# Since the classes in the Wisconsin breast cancer data set are easy to separate, we achieve high performance for the test data.

# %% [markdown]
# ### Feasibility study regarding the features selected by RENT

# %% [markdown]
# In order to validate the selected features we benefit to know whether the selected features provide models that perform better than random. This can be done in two complimentary ways:
#
# 1. randomly draw the same number of features from the full set of features and compute model performance on the test data. Do this many times and collect model performances. Compute average performance across these models and check how many of those are higher than the performance of the selected features. One should expect that the average performance of the models with randomly drawn features would be substantially lower than the performance of the model with the selected features. One should also expect that the number of performances with randomly drawn features higher than the performance of the model with the selected features should be quite low. Say, if 4 out of 100 models with randomly drawn features are higher than the performance with the selected features, this would result in a p-value 4 / 100 = 0.04. It is up to the user where to set the required significance level.
#
# 2. permute the lables of the test data and compute model performance using the selected features every time. In the same manner as in point 1 above, collect the performances based on permuted labels and compute average performance. One should expect that the average performance for the models with permuted labels should be substantially lower. Also as in 1. one can compute the p-value from the permutation based model performances by checking how many of the models provided higher performance than the model using the original lables without permutation.
#
# A nice source on these permuation based p-values is provideded [here](https://www.jwilber.me/permutationtest/ )

# %%
analysis.validation_study(test_data, test_labels, num_drawings=100, num_permutations=1000, alpha=0.05)
# Out:
# VS1: p-value for average score from random feature drawing:  0.02
# With a significancelevel of  0.05  H0 is rejected.
#
# -------------------------------------------------
#
# VS2: p-value for score from permutation of test labels:  0.0
# With a significancelevel of  0.05  H0 is rejected.

# %% [markdown]
# From the plot above and the computed p-values we can conclude that the test performance with the selected features is:
#
# * significantly better than the average prediction performance from randomly drawn features from the full set of features
# * significantly better than the average prediction performance from models with permuted test labels
#
# This means we can be confident that we have selected relevant and important features for the model.

# %% [markdown]
# To evaluate the stability of RENT we use a stability measure investiaged by Nogueira et al. We define RENT as stable, if the selected feature set is the same up to some random variability, when applying RENT multiple times (`M`) to the same dataset.

# %%
import stability as st
import numpy as np
from sklearn.linear_model import LogisticRegression
import time


M=10 # number of runs 
alpha = 0.05 # level of significance for the confidence interval 
d = len(train_data.columns) # number of features
counts = [2, 5, 10, 50, 100, 300, 500] # values to compare (K)
C, l1 = analysis.get_enet_params()

# Store outputs in dictionaries
times = {}
stabilities = {}
perf = {}
num_feats = {}

start = time.time()

for count in counts:
    time_count = []
    Z_net = np.zeros((M,d), dtype=np.int8)
    performance = np.zeros(M)
    numFeatures = np.zeros(M)
    
    for i in range(M):
        model = RENT.RENT_Classification(data=train_data.values,
                                        target=train_labels,
                                        C=[C],
                                        l1_ratios=[l1],
                                        autoEnetParSel=False,
                                        poly='OFF',
                                        testsize_range=(0.25,0.25),
                                        scoring='mcc',
                                        K=count,
                                        scale=True,
                                        verbose=0)
        model.train()
        features = model.selectFeatures(0.9,0.9,0.975)
        time_count.append(model.get_runtime())
        
        #prediction model
        sc = StandardScaler()
        train = sc.fit_transform(train_data.values[:,features])
        test = sc.transform(test_data.values[:,features])
        ML_model = LogisticRegression(penalty='none', max_iter=8000, solver='saga').fit(train, train_labels)
        performance[i] = matthews_corrcoef(test_labels, ML_model.predict(test))
        Z_net[i,features] = 1
        numFeatures[i] = len(features)
    
    times[count] = time_count
    stabilities[count] = st.confidenceIntervals(Z_net, alpha=alpha)
    perf[count] = performance
    num_feats[count] = numFeatures    

end = time.time()

print('Runtime: ', end - start)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-f568704a4ddc> in <module>
# ----> 1 import stability as st
#       2 import numpy as np
#       3 from sklearn.linear_model import LogisticRegression
#       4 import time
#       5
#
# ModuleNotFoundError: No module named 'stability'

# %% [markdown]
# The following plot compares the runtime, stability and prediction performance of RENT for different `K` values.

# %%
import matplotlib.pyplot as plt
def stability_plot(x_levels, stabilities, accuracies, times):
    stability = np.array(list({k: v['stability'] for k, v in stabilities.items()}.values()))
    stab_error = stability - np.array(list({k: v['lower'] for k, v in stabilities.items()}.values()))
    performance = np.array(list({k: np.mean(v) for k, v in accuracies.items()}.values()))
    performance_error = np.array(list({k: np.std(v) for k, v in accuracies.items()}.values()))
    runtime = np.array(list({k: np.mean(v) for k, v in times.items()}.values()))
    runtime_errors = np.array(list({k: np.std(v) for k, v in times.items()}.values())) 

    fig, ax1 = plt.subplots()
    ax1.set_xlabel('number of models (K)',fontsize=10)
    stab = ax1.plot(x_levels,stability, color="red", label='stability', marker='o')
    ax1.fill_between(x_levels, (stability-stab_error), (stability+stab_error),color="red", alpha= 0.1 )
    perf = ax1.plot(x_levels,performance, color="blue", label='performance', marker='o')
    ax1.fill_between(x_levels, (performance-performance_error), (performance+performance_error),color="blue", alpha= 0.1 )
    plt.ylim(0,1.1)
    plt.yticks(fontsize=10)
    plt.xticks(fontsize=10)
    ax2 = ax1.twinx()
    ax2.set_ylabel('time[s]', color='green', fontsize=10)
    tim = ax2.plot(x_levels,runtime, color="green", label='runtime', marker='o')
    ax2.fill_between(x_levels, (runtime-runtime_errors), (runtime+runtime_errors),color="green", alpha= 0.1)
    ax2.tick_params(axis='y', labelcolor="green")

    leg = stab + perf + tim
    labs = [l.get_label() for l in leg]
    ax1.legend(leg, labs, loc=4, fontsize=10)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)


stability_plot(counts, stabilities, perf, times)
